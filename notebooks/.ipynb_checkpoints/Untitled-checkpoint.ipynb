# %%
#!/usr/bin/env python3

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Absolute paths (edit if needed)
# -----------------------------
RUN_IDS = {
    "Baseline_JanS_2MB_16_Way": "sniper_roi1000_fixedcap2m_20250927T171235Z",
    "JanS_2MB_8_Way": "sniper_assoc_jans2mb_8way_20250929T024544Z",
    "JanS_16MB_16_Way": "sniper_cap_equal_16mb_20250929T024544Z",
    "JanS_32MB_16_Way": "sniper_cap_equal_32mb_20250929T024544Z",
    "ChungS_2MB_16_Way": "sniper_dev_chungs_2mb_20250929T024350Z",
    "UmekiS_2MB_16_Way": "sniper_dev_umekis_2mb_20250929T024536Z",
    "XueS_2MB_16_Way": "sniper_dev_xues_2mb_20250929T024537Z"
}
DYNAMORIO_LOGS_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
TIMESTAMP_PREFIX    = "20250929T203551Z"  # prefix used in DynamoRIO filenames

# -----------------------------
# Utilities
# -----------------------------
def safe_div(numer, denom):
    numer = np.array(numer, dtype=float)
    denom = np.array(denom, dtype=float)
    with np.errstate(divide='ignore', invalid='ignore'):
        out = np.where((denom > 0) & np.isfinite(denom), numer / denom, np.nan)
    return out

def geomean(values):
    vals = np.array([v for v in np.ravel(values) if v > 0 and np.isfinite(v)], dtype=float)
    return float(np.exp(np.mean(np.log(vals)))) if len(vals) else np.nan


# -----------------------------
# Parsing helpers
# -----------------------------
def parse_sniper(base_dir):
    """
    Walk output_* folders, read summary.csv and energy_bounds.csv,
    merge them on (benchmark, config). Return a tidy DataFrame.
    Besides the core columns, we opportunistically keep LLC event counters
    (e.g., l3/llc accesses, hits/misses, reads/writes) if they exist.
    """
    energy_rows = []
    summary_rows = []
    print(f"--- Parsing Sniper results from: {base_dir} ---")
    for root, _, files in os.walk(base_dir):
        if os.path.basename(root).startswith("output_") and "summary.csv" in files and "energy_bounds.csv" in files:
            energy_path  = os.path.join(root, "energy_bounds.csv")
            summary_path = os.path.join(root, "summary.csv")

            e = pd.read_csv(energy_path)
            s = pd.read_csv(summary_path)

            # Keep columns we actually use from energy
            e_keep = [
                "benchmark", "config", "time_s",
                "energy_exact_J", "leak_J", "dyn_exact_nJ"
            ]
            e = e[[c for c in e_keep if c in e.columns]].copy()

            # Base columns we want from summary
            s_base = ["benchmark", "config", "ipc", "time_ns", "l3_miss_rate_pct"]
            keep_s = [c for c in s_base if c in s.columns]

            # Try to keep any plausible LLC event columns automatically
            # (we won't fail if they're absent)
            for col in s.columns:
                cl = col.lower()
                if ("l3" in cl or "llc" in cl) and (
                    "access" in cl or "read" in cl or "write" in cl or "hit" in cl or "miss" in cl or "evict" in cl
                ):
                    if col not in keep_s:
                        keep_s.append(col)

            s = s[keep_s].copy()

            # Numeric coercion
            for col in ["time_s", "energy_exact_J", "leak_J", "dyn_exact_nJ"]:
                if col in e.columns:
                    e[col] = pd.to_numeric(e[col], errors="coerce")

            for col in s.columns:
                if col not in ("benchmark", "config"):
                    s[col] = pd.to_numeric(s[col], errors="coerce")

            # Convert nJ -> J
            if "dyn_exact_nJ" in e.columns:
                e["dyn_exact_J"] = e["dyn_exact_nJ"] * 1e-9

            energy_rows.append(e)
            summary_rows.append(s)

    if not energy_rows or not summary_rows:
        raise FileNotFoundError(
            "Could not find summary.csv and energy_bounds.csv in output_* directories under: " + base_dir
        )

    E = pd.concat(energy_rows, ignore_index=True)
    S = pd.concat(summary_rows, ignore_index=True)

    df = pd.merge(E, S, on=["benchmark", "config"], how="inner")

    # minimal sanity
    df = df.dropna(subset=["benchmark", "config", "time_s", "energy_exact_J"])
    print(f"Sniper parse complete. Merged DataFrame shape: {df.shape}")
    print(f"Sniper columns found: {df.columns.tolist()}")
    print("-" * 20)
    return df


def _kv_from_line(s: str) -> dict:
    """Extract numeric key=value pairs from one rwstats line. 'scope' handled separately."""
    kv = {}
    m = re.search(r"\bscope=(\w+)", s)
    if m:
        kv["scope"] = m.group(1)

    for k, v in re.findall(r"([A-Za-z0-9_]+)=([+\-]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+\-]?\d+)?|nan)", s):
        try:
            kv[k] = float("nan") if v.lower() == "nan" else float(v)
        except Exception:
            pass
    return kv


def parse_dynamorio(logs_dir, ts_prefix):
    """
    Parse DynamoRIO log files. For each file, grab the LAST stats-like line
    (lines contain 'scope='). File name format: {ts_prefix}_<benchmark>_instr.rwstats.log
    """
    rows = []
    print(f"\n--- Parsing DynamoRIO logs from: {logs_dir} with prefix '{ts_prefix}' ---")
    if not os.path.isdir(logs_dir):
        print("DynamoRIO logs directory not found. Returning empty DataFrame.")
        print("-" * 20)
        return pd.DataFrame()

    found_files = 0
    for fname in os.listdir(logs_dir):
        if not (fname.startswith(ts_prefix) and fname.endswith("_instr.rwstats.log")):
            continue
        m = re.match(rf"{re.escape(ts_prefix)}_(.+?)_instr\.rwstats\.log$", fname)
        if not m:
            continue
        
        found_files += 1
        benchmark = m.group(1)
        fpath = os.path.join(logs_dir, fname)

        last = None
        with open(fpath, "r", errors="ignore") as f:
            for line in f:
                t = line.strip()
                if "scope=" in t and "=" in t:
                    last = t

        if not last:
            continue

        kv = _kv_from_line(last)
        kv["benchmark"] = benchmark
        rows.append(kv)

    print(f"Found and processed {found_files} matching log files.")
    df = pd.DataFrame(rows) if rows else pd.DataFrame()
    if not df.empty:
        print(f"DynamoRIO parse complete. DataFrame shape: {df.shape}")
        print(f"DynamoRIO columns found: {df.columns.tolist()}")
    else:
        print("DynamoRIO parse complete. No data found, returning empty DataFrame.")
    print("-" * 20)
    return df


# -----------------------------
# Event detection (for per-event view)
# -----------------------------
def detect_llc_events_per_config(df_config):
    """
    Best-effort extraction of an LLC event count from Sniper summary columns
    for a (benchmark-indexed, single-config) DataFrame.
    Priority:
      1) total 'llc_accesses' or 'l3_accesses'
      2) sum of reads+writes
      3) sum of hits+misses
    Returns: pd.Series (index=benchmark) or None if nothing found.
    """
    if df_config is None or df_config.empty:
        return None

    cols = {c.lower(): c for c in df_config.columns}

    # 1) Direct totals
    for key in ["llc_accesses", "l3_accesses", "roi_llc_accesses", "roi_l3_accesses"]:
        if key in cols:
            ser = pd.to_numeric(df_config[cols[key]], errors="coerce")
            if ser.notna().any():
                print(f"[Event Detection] Found total LLC events using column: '{cols[key]}'")
                return ser

    # 2) Reads + writes
    read_keys  = [k for k in cols if ("read"  in k or "rd_" in k) and ("l3" in k or "llc" in k)]
    write_keys = [k for k in cols if ("write" in k or "wr_" in k) and ("l3" in k or "llc" in k)]
    if read_keys and write_keys:
        # choose the most populated pair
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for rk in read_keys:
            for wk in write_keys:
                s = pd.to_numeric(df_config[cols[rk]], errors="coerce") + pd.to_numeric(df_config[cols[wk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[rk], cols[wk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing reads+writes: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    # 3) Hits + misses
    hit_keys   = [k for k in cols if ("hit"   in k) and ("l3" in k or "llc" in k)]
    miss_keys  = [k for k in cols if ("miss"  in k) and ("l3" in k or "llc" in k)]
    if hit_keys and miss_keys:
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for hk in hit_keys:
            for mk in miss_keys:
                s = pd.to_numeric(df_config[cols[hk]], errors="coerce") + pd.to_numeric(df_config[cols[mk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[hk], cols[mk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing hits+misses: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    print("[Event Detection] No suitable LLC event columns found.")
    return None


def build_mem_instruction_counts(dr_df, benchmarks):
    """
    From DynamoRIO, create a per-benchmark count of memory instructions
    (reads + writes). Returns (Series or None).
    """
    if dr_df is None or dr_df.empty:
        return None

    dr = dr_df.set_index("benchmark")
    read_col  = None
    write_col = None

    # common column names
    for cand in ["read_total", "loads", "ld_total", "mem_reads"]:
        if cand in dr.columns:
            read_col = cand
            break
    for cand in ["write_total", "stores", "st_total", "mem_writes"]:
        if cand in dr.columns:
            write_col = cand
            break

    if read_col is None or write_col is None:
        print("[Mem Instr] Could not find read/write total columns in DynamoRIO data.")
        return None

    print(f"[Mem Instr] Calculating memory instructions from DR columns: '{read_col}' + '{write_col}'")
    mem = pd.to_numeric(dr[read_col], errors="coerce") + pd.to_numeric(dr[write_col], errors="coerce")
    mem = mem.reindex(benchmarks)
    if mem.notna().any():
        return mem
    return None


# -----------------------------
# Plot helpers
# -----------------------------
def grouped_barh(ax, labels, a_values, b_values, a_label, b_label, title, x_label):
    y = np.arange(len(labels))
    h = 0.38
    ax.barh(y - h/2, a_values, height=h, label=a_label)
    ax.barh(y + h/2, b_values, height=h, label=b_label)
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()  # top item at top
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)

def corr_heatmap(ax, matrix, row_labels, col_labels, title):
    im = ax.imshow(matrix, aspect="auto", vmin=-1, vmax=1, cmap="coolwarm")
    ax.set_yticks(np.arange(len(row_labels)))
    ax.set_yticklabels(row_labels)
    ax.set_xticks(np.arange(len(col_labels)))
    ax.set_xticklabels(col_labels, rotation=90)
    ax.set_title(title, fontsize=11)
    # annotate
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            val = matrix[i, j]
            ax.text(
                j, i, f"{val:.2f}",
                ha="center", va="center",
                color="white" if abs(val) > 0.6 else "black",
                fontsize=8
            )
    return im

def stacked_barh(ax, labels, data, category_labels, title, x_label):
    y = np.arange(len(labels))
    left = np.zeros(len(labels))
    for i, category in enumerate(data.keys()):
        values = data[category]
        ax.barh(y, values, left=left, label=category_labels[i], height=0.6)
        left += values
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)


# -----------------------------
# Single-run analysis wrapper
# -----------------------------
def analyze_one_run(base_results_dir, run_tag, dr_logs_dir=DYNAMORIO_LOGS_DIR, ts_prefix=TIMESTAMP_PREFIX):
    # Create a per-run output folder
    out_dir = os.path.join(os.getcwd(), f"out_{run_tag}")
    os.makedirs(out_dir, exist_ok=True)

    # --------------- Load data ---------------
    sniper = parse_sniper(base_results_dir)
    dr = parse_dynamorio(dr_logs_dir, ts_prefix)

    # Save raw inputs (handy for inspection)
    sniper.to_csv(os.path.join(out_dir, "sniper_raw.csv"), index=False)
    if not dr.empty:
        dr.to_csv(os.path.join(out_dir, "dynamorio_raw.csv"), index=False)

    print("\n--- Processing and Filtering Data ---")
    # Focus on benchmarks present in BOTH SRAM and JanS
    sram = sniper[sniper["config"] == "SRAM"].set_index("benchmark")
    jans = sniper[sniper["config"] == "JanS"].set_index("benchmark")
    common = sram.index.intersection(jans.index)
    if len(common) == 0:
        raise RuntimeError("No common benchmarks between SRAM and JanS.")
    
    print(f"Found {len(common)} common benchmarks between SRAM and JanS configs: {common.tolist()}")

    sram = sram.loc[common].copy()
    jans = jans.loc[common].copy()

    # Sort by SRAM execution time to keep labels readable
    order = sram.sort_values("time_s").index.tolist()
    sram = sram.loc[order]
    jans = jans.loc[order]
    labels = order
    
    print("Sorted benchmarks by SRAM execution time:", labels)
    print("\n--- SRAM Data (head) ---")
    print(sram.head())
    print("\n--- JanS Data (head) ---")
    print(jans.head())
    print("-" * 20)

    # ---------------- Sniper comparisons (compact 2x2) ----------------
    plt.rcParams.update({
        "figure.figsize": (11, 8),
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "xtick.labelsize": 8,
        "ytick.labelsize": 8
    })
    fig, axs = plt.subplots(2, 2)

    # 1) Execution time (s)
    grouped_barh(
        axs[0, 0], labels,
        sram["time_s"].values, jans["time_s"].values,
        "SRAM", "JanS",
        "Execution Time", "seconds"
    )

    # 2) Total LLC energy (J)
    grouped_barh(
        axs[0, 1], labels,
        sram["energy_exact_J"].values, jans["energy_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (total)", "Joules"
    )

    # 3) Dynamic LLC energy (J)
    grouped_barh(
        axs[1, 0], labels,
        sram["dyn_exact_J"].values, jans["dyn_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (dynamic only)", "Joules"
    )

    # 4) Leakage LLC energy (J)
    grouped_barh(
        axs[1, 1], labels,
        sram["leak_J"].values, jans["leak_J"].values,
        "SRAM", "JanS",
        "LLC Energy (leakage only)", "Joules"
    )

    fig.suptitle("SRAM vs JanS — Timing and Energy (per benchmark)", fontsize=12, y=0.99)
    fig.tight_layout(rect=[0, 0, 1, 0.97])

    # ------------------ Figure: Normalized Performance Summary ------------------
    norm = pd.DataFrame(index=order)
    norm["norm_time"]   = safe_div(jans["time_s"], sram["time_s"])
    norm["norm_energy"] = safe_div(jans["energy_exact_J"], sram["energy_exact_J"])
    
    print("\n--- Normalized Data (JanS / SRAM) ---")
    print(norm)
    print("-" * 20)

    fig2, axs2 = plt.subplots(2, 2, figsize=(11, 8))

    # 1) Normalized Execution Time
    axs2[0, 0].bar(norm.index, norm["norm_time"])
    axs2[0, 0].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 0].set_title("Normalized Execution Time (JanS / SRAM)", fontsize=11)
    axs2[0, 0].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 0].grid(True, axis="y", linestyle=":")

    # 2) Normalized Total LLC Energy
    axs2[0, 1].bar(norm.index, norm["norm_energy"])
    axs2[0, 1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 1].set_title("Normalized Total LLC Energy (JanS / SRAM)", fontsize=11)
    axs2[0, 1].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 1].grid(True, axis="y", linestyle=":")

    # 3) Absolute IPC
    x = np.arange(len(labels))
    width = 0.35
    axs2[1, 0].bar(x - width/2, sram["ipc"], width, label='SRAM')
    axs2[1, 0].bar(x + width/2, jans["ipc"], width, label='JanS')
    axs2[1, 0].set_title("Instructions Per Cycle (IPC)", fontsize=11)
    axs2[1, 0].set_ylabel("IPC (Higher is Better)", fontsize=10)
    axs2[1, 0].legend(fontsize=8, frameon=False)

    # 4) L3 Miss Rate (%)
    if "l3_miss_rate_pct" in sram.columns and "l3_miss_rate_pct" in jans.columns:
        axs2[1, 1].bar(x - width/2, sram["l3_miss_rate_pct"], width, label='SRAM')
        axs2[1, 1].bar(x + width/2, jans["l3_miss_rate_pct"], width, label='JanS')
        axs2[1, 1].set_title("L3 Miss Rate", fontsize=11)
        axs2[1, 1].set_ylabel("Miss Rate (%)", fontsize=10)
        axs2[1, 1].legend(fontsize=8, frameon=False)
    else:
        axs2[1, 1].axis("off")

    for ax in axs2.flatten():
        ax.set_xticks(np.arange(len(labels)))
        ax.set_xticklabels(labels, rotation=90)
        ax.tick_params(axis="x", labelsize=8)

    # Geomeans for headline
    gm_time   = geomean(norm["norm_time"])
    gm_energy = geomean(norm["norm_energy"])
    fig2.suptitle(f"Performance & Cache Metrics: SRAM vs. JanS — GeoMeans (JanS/SRAM): "
                  f"time={gm_time:.3f}, energy={gm_energy:.3f}",
                  fontsize=13, y=0.99)
    fig2.tight_layout(rect=[0, 0, 1, 0.96])

    # ------------------ Figure: LLC Energy Breakdown ------------------
    fig_e, axs_e = plt.subplots(1, 2, figsize=(11, 5), sharex=True)
    sram_energy_data = {'Dynamic': sram["dyn_exact_J"], 'Leakage': sram["leak_J"]}
    jans_energy_data = {'Dynamic': jans["dyn_exact_J"], 'Leakage': jans["leak_J"]}

    stacked_barh(axs_e[0], labels, sram_energy_data, ['Dynamic', 'Leakage'], "SRAM LLC Energy Breakdown", "Joules")
    stacked_barh(axs_e[1], labels, jans_energy_data, ['Dynamic', 'Leakage'], "JanS LLC Energy Breakdown", "Joules")

    fig_e.suptitle("LLC Energy Composition: Dynamic vs. Leakage", fontsize=13, y=0.99)
    fig_e.tight_layout(rect=[0, 0, 1, 0.94])

    # ---------------- Mechanism View: Dynamic energy per event ----------------
    print("\n--- Calculating Dynamic Energy per Event ---")
    # Try to use *LLC event counts* from Sniper; if unavailable, fall back to *memory instructions* from DynamoRIO.
    per_event_mode = None  # "llc" or "mem"
    sram_denom = detect_llc_events_per_config(sram)
    jans_denom = detect_llc_events_per_config(jans)

    if sram_denom is not None and jans_denom is not None:
        per_event_mode = "llc"
        sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, sram_denom)
        jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, jans_denom)
        denom_label = "LLC event"
    else:
        mem_instr = build_mem_instruction_counts(dr, labels)
        if mem_instr is not None and np.nanmax(mem_instr.values) > 0:
            per_event_mode = "mem"
            # Same denominator for both configs (program-level memory instruction count)
            sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            denom_label = "memory instruction"
        else:
            per_event_mode = None
    
    print(f"Per-event mode chosen: '{per_event_mode}'")
    if per_event_mode:
        print(f"Denominator label: '{denom_label}'")
    print("-" * 20)

    if per_event_mode is not None:
        fig_pe, axs_pe = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(
            axs_pe[0], labels,
            sram_pJ, jans_pJ,
            "SRAM", "JanS",
            f"Dynamic LLC Energy per {denom_label}", f"pJ / {denom_label}"
        )
        ratio = safe_div(jans_pJ, sram_pJ)
        x = np.arange(len(labels))
        axs_pe[1].bar(x, ratio)
        axs_pe[1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
        axs_pe[1].set_title(f"Normalized pJ/{denom_label} (JanS / SRAM)")
        axs_pe[1].set_ylabel("Ratio (Lower is Better)")
        axs_pe[1].set_xticks(x)
        axs_pe[1].set_xticklabels(labels, rotation=90)
        axs_pe[1].grid(True, axis="y", linestyle=":")

        gm_pe = geomean(ratio)
        fig_pe.suptitle(
            f"Mechanism: Dynamic Energy per {denom_label} — Geomean (JanS/SRAM) = {gm_pe:.3f}",
            fontsize=13, y=0.99
        )
        fig_pe.tight_layout(rect=[0, 0, 1, 0.94])

        # Save CSV of the per-event metrics
        per_event_df = pd.DataFrame({
            "benchmark": labels,
            "SRAM_dyn_pJ_per_"+denom_label: sram_pJ,
            "JanS_dyn_pJ_per_"+denom_label: jans_pJ,
            "JanS_over_SRAM_pJ_per_"+denom_label: ratio
        }).set_index("benchmark")
        # Add denominators for transparency
        if per_event_mode == "llc":
            per_event_df["SRAM_"+denom_label+"s"] = sram_denom.reindex(labels).values
            per_event_df["JanS_"+denom_label+"s"] = jans_denom.reindex(labels).values
        else:
            per_event_df[denom_label+"s"] = build_mem_instruction_counts(dr, labels).reindex(labels).values
        
        print("\n--- Per-Event Dynamic Energy Data ---")
        print(per_event_df)
        print("-" * 20)
        per_event_df.to_csv(os.path.join(out_dir, "per_event_dynamic_energy.csv"))

    # ---------------- Correlation: DynamoRIO features vs totals / gains ----------------
    if not dr.empty:
        print("\n--- Building Correlation Matrix Data ---")
        feat_map = {
            "rtotal":     "read_total",
            "runique":    "read_unique",
            "90%f_tr":    "read_footprint90L",   # global, line-level
            "Hrg":        "read_entropy",
            "Hrl":        "read_local_entropy",
            "wtotal":     "write_total",
            "wunique":    "write_unique",
            "90%f_tw":    "write_footprint90L",  # global, line-level
            "Hwg":        "write_entropy",
            "Hwl":        "write_local_entropy",
        }

        feats = pd.DataFrame({"benchmark": dr["benchmark"]})
        for out_name, src in feat_map.items():
            feats[out_name] = pd.to_numeric(dr.get(src), errors="coerce")
        feats = feats.set_index("benchmark")

        # Targets (SRAM absolute) and normalized gains
        targets_sram = sram[["time_s", "energy_exact_J", "dyn_exact_J", "ipc"]].copy()
        if "l3_miss_rate_pct" in sram.columns:
            targets_sram["L3_miss%"] = sram["l3_miss_rate_pct"]
        targets_sram = targets_sram.rename(columns={
            "time_s": "exe_time", "energy_exact_J": "LLC_energy", "dyn_exact_J": "Dyn_energy", "ipc": "IPC"
        })

        corr_df = feats.join(targets_sram, how="inner").join(norm[["norm_time", "norm_energy"]], how="inner")

        # If per-event dynamic energy exists, add one column (SRAM) and one ratio
        if per_event_mode is not None:
            corr_label_abs = f"pJ/{denom_label} (SRAM)"
            corr_label_norm = f"norm_pJ/{denom_label} (JanS/SRAM)"
            corr_df[corr_label_abs] = pd.Series(sram_pJ, index=labels)
            corr_df[corr_label_norm] = pd.Series(safe_div(jans_pJ, sram_pJ), index=labels)

        print("Correlation DataFrame (head):")
        print(corr_df.head())
        print("-" * 20)

        feature_names = [k for k in feat_map.keys() if k in corr_df.columns and not corr_df[k].isna().all()]
        abs_cols = [c for c in ["exe_time", "LLC_energy", "Dyn_energy", "IPC", "L3_miss%",] if c in corr_df.columns and not corr_df[c].isna().all()]
        norm_cols = [c for c in ["norm_time", "norm_energy"] if c in corr_df.columns and not corr_df[c].isna().all()]
        extra_cols = []
        if per_event_mode is not None:
            for c in [corr_label_abs, corr_label_norm]:
                if c in corr_df.columns and not corr_df[c].isna().all():
                    extra_cols.append(c)

        if feature_names and (abs_cols or norm_cols or extra_cols) and len(corr_df.dropna(how="all")) >= 2:
            n_panels = 2 if extra_cols else 2
            fig_c, axs_c = plt.subplots(1, 2, figsize=(9, 5))

            # Features vs. SRAM absolute metrics
            if abs_cols:
                C1 = corr_df[feature_names + abs_cols].corr().loc[feature_names, abs_cols].values
                corr_heatmap(axs_c[0], C1, feature_names, abs_cols, "Features vs. SRAM Totals")
            else:
                axs_c[0].axis("off")

            # Features vs. normalized gains (+ optional per-event targets)
            cols2 = norm_cols + extra_cols
            if cols2:
                C2 = corr_df[feature_names + cols2].corr().loc[feature_names, cols2].values
                corr_heatmap(axs_c[1], C2, feature_names, cols2, "Features vs. Gains / Per-Event")
            else:
                axs_c[1].axis("off")
            
            fig_c.suptitle("Correlation: Memory Features ↔ Totals & Gains", fontsize=13, y=0.99)
            fig_c.tight_layout(rect=[0, 0, 1, 0.92])
        else:
            print("Not enough data for correlation heatmaps (missing features/targets or too few benchmarks).")
    else:
        print("DynamoRIO features unavailable — skipping correlation plots.")

    # -------- Save headline geomeans --------
    geomean_df = pd.DataFrame({
        "metric": ["time (JanS/SRAM)", "total LLC energy (JanS/SRAM)"],
        "geomean_ratio": [gm_time, gm_energy],
    })
    print("\n--- Geomean Summary ---")
    print(geomean_df)
    print("-" * 20)
    geomean_df.to_csv(os.path.join(out_dir, "geomean_summary.csv"), index=False)

    #########################################
    
    print("\n--- Additional System-Level Analysis (Power & EDP) ---")
    sys = pd.DataFrame({
        "benchmark": labels,
        "SRAM_time_s": sram["time_s"].values,
        "JanS_time_s": jans["time_s"].values,
        "SRAM_energy_J": sram["energy_exact_J"].values,
        "JanS_energy_J": jans["energy_exact_J"].values,
        "SRAM_dyn_W": safe_div(sram["dyn_exact_J"].values, sram["time_s"].values),
        "JanS_dyn_W": safe_div(jans["dyn_exact_J"].values, jans["time_s"].values),
        "SRAM_leak_W": safe_div(sram["leak_J"].values, sram["time_s"].values),
        "JanS_leak_W": safe_div(jans["leak_J"].values, jans["time_s"].values),
    }).set_index("benchmark")
    sys["SRAM_EDP"] = sys["SRAM_energy_J"] * sys["SRAM_time_s"]
    sys["JanS_EDP"] = sys["JanS_energy_J"] * sys["JanS_time_s"]

    print("System-level metrics (head):")
    print(sys.head())
    print("-" * 20)
    
    fig_sys, axs_sys = plt.subplots(1, 3, figsize=(14, 5))
    grouped_barh(axs_sys[0], labels,
                 sys["SRAM_dyn_W"].values, sys["JanS_dyn_W"].values,
                 "SRAM","JanS","Dynamic Power (LLC)","Watts")
    grouped_barh(axs_sys[1], labels,
                 sys["SRAM_leak_W"].values, sys["JanS_leak_W"].values,
                 "SRAM","JanS","Leakage Power (LLC)","Watts")

    x = np.arange(len(labels))
    edp_ratio = safe_div(sys["JanS_EDP"].values, sys["SRAM_EDP"].values)
    axs_sys[2].bar(x, edp_ratio)
    axs_sys[2].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
    axs_sys[2].set_xticks(x)
    axs_sys[2].set_xticklabels(labels, rotation=90)
    axs_sys[2].set_ylabel("Ratio (Lower is Better)")
    axs_sys[2].set_title("EDP (JanS / SRAM)")
    fig_sys.suptitle("System Power & EDP", fontsize=13, y=0.99)
    fig_sys.tight_layout(rect=[0,0,1,0.94])

    # -- B) Per-miss dynamic energy (best-effort) -----------------------------
    def _approx_misses(df_config, total_series):
        if total_series is None or "l3_miss_rate_pct" not in df_config.columns:
            return None
        total = pd.to_numeric(total_series.reindex(df_config.index), errors="coerce")
        miss_rate = pd.to_numeric(df_config["l3_miss_rate_pct"], errors="coerce") / 100.0
        misses = total * miss_rate
        return misses if misses.notna().any() else None

    sram_total = detect_llc_events_per_config(sram)
    jans_total = detect_llc_events_per_config(jans)
    sram_misses = _approx_misses(sram, sram_total) if sram_total is not None else None
    jans_misses = _approx_misses(jans, jans_total) if jans_total is not None else None

    if sram_misses is not None and jans_misses is not None:
        print("\n--- Per-Miss Dynamic Energy Analysis ---")
        pJmiss_s = safe_div(sram["dyn_exact_J"].values * 1e12, sram_misses.reindex(labels).values)
        pJmiss_j = safe_div(jans["dyn_exact_J"].values * 1e12, jans_misses.reindex(labels).values)
        r_pm = safe_div(pJmiss_j, pJmiss_s)

        pm_df = pd.DataFrame({
            'sram_misses_approx': sram_misses,
            'jans_misses_approx': jans_misses,
            'sram_pJ_per_miss': pJmiss_s,
            'jans_pJ_per_miss': pJmiss_j,
            'ratio_pJ_per_miss': r_pm
        }, index=labels)
        print("Per-miss energy data (head):")
        print(pm_df.head())
        print("-" * 20)

        fig_pm, axs_pm = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(axs_pm[0], labels, pJmiss_s, pJmiss_j,
                     "SRAM","JanS","Dynamic Energy per L3 Miss","pJ / miss")

        axs_pm[1].bar(x, r_pm)
        axs_pm[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
        axs_pm[1].set_xticks(x)
        axs_pm[1].set_xticklabels(labels, rotation=90)
        axs_pm[1].set_ylabel("Ratio (Lower is Better)")
        axs_pm[1].set_title("pJ/miss (JanS / SRAM)")
        fig_pm.suptitle("Per-Miss Dynamic Energy (approx. via miss_rate × total L3/LLC)", y=0.99)
        fig_pm.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[per-miss] Skipped: need total L3/LLC events + l3_miss_rate_pct in summary.csv.")

    # -- C) Event-type cost fit (pJ per event) -------------------------------
    def _choose_col(df_config, must_terms, maybes=("l3","llc")):
        best = None; best_pop = -1
        for c in df_config.columns:
            cl = c.lower()
            if all(t in cl for t in must_terms) and any(m in cl for m in maybes):
                ser = pd.to_numeric(df_config[c], errors="coerce")
                pop = ser.notna().sum()
                if pop > best_pop:
                    best, best_pop = c, pop
        return best

    def _find_event_cols(df_config):
        mapping = {
            "read_hit":  ["read","hit"],
            "write_hit": ["write","hit"],
            "read_miss": ["read","miss"],
            "write_miss":["write","miss"],
            "evict":     ["evict"],
        }
        out = {}
        for name, terms in mapping.items():
            col = _choose_col(df_config, terms)
            if col is None and name == "evict":
                col = _choose_col(df_config, ["writeback"]) or _choose_col(df_config, ["wb"])
            if col is not None:
                out[name] = col
        return out

    def _fit_costs(df_config, event_cols):
        if not event_cols:
            return None, None
        X_cols = list(event_cols.values())
        X = np.column_stack([pd.to_numeric(df_config[c], errors="coerce").fillna(0.0).values for c in X_cols])
        y = pd.to_numeric(df_config["dyn_exact_J"], errors="coerce").values
        mask = np.isfinite(y)
        for i in range(X.shape[1]):
            mask &= np.isfinite(X[:, i])
        X, y = X[mask], y[mask]
        if X.shape[0] < len(X_cols):
            return None, None
        beta, residuals, rank, s = np.linalg.lstsq(X, y, rcond=None)
        r2 = 1.0 - ((y - X @ beta)**2).sum() / np.maximum(1e-12, ((y - y.mean())**2).sum())
        return pd.Series(beta * 1e12, index=list(event_cols.keys())), r2  # pJ/event

    sram_event_cols = _find_event_cols(sram)
    jans_event_cols = _find_event_cols(jans)
    coef_s, r2_s = _fit_costs(sram, sram_event_cols)
    coef_j, r2_j = _fit_costs(jans, jans_event_cols)

    if coef_s is not None or coef_j is not None:
        print("\n--- Fitted Event Cost Analysis ---")
        print(f"SRAM event columns used for fit: {sram_event_cols}")
        print(f"JanS event columns used for fit: {jans_event_cols}")
        
        keys = sorted(set([] if coef_s is None else coef_s.index).union([] if coef_j is None else coef_j.index))
        s_vals = np.array([coef_s.get(k, np.nan) if coef_s is not None else np.nan for k in keys])
        j_vals = np.array([coef_j.get(k, np.nan) if coef_j is not None else np.nan for k in keys])

        fit_df = pd.DataFrame({'event_type': keys, 'SRAM_pJ_per_event': s_vals, 'JanS_pJ_per_event': j_vals}).set_index('event_type')
        print("Fitted coefficients (pJ/event):")
        print(fit_df)
        print(f"SRAM R² = {r2_s:.3f}, JanS R² = {r2_j:.3f}")
        print("-" * 20)

        fig_ev, ax_ev = plt.subplots(1, 1, figsize=(10, 4.8))
        xx = np.arange(len(keys)); w = 0.42
        ax_ev.bar(xx - w/2, s_vals, width=w, label="SRAM")
        ax_ev.bar(xx + w/2, j_vals, width=w, label="JanS")
        ax_ev.set_xticks(xx)
        ax_ev.set_xticklabels(keys)
        ax_ev.set_ylabel("pJ / event")
        ax_ev.set_title("Fitted LLC Event Costs")
        ax_ev.grid(True, axis="y", linestyle=":")
        ax_ev.legend(fontsize=8, frameon=False)
        fig_ev.suptitle(f"Event-Cost Fit (least squares) — R² SRAM={r2_s if r2_s is not None else float('nan'):.2f}, JanS={r2_j if r2_j is not None else float('nan'):.2f}", y=0.99)
        fig_ev.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[event-fit] Skipped: insufficient L3/LLC event columns in summary.csv.")

    # -- D) What-if gating rule visualization ---------------------------------
    try:
        if not dr.empty:
            print("\n--- What-if Gating Rule Visualization ---")
            dr_idx = dr.set_index("benchmark")
            rf = pd.to_numeric(dr_idx.get("read_footprint90L"), errors="coerce")
            wf = pd.to_numeric(dr_idx.get("write_footprint90L"), errors="coerce")
            p50s = pd.to_numeric(dr_idx.get("p50_strideB"), errors="coerce")
            rf_thr = np.nanmedian(rf.values); wf_thr = np.nanmedian(wf.values); stride_thr = 512 * 1024
            enable = ((rf >= rf_thr) | (wf >= wf_thr)) & (p50s <= stride_thr)
            enable = enable.reindex(labels).fillna(False)

            print(f"Gating rule: ((read_footprint >= {rf_thr:.1f}) OR (write_footprint >= {wf_thr:.1f})) AND (p50_stride <= {stride_thr})")
            print("Gating decisions (True means enable JanS):")
            print(enable)
            
            chosen_E = np.where(enable.values, jans["energy_exact_J"].values, sram["energy_exact_J"].values)
            chosen_T = np.where(enable.values, jans["time_s"].values,         sram["time_s"].values)
            energy_ratio = safe_div(chosen_E, sram["energy_exact_J"].values)
            time_ratio   = safe_div(chosen_T, sram["time_s"].values)
            print("-" * 20)

            fig_gate, axs_gate = plt.subplots(1, 2, figsize=(12, 5))
            axs_gate[0].bar(x, energy_ratio)
            axs_gate[0].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
            axs_gate[0].set_xticks(x); axs_gate[0].set_xticklabels(labels, rotation=90)
            axs_gate[0].set_ylabel("Ratio vs SRAM"); axs_gate[0].set_title("What-if Energy (rule)")

            axs_gate[1].bar(x, time_ratio)
            axs_gate[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
            axs_gate[1].set_xticks(x); axs_gate[1].set_xticklabels(labels, rotation=90)
            axs_gate[1].set_ylabel("Ratio vs SRAM"); axs_gate[1].set_title("What-if Time (rule)")

            # annotate chosen config under each bar
            for ax in axs_gate:
                ymin, ymax = ax.get_ylim()
                for xi, choose_j in enumerate(enable.values):
                    ax.text(xi, ymin + 0.02*(ymax - ymin),
                            "JanS" if choose_j else "SRAM",
                            rotation=90, ha="center", va="bottom", fontsize=7, alpha=0.75)
            fig_gate.suptitle("Simple Gating Rule Outcome", y=0.99)
            fig_gate.tight_layout(rect=[0,0,1,0.94])
        else:
            print("\n[gating] Skipped: no DynamoRIO features available.")
    except Exception as e:
        print("\n[gating] Error:", e)
    
    #########################################
    
        # ==== PREDICTORS ↔ OUTCOMES: DATA-BACKED CHECK ===========================
    # Build per-access metrics from DR (reads+writes)
    def _mem_accesses_from_dr(dr_df, bench_idx):
        if dr_df is None or dr_df.empty:
            return None
        d = dr_df.set_index("benchmark")
        # prefer "read_total"/"write_total", else common fallbacks
        rc = next((c for c in ["read_total","loads","ld_total","mem_reads"] if c in d.columns), None)
        wc = next((c for c in ["write_total","stores","st_total","mem_writes"] if c in d.columns), None)
        if rc is None or wc is None:
            return None
        mem = pd.to_numeric(d[rc], errors="coerce") + pd.to_numeric(d[wc], errors="coerce")
        return mem.reindex(bench_idx)

    mem = _mem_accesses_from_dr(dr, labels)
    if mem is not None and np.nanmax(mem.values) > 0:
        # Per-access metrics (SRAM & JanS)
        sram_pJ = safe_div(sram["dyn_exact_J"].values * 1e12, mem.values)
        jans_pJ = safe_div(jans["dyn_exact_J"].values * 1e12, mem.values)
        sram_ns = safe_div(sram["time_s"].values * 1e9, mem.values)
        jans_ns = safe_div(jans["time_s"].values * 1e9, mem.values)
        ratio_pJ = safe_div(jans_pJ, sram_pJ)
        ratio_ns = safe_div(jans_ns, sram_ns)

        # Pull DR predictors
        dr_idx = dr.set_index("benchmark")
        feats = pd.DataFrame(index=labels)
        for col in ["read_footprint90L","write_footprint90L","read_local_entropy","write_local_entropy"]:
            feats[col] = pd.to_numeric(dr_idx.get(col), errors="coerce").reindex(labels)

        # Assemble analysis frame
        A = pd.DataFrame({
            "ratio_pJ_per_access": ratio_pJ,
            "ratio_ns_per_access": ratio_ns,
            "sram_pJ_per_access":  sram_pJ,
            "sram_ns_per_access":  sram_ns,
        }, index=labels).join(feats)
        
        print("\n--- Predictor Analysis DataFrame (head) ---")
        print(A.head())
        print("-" * 20)

        def _corr_table(df, Xcols, Ycol):
            rows = []
            for x in Xcols:
                xser = pd.to_numeric(df[x], errors="coerce")
                yser = pd.to_numeric(df[Ycol], errors="coerce")
                if xser.notna().sum() >= 3 and yser.notna().sum() >= 3:
                    r_p = xser.corr(yser, method="pearson")
                    r_s = xser.corr(yser, method="spearman")
                    rows.append([x, r_p, r_s, xser.notna().sum()])
            return pd.DataFrame(rows, columns=["feature","pearson_r","spearman_r","N"]).set_index("feature")

        # Correlations that support the claims
        tab_foot_vs_ratio = _corr_table(A,
            ["read_footprint90L","write_footprint90L"], "ratio_pJ_per_access")
        tab_entropy_vs_sram_ns = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "sram_ns_per_access")
        tab_entropy_vs_sram_pJ = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "sram_pJ_per_access")
        tab_entropy_vs_ratio_ns = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "ratio_ns_per_access")

        print("\n[predictors] JanS/SRAM pJ per access vs 90% footprints:")
        print(tab_foot_vs_ratio.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] SRAM ns/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_sram_ns.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] SRAM pJ/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_sram_pJ.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] JanS/SRAM ns/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_ratio_ns.to_string(float_format=lambda v: f"{v: .3f}"))

        # Save CSV summary
        corr_out = (tab_foot_vs_ratio.assign(target="ratio_pJ/access")
                    .append(tab_entropy_vs_sram_ns.assign(target="sram_ns/access"))
                    .append(tab_entropy_vs_sram_pJ.assign(target="sram_pJ/access"))
                    .append(tab_entropy_vs_ratio_ns.assign(target="ratio_ns/access")))
        corr_out.to_csv(os.path.join(out_dir, "predictors_correlations.csv"))

        # --- Plots: clean and compact ---------------------------------------
        # 1) ratio pJ/access vs footprints
        fig_pf, axs_pf = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_pf,
            ["read_footprint90L","write_footprint90L"],
            ["JanS/SRAM pJ/access vs Read 90%Footprint (lines)",
             "JanS/SRAM pJ/access vs Write 90%Footprint (lines)"]
        ):
            x = A[col].values; y = A["ratio_pJ_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            # OLS line (best fit)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("lines"); 
        axs_pf[0].set_ylabel("JanS/SRAM pJ per access")
        fig_pf.tight_layout()

        # 2) SRAM per-access latency vs local entropies
        fig_he, axs_he = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_he,
            ["read_local_entropy","write_local_entropy"],
            ["SRAM ns/access vs Hrl","SRAM ns/access vs Hwl"]
        ):
            x = A[col].values; y = A["sram_ns_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("entropy (bits)"); 
        axs_he[0].set_ylabel("SRAM ns per access")
        fig_he.tight_layout()

        # 3) JanS/SRAM ns/access vs local entropies (to show 'little latency benefit')
        fig_ln, axs_ln = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_ln,
            ["read_local_entropy","write_local_entropy"],
            ["JanS/SRAM ns/access vs Hrl","JanS/SRAM ns/access vs Hwl"]
        ):
            x = A[col].values; y = A["ratio_ns_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("entropy (bits)"); 
        axs_ln[0].set_ylabel("JanS/SRAM ns per access")
        fig_ln.tight_layout()
    else:
        print("\n[predictors] Skipped: missing DR read/write totals to build per-access metrics.")

    # --------------- Save all figures for this run and close ---------------
    for i, num in enumerate(plt.get_fignums(), start=1):
        fig = plt.figure(num)
        fig.savefig(os.path.join(out_dir, f"fig_{i:02d}.png"), dpi=200, bbox_inches="tight")
    plt.close('all')


# -----------------------------
# Main
# -----------------------------
def main():
    for run_label, run_id in RUN_IDS.items():
        base_dir = f"/home/skataoka26/COSC_498/miniMXE/results/{run_id}"
        print(f"\n================= Processing: {run_label} =================")
        try:
            analyze_one_run(base_dir, run_tag=run_label)
        except Exception as e:
            print(f"[WARN] Skipping '{run_label}' due to error: {e}")


if __name__ == "__main__":
    main()
# Out:
# ================= Processing: Baseline_JanS_2MB_16_Way =================
# --- Parsing Sniper results from: /home/skataoka26/COSC_498/miniMXE/results/sniper_roi1000_fixedcap2m_20250927T171235Z ---
# Sniper parse complete. Merged DataFrame shape: (18, 19)
# Sniper columns found: ['benchmark', 'config', 'time_s', 'energy_exact_J', 'leak_J', 'dyn_exact_nJ', 'dyn_exact_J', 'ipc', 'time_ns', 'l3_miss_rate_pct', 'l3_miss_text', 'l3_accesses_db', 'l3_misses_db', 'l3_read_hits', 'l3_write_hits', 'l3_writebacks', 'l3_evictions', 'l3_misses_custom', 'avg_l3_hit_ns']
# --------------------
#
# --- Parsing DynamoRIO logs from: /home/skataoka26/COSC_498/miniMXE/results_trace/logs with prefix '20250929T203551Z' ---
# Found and processed 12 matching log files.
# DynamoRIO parse complete. DataFrame shape: (12, 40)
# ...

# %%
#!/usr/bin/env python3

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Absolute paths (edit if needed)
# -----------------------------
RUN_IDS = {
    "Baseline (JanS, 2MB, 16 Way)": "sniper_roi1000_fixedcap2m_20250927T171235Z",
    "JanS, 2MB, 8 Way": "sniper_assoc_jans2mb_8way_20250929T024544Z",
    "JanS, 16MB, 16 Way": "sniper_cap_equal_16mb_20250929T024544Z",
    "JanS, 32MB, 16 Way": "sniper_cap_equal_32mb_20250929T024544Z",
    "ChungS, 2MB, 16 Way": "sniper_dev_chungs_2mb_20250929T024350Z",
    "UmekiS, 2MB, 16 Way": "sniper_dev_umekis_2mb_20250929T024536Z",
    "XueS, 2MB, 16 Way": "sniper_dev_xues_2mb_20250929T024537Z"
}
SNIPER_RESULTS_DIR= f"/home/skataoka26/COSC_498/miniMXE/results/{RUN_IDS['JanS, 2MB, 16 Way']}"
DYNAMORIO_LOGS_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
TIMESTAMP_PREFIX    = "20250929T203551Z"  # prefix used in DynamoRIO filenames

# -----------------------------
# Utilities
# -----------------------------
def safe_div(numer, denom):
    numer = np.array(numer, dtype=float)
    denom = np.array(denom, dtype=float)
    with np.errstate(divide='ignore', invalid='ignore'):
        out = np.where((denom > 0) & np.isfinite(denom), numer / denom, np.nan)
    return out

def geomean(values):
    vals = np.array([v for v in np.ravel(values) if v > 0 and np.isfinite(v)], dtype=float)
    return float(np.exp(np.mean(np.log(vals)))) if len(vals) else np.nan


# -----------------------------
# Parsing helpers
# -----------------------------
def parse_sniper(base_dir):
    """
    Walk output_* folders, read summary.csv and energy_bounds.csv,
    merge them on (benchmark, config). Return a tidy DataFrame.
    Besides the core columns, we opportunistically keep LLC event counters
    (e.g., l3/llc accesses, hits/misses, reads/writes) if they exist.
    """
    energy_rows = []
    summary_rows = []
    print(f"--- Parsing Sniper results from: {base_dir} ---")
    for root, _, files in os.walk(base_dir):
        if os.path.basename(root).startswith("output_") and "summary.csv" in files and "energy_bounds.csv" in files:
            energy_path  = os.path.join(root, "energy_bounds.csv")
            summary_path = os.path.join(root, "summary.csv")

            e = pd.read_csv(energy_path)
            s = pd.read_csv(summary_path)

            # Keep columns we actually use from energy
            e_keep = [
                "benchmark", "config", "time_s",
                "energy_exact_J", "leak_J", "dyn_exact_nJ"
            ]
            e = e[[c for c in e_keep if c in e.columns]].copy()

            # Base columns we want from summary
            s_base = ["benchmark", "config", "ipc", "time_ns", "l3_miss_rate_pct"]
            keep_s = [c for c in s_base if c in s.columns]

            # Try to keep any plausible LLC event columns automatically
            # (we won't fail if they're absent)
            for col in s.columns:
                cl = col.lower()
                if ("l3" in cl or "llc" in cl) and (
                    "access" in cl or "read" in cl or "write" in cl or "hit" in cl or "miss" in cl or "evict" in cl
                ):
                    if col not in keep_s:
                        keep_s.append(col)

            s = s[keep_s].copy()

            # Numeric coercion
            for col in ["time_s", "energy_exact_J", "leak_J", "dyn_exact_nJ"]:
                if col in e.columns:
                    e[col] = pd.to_numeric(e[col], errors="coerce")

            for col in s.columns:
                if col not in ("benchmark", "config"):
                    s[col] = pd.to_numeric(s[col], errors="coerce")

            # Convert nJ -> J
            if "dyn_exact_nJ" in e.columns:
                e["dyn_exact_J"] = e["dyn_exact_nJ"] * 1e-9

            energy_rows.append(e)
            summary_rows.append(s)

    if not energy_rows or not summary_rows:
        raise FileNotFoundError(
            "Could not find summary.csv and energy_bounds.csv in output_* directories under: " + base_dir
        )

    E = pd.concat(energy_rows, ignore_index=True)
    S = pd.concat(summary_rows, ignore_index=True)

    df = pd.merge(E, S, on=["benchmark", "config"], how="inner")

    # minimal sanity
    df = df.dropna(subset=["benchmark", "config", "time_s", "energy_exact_J"])
    print(f"Sniper parse complete. Merged DataFrame shape: {df.shape}")
    print(f"Sniper columns found: {df.columns.tolist()}")
    print("-" * 20)
    return df


def _kv_from_line(s: str) -> dict:
    """Extract numeric key=value pairs from one rwstats line. 'scope' handled separately."""
    kv = {}
    m = re.search(r"\bscope=(\w+)", s)
    if m:
        kv["scope"] = m.group(1)

    for k, v in re.findall(r"([A-Za-z0-9_]+)=([+\-]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+\-]?\d+)?|nan)", s):
        try:
            kv[k] = float("nan") if v.lower() == "nan" else float(v)
        except Exception:
            pass
    return kv


def parse_dynamorio(logs_dir, ts_prefix):
    """
    Parse DynamoRIO log files. For each file, grab the LAST stats-like line
    (lines contain 'scope='). File name format: {ts_prefix}_<benchmark>_instr.rwstats.log
    """
    rows = []
    print(f"\n--- Parsing DynamoRIO logs from: {logs_dir} with prefix '{ts_prefix}' ---")
    if not os.path.isdir(logs_dir):
        print("DynamoRIO logs directory not found. Returning empty DataFrame.")
        print("-" * 20)
        return pd.DataFrame()

    found_files = 0
    for fname in os.listdir(logs_dir):
        if not (fname.startswith(ts_prefix) and fname.endswith("_instr.rwstats.log")):
            continue
        m = re.match(rf"{re.escape(ts_prefix)}_(.+?)_instr\.rwstats\.log$", fname)
        if not m:
            continue
        
        found_files += 1
        benchmark = m.group(1)
        fpath = os.path.join(logs_dir, fname)

        last = None
        with open(fpath, "r", errors="ignore") as f:
            for line in f:
                t = line.strip()
                if "scope=" in t and "=" in t:
                    last = t

        if not last:
            continue

        kv = _kv_from_line(last)
        kv["benchmark"] = benchmark
        rows.append(kv)

    print(f"Found and processed {found_files} matching log files.")
    df = pd.DataFrame(rows) if rows else pd.DataFrame()
    if not df.empty:
        print(f"DynamoRIO parse complete. DataFrame shape: {df.shape}")
        print(f"DynamoRIO columns found: {df.columns.tolist()}")
    else:
        print("DynamoRIO parse complete. No data found, returning empty DataFrame.")
    print("-" * 20)
    return df


# -----------------------------
# Event detection (for per-event view)
# -----------------------------
def detect_llc_events_per_config(df_config):
    """
    Best-effort extraction of an LLC event count from Sniper summary columns
    for a (benchmark-indexed, single-config) DataFrame.
    Priority:
      1) total 'llc_accesses' or 'l3_accesses'
      2) sum of reads+writes
      3) sum of hits+misses
    Returns: pd.Series (index=benchmark) or None if nothing found.
    """
    if df_config is None or df_config.empty:
        return None

    cols = {c.lower(): c for c in df_config.columns}

    # 1) Direct totals
    for key in ["llc_accesses", "l3_accesses", "roi_llc_accesses", "roi_l3_accesses"]:
        if key in cols:
            ser = pd.to_numeric(df_config[cols[key]], errors="coerce")
            if ser.notna().any():
                print(f"[Event Detection] Found total LLC events using column: '{cols[key]}'")
                return ser

    # 2) Reads + writes
    read_keys  = [k for k in cols if ("read"  in k or "rd_" in k) and ("l3" in k or "llc" in k)]
    write_keys = [k for k in cols if ("write" in k or "wr_" in k) and ("l3" in k or "llc" in k)]
    if read_keys and write_keys:
        # choose the most populated pair
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for rk in read_keys:
            for wk in write_keys:
                s = pd.to_numeric(df_config[cols[rk]], errors="coerce") + pd.to_numeric(df_config[cols[wk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[rk], cols[wk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing reads+writes: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    # 3) Hits + misses
    hit_keys   = [k for k in cols if ("hit"   in k) and ("l3" in k or "llc" in k)]
    miss_keys  = [k for k in cols if ("miss"  in k) and ("l3" in k or "llc" in k)]
    if hit_keys and miss_keys:
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for hk in hit_keys:
            for mk in miss_keys:
                s = pd.to_numeric(df_config[cols[hk]], errors="coerce") + pd.to_numeric(df_config[cols[mk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[hk], cols[mk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing hits+misses: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    print("[Event Detection] No suitable LLC event columns found.")
    return None


def build_mem_instruction_counts(dr_df, benchmarks):
    """
    From DynamoRIO, create a per-benchmark count of memory instructions
    (reads + writes). Returns (Series or None).
    """
    if dr_df is None or dr_df.empty:
        return None

    dr = dr_df.set_index("benchmark")
    read_col  = None
    write_col = None

    # common column names
    for cand in ["read_total", "loads", "ld_total", "mem_reads"]:
        if cand in dr.columns:
            read_col = cand
            break
    for cand in ["write_total", "stores", "st_total", "mem_writes"]:
        if cand in dr.columns:
            write_col = cand
            break

    if read_col is None or write_col is None:
        print("[Mem Instr] Could not find read/write total columns in DynamoRIO data.")
        return None

    print(f"[Mem Instr] Calculating memory instructions from DR columns: '{read_col}' + '{write_col}'")
    mem = pd.to_numeric(dr[read_col], errors="coerce") + pd.to_numeric(dr[write_col], errors="coerce")
    mem = mem.reindex(benchmarks)
    if mem.notna().any():
        return mem
    return None


# -----------------------------
# Plot helpers
# -----------------------------
def grouped_barh(ax, labels, a_values, b_values, a_label, b_label, title, x_label):
    y = np.arange(len(labels))
    h = 0.38
    ax.barh(y - h/2, a_values, height=h, label=a_label)
    ax.barh(y + h/2, b_values, height=h, label=b_label)
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()  # top item at top
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)

def corr_heatmap(ax, matrix, row_labels, col_labels, title):
    im = ax.imshow(matrix, aspect="auto", vmin=-1, vmax=1, cmap="coolwarm")
    ax.set_yticks(np.arange(len(row_labels)))
    ax.set_yticklabels(row_labels)
    ax.set_xticks(np.arange(len(col_labels)))
    ax.set_xticklabels(col_labels, rotation=90)
    ax.set_title(title, fontsize=11)
    # annotate
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            val = matrix[i, j]
            ax.text(
                j, i, f"{val:.2f}",
                ha="center", va="center",
                color="white" if abs(val) > 0.6 else "black",
                fontsize=8
            )
    return im

def stacked_barh(ax, labels, data, category_labels, title, x_label):
    y = np.arange(len(labels))
    left = np.zeros(len(labels))
    for i, category in enumerate(data.keys()):
        values = data[category]
        ax.barh(y, values, left=left, label=category_labels[i], height=0.6)
        left += values
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)


# -----------------------------
# Main
# -----------------------------
def main():
    out_dir = os.getcwd()

    # Load data
    sniper = parse_sniper(SNIPER_RESULTS_DIR)
    dr = parse_dynamorio(DYNAMORIO_LOGS_DIR, TIMESTAMP_PREFIX)

    # Save raw inputs (handy for inspection)
    sniper.to_csv(os.path.join(out_dir, "sniper_raw.csv"), index=False)
    if not dr.empty:
        dr.to_csv(os.path.join(out_dir, "dynamorio_raw.csv"), index=False)

    print("\n--- Processing and Filtering Data ---")
    # Focus on benchmarks present in BOTH SRAM and JanS
    sram = sniper[sniper["config"] == "SRAM"].set_index("benchmark")
    jans = sniper[sniper["config"] == "JanS"].set_index("benchmark")
    common = sram.index.intersection(jans.index)
    if len(common) == 0:
        raise RuntimeError("No common benchmarks between SRAM and JanS.")
    
    print(f"Found {len(common)} common benchmarks between SRAM and JanS configs: {common.tolist()}")

    sram = sram.loc[common].copy()
    jans = jans.loc[common].copy()

    # Sort by SRAM execution time to keep labels readable
    order = sram.sort_values("time_s").index.tolist()
    sram = sram.loc[order]
    jans = jans.loc[order]
    labels = order
    
    print("Sorted benchmarks by SRAM execution time:", labels)
    print("\n--- SRAM Data (head) ---")
    print(sram.head())
    print("\n--- JanS Data (head) ---")
    print(jans.head())
    print("-" * 20)

    # ---------------- Sniper comparisons (compact 2x2) ----------------
    plt.rcParams.update({
        "figure.figsize": (11, 8),
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "xtick.labelsize": 8,
        "ytick.labelsize": 8
    })
    fig, axs = plt.subplots(2, 2)

    # 1) Execution time (s)
    grouped_barh(
        axs[0, 0], labels,
        sram["time_s"].values, jans["time_s"].values,
        "SRAM", "JanS",
        "Execution Time", "seconds"
    )

    # 2) Total LLC energy (J)
    grouped_barh(
        axs[0, 1], labels,
        sram["energy_exact_J"].values, jans["energy_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (total)", "Joules"
    )

    # 3) Dynamic LLC energy (J)
    grouped_barh(
        axs[1, 0], labels,
        sram["dyn_exact_J"].values, jans["dyn_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (dynamic only)", "Joules"
    )

    # 4) Leakage LLC energy (J)
    grouped_barh(
        axs[1, 1], labels,
        sram["leak_J"].values, jans["leak_J"].values,
        "SRAM", "JanS",
        "LLC Energy (leakage only)", "Joules"
    )

    fig.suptitle("SRAM vs JanS — Timing and Energy (per benchmark)", fontsize=12, y=0.99)
    fig.tight_layout(rect=[0, 0, 1, 0.97])

    # ------------------ Figure: Normalized Performance Summary ------------------
    norm = pd.DataFrame(index=order)
    norm["norm_time"]   = safe_div(jans["time_s"], sram["time_s"])
    norm["norm_energy"] = safe_div(jans["energy_exact_J"], sram["energy_exact_J"])
    
    print("\n--- Normalized Data (JanS / SRAM) ---")
    print(norm)
    print("-" * 20)

    fig2, axs2 = plt.subplots(2, 2, figsize=(11, 8))

    # 1) Normalized Execution Time
    axs2[0, 0].bar(norm.index, norm["norm_time"])
    axs2[0, 0].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 0].set_title("Normalized Execution Time (JanS / SRAM)", fontsize=11)
    axs2[0, 0].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 0].grid(True, axis="y", linestyle=":")

    # 2) Normalized Total LLC Energy
    axs2[0, 1].bar(norm.index, norm["norm_energy"])
    axs2[0, 1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 1].set_title("Normalized Total LLC Energy (JanS / SRAM)", fontsize=11)
    axs2[0, 1].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 1].grid(True, axis="y", linestyle=":")

    # 3) Absolute IPC
    x = np.arange(len(labels))
    width = 0.35
    axs2[1, 0].bar(x - width/2, sram["ipc"], width, label='SRAM')
    axs2[1, 0].bar(x + width/2, jans["ipc"], width, label='JanS')
    axs2[1, 0].set_title("Instructions Per Cycle (IPC)", fontsize=11)
    axs2[1, 0].set_ylabel("IPC (Higher is Better)", fontsize=10)
    axs2[1, 0].legend(fontsize=8, frameon=False)

    # 4) L3 Miss Rate (%)
    if "l3_miss_rate_pct" in sram.columns and "l3_miss_rate_pct" in jans.columns:
        axs2[1, 1].bar(x - width/2, sram["l3_miss_rate_pct"], width, label='SRAM')
        axs2[1, 1].bar(x + width/2, jans["l3_miss_rate_pct"], width, label='JanS')
        axs2[1, 1].set_title("L3 Miss Rate", fontsize=11)
        axs2[1, 1].set_ylabel("Miss Rate (%)", fontsize=10)
        axs2[1, 1].legend(fontsize=8, frameon=False)
    else:
        axs2[1, 1].axis("off")

    for ax in axs2.flatten():
        ax.set_xticks(np.arange(len(labels)))
        ax.set_xticklabels(labels, rotation=90)
        ax.tick_params(axis="x", labelsize=8)

    # Geomeans for headline
    gm_time   = geomean(norm["norm_time"])
    gm_energy = geomean(norm["norm_energy"])
    fig2.suptitle(f"Performance & Cache Metrics: SRAM vs. JanS — GeoMeans (JanS/SRAM): "
                  f"time={gm_time:.3f}, energy={gm_energy:.3f}",
                  fontsize=13, y=0.99)
    fig2.tight_layout(rect=[0, 0, 1, 0.96])

    # ------------------ Figure: LLC Energy Breakdown ------------------
    fig_e, axs_e = plt.subplots(1, 2, figsize=(11, 5), sharex=True)
    sram_energy_data = {'Dynamic': sram["dyn_exact_J"], 'Leakage': sram["leak_J"]}
    jans_energy_data = {'Dynamic': jans["dyn_exact_J"], 'Leakage': jans["leak_J"]}

    stacked_barh(axs_e[0], labels, sram_energy_data, ['Dynamic', 'Leakage'], "SRAM LLC Energy Breakdown", "Joules")
    stacked_barh(axs_e[1], labels, jans_energy_data, ['Dynamic', 'Leakage'], "JanS LLC Energy Breakdown", "Joules")

    fig_e.suptitle("LLC Energy Composition: Dynamic vs. Leakage", fontsize=13, y=0.99)
    fig_e.tight_layout(rect=[0, 0, 1, 0.94])

    # ---------------- Mechanism View: Dynamic energy per event ----------------
    print("\n--- Calculating Dynamic Energy per Event ---")
    # Try to use *LLC event counts* from Sniper; if unavailable, fall back to *memory instructions* from DynamoRIO.
    per_event_mode = None  # "llc" or "mem"
    sram_denom = detect_llc_events_per_config(sram)
    jans_denom = detect_llc_events_per_config(jans)

    if sram_denom is not None and jans_denom is not None:
        per_event_mode = "llc"
        sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, sram_denom)
        jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, jans_denom)
        denom_label = "LLC event"
    else:
        mem_instr = build_mem_instruction_counts(dr, labels)
        if mem_instr is not None and np.nanmax(mem_instr.values) > 0:
            per_event_mode = "mem"
            # Same denominator for both configs (program-level memory instruction count)
            sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            denom_label = "memory instruction"
        else:
            per_event_mode = None
    
    print(f"Per-event mode chosen: '{per_event_mode}'")
    if per_event_mode:
        print(f"Denominator label: '{denom_label}'")
    print("-" * 20)

    if per_event_mode is not None:
        fig_pe, axs_pe = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(
            axs_pe[0], labels,
            sram_pJ, jans_pJ,
            "SRAM", "JanS",
            f"Dynamic LLC Energy per {denom_label}", f"pJ / {denom_label}"
        )
        ratio = safe_div(jans_pJ, sram_pJ)
        x = np.arange(len(labels))
        axs_pe[1].bar(x, ratio)
        axs_pe[1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
        axs_pe[1].set_title(f"Normalized pJ/{denom_label} (JanS / SRAM)")
        axs_pe[1].set_ylabel("Ratio (Lower is Better)")
        axs_pe[1].set_xticks(x)
        axs_pe[1].set_xticklabels(labels, rotation=90)
        axs_pe[1].grid(True, axis="y", linestyle=":")

        gm_pe = geomean(ratio)
        fig_pe.suptitle(
            f"Mechanism: Dynamic Energy per {denom_label} — Geomean (JanS/SRAM) = {gm_pe:.3f}",
            fontsize=13, y=0.99
        )
        fig_pe.tight_layout(rect=[0, 0, 1, 0.94])

        # Save CSV of the per-event metrics
        per_event_df = pd.DataFrame({
            "benchmark": labels,
            "SRAM_dyn_pJ_per_"+denom_label: sram_pJ,
            "JanS_dyn_pJ_per_"+denom_label: jans_pJ,
            "JanS_over_SRAM_pJ_per_"+denom_label: ratio
        }).set_index("benchmark")
        # Add denominators for transparency
        if per_event_mode == "llc":
            per_event_df["SRAM_"+denom_label+"s"] = sram_denom.reindex(labels).values
            per_event_df["JanS_"+denom_label+"s"] = jans_denom.reindex(labels).values
        else:
            per_event_df[denom_label+"s"] = build_mem_instruction_counts(dr, labels).reindex(labels).values
        
        print("\n--- Per-Event Dynamic Energy Data ---")
        print(per_event_df)
        print("-" * 20)
        per_event_df.to_csv(os.path.join(out_dir, "per_event_dynamic_energy.csv"))

    # ---------------- Correlation: DynamoRIO features vs totals / gains ----------------
    if not dr.empty:
        print("\n--- Building Correlation Matrix Data ---")
        feat_map = {
            "rtotal":     "read_total",
            "runique":    "read_unique",
            "90%f_tr":    "read_footprint90L",   # global, line-level
            "Hrg":        "read_entropy",
            "Hrl":        "read_local_entropy",
            "wtotal":     "write_total",
            "wunique":    "write_unique",
            "90%f_tw":    "write_footprint90L",  # global, line-level
            "Hwg":        "write_entropy",
            "Hwl":        "write_local_entropy",
        }

        feats = pd.DataFrame({"benchmark": dr["benchmark"]})
        for out_name, src in feat_map.items():
            feats[out_name] = pd.to_numeric(dr.get(src), errors="coerce")
        feats = feats.set_index("benchmark")

        # Targets (SRAM absolute) and normalized gains
        targets_sram = sram[["time_s", "energy_exact_J", "dyn_exact_J", "ipc"]].copy()
        if "l3_miss_rate_pct" in sram.columns:
            targets_sram["L3_miss%"] = sram["l3_miss_rate_pct"]
        targets_sram = targets_sram.rename(columns={
            "time_s": "exe_time", "energy_exact_J": "LLC_energy", "dyn_exact_J": "Dyn_energy", "ipc": "IPC"
        })

        corr_df = feats.join(targets_sram, how="inner").join(norm[["norm_time", "norm_energy"]], how="inner")

        # If per-event dynamic energy exists, add one column (SRAM) and one ratio
        if per_event_mode is not None:
            corr_label_abs = f"pJ/{denom_label} (SRAM)"
            corr_label_norm = f"norm_pJ/{denom_label} (JanS/SRAM)"
            corr_df[corr_label_abs] = pd.Series(sram_pJ, index=labels)
            corr_df[corr_label_norm] = pd.Series(safe_div(jans_pJ, sram_pJ), index=labels)

        print("Correlation DataFrame (head):")
        print(corr_df.head())
        print("-" * 20)

        feature_names = [k for k in feat_map.keys() if k in corr_df.columns and not corr_df[k].isna().all()]
        abs_cols = [c for c in ["exe_time", "LLC_energy", "Dyn_energy", "IPC", "L3_miss%",] if c in corr_df.columns and not corr_df[c].isna().all()]
        norm_cols = [c for c in ["norm_time", "norm_energy"] if c in corr_df.columns and not corr_df[c].isna().all()]
        extra_cols = []
        if per_event_mode is not None:
            for c in [corr_label_abs, corr_label_norm]:
                if c in corr_df.columns and not corr_df[c].isna().all():
                    extra_cols.append(c)

        if feature_names and (abs_cols or norm_cols or extra_cols) and len(corr_df.dropna(how="all")) >= 2:
            n_panels = 2 if extra_cols else 2
            fig_c, axs_c = plt.subplots(1, 2, figsize=(9, 5))

            # Features vs. SRAM absolute metrics
            if abs_cols:
                C1 = corr_df[feature_names + abs_cols].corr().loc[feature_names, abs_cols].values
                corr_heatmap(axs_c[0], C1, feature_names, abs_cols, "Features vs. SRAM Totals")
            else:
                axs_c[0].axis("off")

            # Features vs. normalized gains (+ optional per-event targets)
            cols2 = norm_cols + extra_cols
            if cols2:
                C2 = corr_df[feature_names + cols2].corr().loc[feature_names, cols2].values
                corr_heatmap(axs_c[1], C2, feature_names, cols2, "Features vs. Gains / Per-Event")
            else:
                axs_c[1].axis("off")
            
            fig_c.suptitle("Correlation: Memory Features ↔ Totals & Gains", fontsize=13, y=0.99)
            fig_c.tight_layout(rect=[0, 0, 1, 0.92])
        else:
            print("Not enough data for correlation heatmaps (missing features/targets or too few benchmarks).")
    else:
        print("DynamoRIO features unavailable — skipping correlation plots.")

    # -------- Save headline geomeans --------
    geomean_df = pd.DataFrame({
        "metric": ["time (JanS/SRAM)", "total LLC energy (JanS/SRAM)"],
        "geomean_ratio": [gm_time, gm_energy],
    })
    print("\n--- Geomean Summary ---")
    print(geomean_df)
    print("-" * 20)
    geomean_df.to_csv(os.path.join(out_dir, "geomean_summary.csv"), index=False)

    #########################################
    
    print("\n--- Additional System-Level Analysis (Power & EDP) ---")
    sys = pd.DataFrame({
        "benchmark": labels,
        "SRAM_time_s": sram["time_s"].values,
        "JanS_time_s": jans["time_s"].values,
        "SRAM_energy_J": sram["energy_exact_J"].values,
        "JanS_energy_J": jans["energy_exact_J"].values,
        "SRAM_dyn_W": safe_div(sram["dyn_exact_J"].values, sram["time_s"].values),
        "JanS_dyn_W": safe_div(jans["dyn_exact_J"].values, jans["time_s"].values),
        "SRAM_leak_W": safe_div(sram["leak_J"].values, sram["time_s"].values),
        "JanS_leak_W": safe_div(jans["leak_J"].values, jans["time_s"].values),
    }).set_index("benchmark")
    sys["SRAM_EDP"] = sys["SRAM_energy_J"] * sys["SRAM_time_s"]
    sys["JanS_EDP"] = sys["JanS_energy_J"] * sys["JanS_time_s"]

    print("System-level metrics (head):")
    print(sys.head())
    print("-" * 20)
    
    fig_sys, axs_sys = plt.subplots(1, 3, figsize=(14, 5))
    grouped_barh(axs_sys[0], labels,
                 sys["SRAM_dyn_W"].values, sys["JanS_dyn_W"].values,
                 "SRAM","JanS","Dynamic Power (LLC)","Watts")
    grouped_barh(axs_sys[1], labels,
                 sys["SRAM_leak_W"].values, sys["JanS_leak_W"].values,
                 "SRAM","JanS","Leakage Power (LLC)","Watts")

    x = np.arange(len(labels))
    edp_ratio = safe_div(sys["JanS_EDP"].values, sys["SRAM_EDP"].values)
    axs_sys[2].bar(x, edp_ratio)
    axs_sys[2].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
    axs_sys[2].set_xticks(x)
    axs_sys[2].set_xticklabels(labels, rotation=90)
    axs_sys[2].set_ylabel("Ratio (Lower is Better)")
    axs_sys[2].set_title("EDP (JanS / SRAM)")
    fig_sys.suptitle("System Power & EDP", fontsize=13, y=0.99)
    fig_sys.tight_layout(rect=[0,0,1,0.94])

    # -- B) Per-miss dynamic energy (best-effort) -----------------------------
    def _approx_misses(df_config, total_series):
        if total_series is None or "l3_miss_rate_pct" not in df_config.columns:
            return None
        total = pd.to_numeric(total_series.reindex(df_config.index), errors="coerce")
        miss_rate = pd.to_numeric(df_config["l3_miss_rate_pct"], errors="coerce") / 100.0
        misses = total * miss_rate
        return misses if misses.notna().any() else None

    sram_total = detect_llc_events_per_config(sram)
    jans_total = detect_llc_events_per_config(jans)
    sram_misses = _approx_misses(sram, sram_total) if sram_total is not None else None
    jans_misses = _approx_misses(jans, jans_total) if jans_total is not None else None

    if sram_misses is not None and jans_misses is not None:
        print("\n--- Per-Miss Dynamic Energy Analysis ---")
        pJmiss_s = safe_div(sram["dyn_exact_J"].values * 1e12, sram_misses.reindex(labels).values)
        pJmiss_j = safe_div(jans["dyn_exact_J"].values * 1e12, jans_misses.reindex(labels).values)
        r_pm = safe_div(pJmiss_j, pJmiss_s)

        pm_df = pd.DataFrame({
            'sram_misses_approx': sram_misses,
            'jans_misses_approx': jans_misses,
            'sram_pJ_per_miss': pJmiss_s,
            'jans_pJ_per_miss': pJmiss_j,
            'ratio_pJ_per_miss': r_pm
        }, index=labels)
        print("Per-miss energy data (head):")
        print(pm_df.head())
        print("-" * 20)

        fig_pm, axs_pm = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(axs_pm[0], labels, pJmiss_s, pJmiss_j,
                     "SRAM","JanS","Dynamic Energy per L3 Miss","pJ / miss")

        axs_pm[1].bar(x, r_pm)
        axs_pm[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
        axs_pm[1].set_xticks(x)
        axs_pm[1].set_xticklabels(labels, rotation=90)
        axs_pm[1].set_ylabel("Ratio (Lower is Better)")
        axs_pm[1].set_title("pJ/miss (JanS / SRAM)")
        fig_pm.suptitle("Per-Miss Dynamic Energy (approx. via miss_rate × total L3/LLC)", y=0.99)
        fig_pm.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[per-miss] Skipped: need total L3/LLC events + l3_miss_rate_pct in summary.csv.")

    # -- C) Event-type cost fit (pJ per event) -------------------------------
    # Estimate costs for {read_hit, read_miss, write_hit, write_miss, evict} via least squares, if columns exist.
    def _choose_col(df_config, must_terms, maybes=("l3","llc")):
        best = None; best_pop = -1
        for c in df_config.columns:
            cl = c.lower()
            if all(t in cl for t in must_terms) and any(m in cl for m in maybes):
                ser = pd.to_numeric(df_config[c], errors="coerce")
                pop = ser.notna().sum()
                if pop > best_pop:
                    best, best_pop = c, pop
        return best

    def _find_event_cols(df_config):
        mapping = {
            "read_hit":  ["read","hit"],
            "write_hit": ["write","hit"],
            "read_miss": ["read","miss"],
            "write_miss":["write","miss"],
            "evict":     ["evict"],
        }
        out = {}
        for name, terms in mapping.items():
            col = _choose_col(df_config, terms)
            if col is None and name == "evict":
                col = _choose_col(df_config, ["writeback"]) or _choose_col(df_config, ["wb"])
            if col is not None:
                out[name] = col
        return out

    def _fit_costs(df_config, event_cols):
        if not event_cols:
            return None, None
        X_cols = list(event_cols.values())
        X = np.column_stack([pd.to_numeric(df_config[c], errors="coerce").fillna(0.0).values for c in X_cols])
        y = pd.to_numeric(df_config["dyn_exact_J"], errors="coerce").values
        mask = np.isfinite(y)
        for i in range(X.shape[1]):
            mask &= np.isfinite(X[:, i])
        X, y = X[mask], y[mask]
        if X.shape[0] < len(X_cols):
            return None, None
        beta, residuals, rank, s = np.linalg.lstsq(X, y, rcond=None)
        r2 = 1.0 - ((y - X @ beta)**2).sum() / np.maximum(1e-12, ((y - y.mean())**2).sum())
        return pd.Series(beta * 1e12, index=list(event_cols.keys())), r2  # pJ/event

    sram_event_cols = _find_event_cols(sram)
    jans_event_cols = _find_event_cols(jans)
    coef_s, r2_s = _fit_costs(sram, sram_event_cols)
    coef_j, r2_j = _fit_costs(jans, jans_event_cols)

    if coef_s is not None or coef_j is not None:
        print("\n--- Fitted Event Cost Analysis ---")
        print(f"SRAM event columns used for fit: {sram_event_cols}")
        print(f"JanS event columns used for fit: {jans_event_cols}")
        
        keys = sorted(set([] if coef_s is None else coef_s.index).union([] if coef_j is None else coef_j.index))
        s_vals = np.array([coef_s.get(k, np.nan) if coef_s is not None else np.nan for k in keys])
        j_vals = np.array([coef_j.get(k, np.nan) if coef_j is not None else np.nan for k in keys])

        fit_df = pd.DataFrame({'event_type': keys, 'SRAM_pJ_per_event': s_vals, 'JanS_pJ_per_event': j_vals}).set_index('event_type')
        print("Fitted coefficients (pJ/event):")
        print(fit_df)
        print(f"SRAM R² = {r2_s:.3f}, JanS R² = {r2_j:.3f}")
        print("-" * 20)

        fig_ev, ax_ev = plt.subplots(1, 1, figsize=(10, 4.8))
        xx = np.arange(len(keys)); w = 0.42
        ax_ev.bar(xx - w/2, s_vals, width=w, label="SRAM")
        ax_ev.bar(xx + w/2, j_vals, width=w, label="JanS")
        ax_ev.set_xticks(xx)
        ax_ev.set_xticklabels(keys)
        ax_ev.set_ylabel("pJ / event")
        ax_ev.set_title("Fitted LLC Event Costs")
        ax_ev.grid(True, axis="y", linestyle=":")
        ax_ev.legend(fontsize=8, frameon=False)
        fig_ev.suptitle(f"Event-Cost Fit (least squares) — R² SRAM={r2_s if r2_s is not None else float('nan'):.2f}, JanS={r2_j if r2_j is not None else float('nan'):.2f}", y=0.99)
        fig_ev.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[event-fit] Skipped: insufficient L3/LLC event columns in summary.csv.")

    # -- D) What-if gating rule visualization ---------------------------------
    try:
        if not dr.empty:
            print("\n--- What-if Gating Rule Visualization ---")
            dr_idx = dr.set_index("benchmark")
            rf = pd.to_numeric(dr_idx.get("read_footprint90L"), errors="coerce")
            wf = pd.to_numeric(dr_idx.get("write_footprint90L"), errors="coerce")
            p50s = pd.to_numeric(dr_idx.get("p50_strideB"), errors="coerce")
            rf_thr = np.nanmedian(rf.values); wf_thr = np.nanmedian(wf.values); stride_thr = 512 * 1024
            enable = ((rf >= rf_thr) | (wf >= wf_thr)) & (p50s <= stride_thr)
            enable = enable.reindex(labels).fillna(False)

            print(f"Gating rule: ((read_footprint >= {rf_thr:.1f}) OR (write_footprint >= {wf_thr:.1f})) AND (p50_stride <= {stride_thr})")
            print("Gating decisions (True means enable JanS):")
            print(enable)
            
            chosen_E = np.where(enable.values, jans["energy_exact_J"].values, sram["energy_exact_J"].values)
            chosen_T = np.where(enable.values, jans["time_s"].values,         sram["time_s"].values)
            energy_ratio = safe_div(chosen_E, sram["energy_exact_J"].values)
            time_ratio   = safe_div(chosen_T, sram["time_s"].values)
            print("-" * 20)

            fig_gate, axs_gate = plt.subplots(1, 2, figsize=(12, 5))
            axs_gate[0].bar(x, energy_ratio)
            axs_gate[0].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
            axs_gate[0].set_xticks(x); axs_gate[0].set_xticklabels(labels, rotation=90)
            axs_gate[0].set_ylabel("Ratio vs SRAM"); axs_gate[0].set_title("What-if Energy (rule)")

            axs_gate[1].bar(x, time_ratio)
            axs_gate[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
            axs_gate[1].set_xticks(x); axs_gate[1].set_xticklabels(labels, rotation=90)
            axs_gate[1].set_ylabel("Ratio vs SRAM"); axs_gate[1].set_title("What-if Time (rule)")

            # annotate chosen config under each bar
            for ax in axs_gate:
                ymin, ymax = ax.get_ylim()
                for xi, choose_j in enumerate(enable.values):
                    ax.text(xi, ymin + 0.02*(ymax - ymin),
                            "JanS" if choose_j else "SRAM",
                            rotation=90, ha="center", va="bottom", fontsize=7, alpha=0.75)
            fig_gate.suptitle("Simple Gating Rule Outcome", y=0.99)
            fig_gate.tight_layout(rect=[0,0,1,0.94])
        else:
            print("\n[gating] Skipped: no DynamoRIO features available.")
    except Exception as e:
        print("\n[gating] Error:", e)
    
    #########################################
    
        # ==== PREDICTORS ↔ OUTCOMES: DATA-BACKED CHECK ===========================
    # Build per-access metrics from DR (reads+writes)
    def _mem_accesses_from_dr(dr_df, bench_idx):
        if dr_df is None or dr_df.empty:
            return None
        d = dr_df.set_index("benchmark")
        # prefer "read_total"/"write_total", else common fallbacks
        rc = next((c for c in ["read_total","loads","ld_total","mem_reads"] if c in d.columns), None)
        wc = next((c for c in ["write_total","stores","st_total","mem_writes"] if c in d.columns), None)
        if rc is None or wc is None:
            return None
        mem = pd.to_numeric(d[rc], errors="coerce") + pd.to_numeric(d[wc], errors="coerce")
        return mem.reindex(bench_idx)

    mem = _mem_accesses_from_dr(dr, labels)
    if mem is not None and np.nanmax(mem.values) > 0:
        # Per-access metrics (SRAM & JanS)
        sram_pJ = safe_div(sram["dyn_exact_J"].values * 1e12, mem.values)
        jans_pJ = safe_div(jans["dyn_exact_J"].values * 1e12, mem.values)
        sram_ns = safe_div(sram["time_s"].values * 1e9, mem.values)
        jans_ns = safe_div(jans["time_s"].values * 1e9, mem.values)
        ratio_pJ = safe_div(jans_pJ, sram_pJ)
        ratio_ns = safe_div(jans_ns, sram_ns)

        # Pull DR predictors
        dr_idx = dr.set_index("benchmark")
        feats = pd.DataFrame(index=labels)
        for col in ["read_footprint90L","write_footprint90L","read_local_entropy","write_local_entropy"]:
            feats[col] = pd.to_numeric(dr_idx.get(col), errors="coerce").reindex(labels)

        # Assemble analysis frame
        A = pd.DataFrame({
            "ratio_pJ_per_access": ratio_pJ,
            "ratio_ns_per_access": ratio_ns,
            "sram_pJ_per_access":  sram_pJ,
            "sram_ns_per_access":  sram_ns,
        }, index=labels).join(feats)
        
        print("\n--- Predictor Analysis DataFrame (head) ---")
        print(A.head())
        print("-" * 20)

        def _corr_table(df, Xcols, Ycol):
            rows = []
            for x in Xcols:
                xser = pd.to_numeric(df[x], errors="coerce")
                yser = pd.to_numeric(df[Ycol], errors="coerce")
                if xser.notna().sum() >= 3 and yser.notna().sum() >= 3:
                    r_p = xser.corr(yser, method="pearson")
                    r_s = xser.corr(yser, method="spearman")
                    rows.append([x, r_p, r_s, xser.notna().sum()])
            return pd.DataFrame(rows, columns=["feature","pearson_r","spearman_r","N"]).set_index("feature")

        # Correlations that support the claims
        tab_foot_vs_ratio = _corr_table(A,
            ["read_footprint90L","write_footprint90L"], "ratio_pJ_per_access")
        tab_entropy_vs_sram_ns = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "sram_ns_per_access")
        tab_entropy_vs_sram_pJ = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "sram_pJ_per_access")
        tab_entropy_vs_ratio_ns = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "ratio_ns_per_access")

        print("\n[predictors] JanS/SRAM pJ per access vs 90% footprints:")
        print(tab_foot_vs_ratio.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] SRAM ns/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_sram_ns.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] SRAM pJ/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_sram_pJ.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] JanS/SRAM ns/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_ratio_ns.to_string(float_format=lambda v: f"{v: .3f}"))

        # Save CSV summary
        corr_out = (tab_foot_vs_ratio.assign(target="ratio_pJ/access")
                    .append(tab_entropy_vs_sram_ns.assign(target="sram_ns/access"))
                    .append(tab_entropy_vs_sram_pJ.assign(target="sram_pJ/access"))
                    .append(tab_entropy_vs_ratio_ns.assign(target="ratio_ns/access")))
        corr_out.to_csv(os.path.join(out_dir, "predictors_correlations.csv"))

        # --- Plots: clean and compact ---------------------------------------
        # 1) ratio pJ/access vs footprints
        fig_pf, axs_pf = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_pf,
            ["read_footprint90L","write_footprint90L"],
            ["JanS/SRAM pJ/access vs Read 90%Footprint (lines)",
             "JanS/SRAM pJ/access vs Write 90%Footprint (lines)"]
        ):
            x = A[col].values; y = A["ratio_pJ_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            # OLS line (best fit)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("lines"); 
        axs_pf[0].set_ylabel("JanS/SRAM pJ per access")
        fig_pf.tight_layout()

        # 2) SRAM per-access latency vs local entropies
        fig_he, axs_he = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_he,
            ["read_local_entropy","write_local_entropy"],
            ["SRAM ns/access vs Hrl","SRAM ns/access vs Hwl"]
        ):
            x = A[col].values; y = A["sram_ns_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("entropy (bits)"); 
        axs_he[0].set_ylabel("SRAM ns per access")
        fig_he.tight_layout()

        # 3) JanS/SRAM ns/access vs local entropies (to show 'little latency benefit')
        fig_ln, axs_ln = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_ln,
            ["read_local_entropy","write_local_entropy"],
            ["JanS/SRAM ns/access vs Hrl","JanS/SRAM ns/access vs Hwl"]
        ):
            x = A[col].values; y = A["ratio_ns_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("entropy (bits)"); 
        axs_ln[0].set_ylabel("JanS/SRAM ns per access")
        fig_ln.tight_layout()
    else:
        print("\n[predictors] Skipped: missing DR read/write totals to build per-access metrics.")
    # ==== END PREDICTORS CHECK ===============================================

    
    print("\n--- Displaying all generated plots ---")
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 22
#      10 # -----------------------------
#      11 # Absolute paths (edit if needed)
#      12 # -----------------------------
#      13 RUN_IDS = {
#      14     "Baseline (JanS, 2MB, 16 Way)": "sniper_roi1000_fixedcap2m_20250927T171235Z",
#      15     "JanS, 2MB, 8 Way": "sniper_assoc_jans2mb_8way_20250929T024544Z",
#    (...)
#      20     "XueS, 2MB, 16 Way": "sniper_dev_xues_2mb_20250929T024537Z"
#      21 }
# ---> 22 SNIPER_RESULTS_DIR= f"/home/skataoka26/COSC_498/miniMXE/results/{RUN_IDS['JanS, 2MB, 16 Way']}"
#      23 DYNAMORIO_LOGS_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
#      24 TIMESTAMP_PREFIX    = "20250929T203551Z"  # prefix used in DynamoRIO filenames
#
# KeyError: 'JanS, 2MB, 16 Way'

# %%
#!/usr/bin/env python3

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Absolute paths (edit if needed)
# -----------------------------
RUN_IDS = {
    "Baseline (JanS, 2MB, 16 Way)": "sniper_roi1000_fixedcap2m_20250927T171235Z",
    "JanS, 2MB, 8 Way": "sniper_assoc_jans2mb_8way_20250929T024544Z",
    "JanS, 16MB, 16 Way": "sniper_cap_equal_16mb_20250929T024544Z",
    "JanS, 32MB, 16 Way": "sniper_cap_equal_32mb_20250929T024544Z",
    "ChungS, 2MB, 16 Way": "sniper_dev_chungs_2mb_20250929T024350Z",
    "UmekiS, 2MB, 16 Way": "sniper_dev_umekis_2mb_20250929T024536Z",
    "XueS, 2MB, 16 Way": "sniper_dev_xues_2mb_20250929T024537Z"
}
SNIPER_RESULTS_DIR= f"/home/skataoka26/COSC_498/miniMXE/results/{RUN_IDS['Baseline (JanS, 2MB, 16 Way)']}"
# sniper_llc_2mb_16w_20251002T020032Z
SNIPER_RESULTS_DIR= "/home/skataoka26/COSC_498/miniMXE/results/sniper_llc_2mb_16w_20251002T020032Z"
DYNAMORIO_LOGS_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
TIMESTAMP_PREFIX    = "20250929T203551Z"  # prefix used in DynamoRIO filenames

# -----------------------------
# Utilities
# -----------------------------
def safe_div(numer, denom):
    numer = np.array(numer, dtype=float)
    denom = np.array(denom, dtype=float)
    with np.errstate(divide='ignore', invalid='ignore'):
        out = np.where((denom > 0) & np.isfinite(denom), numer / denom, np.nan)
    return out

def geomean(values):
    vals = np.array([v for v in np.ravel(values) if v > 0 and np.isfinite(v)], dtype=float)
    return float(np.exp(np.mean(np.log(vals)))) if len(vals) else np.nan

# --- NEW: statistics helpers for bootstrap / partial correlations / LOO stability
def bootstrap_spearman_ci(x, y, n_boot=10000, alpha=0.05, random_state=0):
    """
    Compute Spearman correlation and bootstrap percentile CI.
    x,y: 1-D arrays (can contain nans).
    Returns (observed_spearman, lower, upper, n_obs)
    """
    rng = np.random.default_rng(random_state)
    mask = np.isfinite(x) & np.isfinite(y)
    x0 = np.array(x)[mask]
    y0 = np.array(y)[mask]
    n = len(x0)
    if n < 3:
        return (np.nan, np.nan, np.nan, n)
    # observed
    obs = pd.Series(x0).corr(pd.Series(y0), method="spearman")
    # bootstrap
    boots = []
    for _ in range(n_boot):
        idx = rng.integers(0, n, n)
        xi = x0[idx]
        yi = y0[idx]
        # if all equal or constant, result may be nan; skip those
        try:
            r = pd.Series(xi).corr(pd.Series(yi), method="spearman")
        except Exception:
            r = np.nan
        boots.append(r)
    boots = np.array([b for b in boots if np.isfinite(b)])
    if boots.size == 0:
        return (obs, np.nan, np.nan, n)
    lo = np.percentile(boots, 100 * alpha / 2.0)
    hi = np.percentile(boots, 100 * (1 - alpha/2.0))
    return (obs, lo, hi, n)

def partial_corr_pearson(x, y, controls):
    """
    Partial Pearson correlation between x and y controlling for columns in controls (2D array or DataFrame).
    Uses residualization (OLS).
    Returns Pearson r and N used.
    """
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)
    if isinstance(controls, pd.DataFrame):
        C = controls.values.astype(float)
    else:
        C = np.asarray(controls, dtype=float)
    mask = np.isfinite(x) & np.isfinite(y) & np.all(np.isfinite(C), axis=1)
    x0 = x[mask]; y0 = y[mask]; C0 = C[mask]
    if len(x0) < 3:
        return (np.nan, len(x0))
    # Add intercept
    Xc = np.column_stack([np.ones(len(C0)), C0])
    # regress x on controls
    beta_x, *_ = np.linalg.lstsq(Xc, x0, rcond=None)
    resid_x = x0 - Xc.dot(beta_x)
    beta_y, *_ = np.linalg.lstsq(Xc, y0, rcond=None)
    resid_y = y0 - Xc.dot(beta_y)
    r = np.corrcoef(resid_x, resid_y)[0,1]
    return (r, len(x0))

def loo_regression_stability(y, X):
    """
    Leave-one-out coefficient stability for linear regression of y ~ X (no intercept automatically added).
    Returns dict with 'coefs' array shape (n_points, n_features), and 'mean_coef', 'std_coef'
    We add intercept inside.
    """
    y = np.asarray(y, dtype=float)
    X = np.asarray(X, dtype=float)
    n = len(y)
    if n < 3 or X.shape[0] != n:
        return None
    coefs = []
    for i in range(n):
        mask = np.ones(n, dtype=bool)
        mask[i] = False
        Xi = X[mask]; yi = y[mask]
        Xi2 = np.column_stack([np.ones(Xi.shape[0]), Xi])
        try:
            beta, *_ = np.linalg.lstsq(Xi2, yi, rcond=None)
            coefs.append(beta)  # intercept + coefs
        except Exception:
            coefs.append(np.full(Xi2.shape[1], np.nan))
    coefs = np.vstack(coefs)
    return {
        "coefs": coefs,
        "mean_coef": np.nanmean(coefs, axis=0),
        "std_coef": np.nanstd(coefs, axis=0)
    }

# -----------------------------
# Parsing helpers
# -----------------------------
def parse_sniper(base_dir):
    """
    Walk output_* folders, read summary.csv and energy_bounds.csv,
    merge them on (benchmark, config). Return a tidy DataFrame.
    Besides the core columns, we opportunistically keep LLC event counters
    (e.g., l3/llc accesses, hits/misses, reads/writes) if they exist.
    """
    energy_rows = []
    summary_rows = []
    print(f"--- Parsing Sniper results from: {base_dir} ---")
    for root, _, files in os.walk(base_dir):
        if os.path.basename(root).startswith("output_") and "summary.csv" in files and "energy_bounds.csv" in files:
            energy_path  = os.path.join(root, "energy_bounds.csv")
            summary_path = os.path.join(root, "summary.csv")

            e = pd.read_csv(energy_path)
            s = pd.read_csv(summary_path)

            # Keep columns we actually use from energy
            e_keep = [
                "benchmark", "config", "time_s",
                "energy_exact_J", "leak_J", "dyn_exact_nJ"
            ]
            e = e[[c for c in e_keep if c in e.columns]].copy()

            # Base columns we want from summary
            s_base = ["benchmark", "config", "ipc", "time_ns", "l3_miss_rate_pct"]
            keep_s = [c for c in s_base if c in s.columns]

            # Try to keep any plausible LLC event columns automatically
            # (we won't fail if they're absent)
            for col in s.columns:
                cl = col.lower()
                if ("l3" in cl or "llc" in cl) and (
                    "access" in cl or "read" in cl or "write" in cl or "hit" in cl or "miss" in cl or "evict" in cl
                ):
                    if col not in keep_s:
                        keep_s.append(col)

            s = s[keep_s].copy()

            # Numeric coercion
            for col in ["time_s", "energy_exact_J", "leak_J", "dyn_exact_nJ"]:
                if col in e.columns:
                    e[col] = pd.to_numeric(e[col], errors="coerce")

            for col in s.columns:
                if col not in ("benchmark", "config"):
                    s[col] = pd.to_numeric(s[col], errors="coerce")

            # Convert nJ -> J
            if "dyn_exact_nJ" in e.columns:
                e["dyn_exact_J"] = e["dyn_exact_nJ"] * 1e-9

            energy_rows.append(e)
            summary_rows.append(s)

    if not energy_rows or not summary_rows:
        raise FileNotFoundError(
            "Could not find summary.csv and energy_bounds.csv in output_* directories under: " + base_dir
        )

    E = pd.concat(energy_rows, ignore_index=True)
    S = pd.concat(summary_rows, ignore_index=True)

    df = pd.merge(E, S, on=["benchmark", "config"], how="inner")

    # minimal sanity
    df = df.dropna(subset=["benchmark", "config", "time_s", "energy_exact_J"])
    print(f"Sniper parse complete. Merged DataFrame shape: {df.shape}")
    print(f"Sniper columns found: {df.columns.tolist()}")
    print("-" * 20)
    return df


def _kv_from_line(s: str) -> dict:
    """Extract numeric key=value pairs from one rwstats line. 'scope' handled separately."""
    kv = {}
    m = re.search(r"\bscope=(\w+)", s)
    if m:
        kv["scope"] = m.group(1)

    for k, v in re.findall(r"([A-Za-z0-9_]+)=([+\-]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+\-]?\d+)?|nan)", s):
        try:
            kv[k] = float("nan") if v.lower() == "nan" else float(v)
        except Exception:
            pass
    return kv


def parse_dynamorio(logs_dir, ts_prefix):
    """
    Parse DynamoRIO log files. For each file, grab the LAST stats-like line
    (lines contain 'scope='). File name format: {ts_prefix}_<benchmark>_instr.rwstats.log
    """
    rows = []
    print(f"\n--- Parsing DynamoRIO logs from: {logs_dir} with prefix '{ts_prefix}' ---")
    if not os.path.isdir(logs_dir):
        print("DynamoRIO logs directory not found. Returning empty DataFrame.")
        print("-" * 20)
        return pd.DataFrame()

    found_files = 0
    for fname in os.listdir(logs_dir):
        if not (fname.startswith(ts_prefix) and fname.endswith("_instr.rwstats.log")):
            continue
        m = re.match(rf"{re.escape(ts_prefix)}_(.+?)_instr\.rwstats\.log$", fname)
        if not m:
            continue
        
        found_files += 1
        benchmark = m.group(1)
        fpath = os.path.join(logs_dir, fname)

        last = None
        with open(fpath, "r", errors="ignore") as f:
            for line in f:
                t = line.strip()
                if "scope=" in t and "=" in t:
                    last = t

        if not last:
            continue

        kv = _kv_from_line(last)
        kv["benchmark"] = benchmark
        rows.append(kv)

    print(f"Found and processed {found_files} matching log files.")
    df = pd.DataFrame(rows) if rows else pd.DataFrame()
    if not df.empty:
        print(f"DynamoRIO parse complete. DataFrame shape: {df.shape}")
        print(f"DynamoRIO columns found: {df.columns.tolist()}")
    else:
        print("DynamoRIO parse complete. No data found, returning empty DataFrame.")
    print("-" * 20)
    return df


# -----------------------------
# Event detection (for per-event view)
# -----------------------------
def detect_llc_events_per_config(df_config):
    """
    Best-effort extraction of an LLC event count from Sniper summary columns
    for a (benchmark-indexed, single-config) DataFrame.
    Priority:
      1) total 'llc_accesses' or 'l3_accesses'
      2) sum of reads+writes
      3) sum of hits+misses
    Returns: pd.Series (index=benchmark) or None if nothing found.
    """
    if df_config is None or df_config.empty:
        return None

    cols = {c.lower(): c for c in df_config.columns}

    # 1) Direct totals
    for key in ["llc_accesses", "l3_accesses", "roi_llc_accesses", "roi_l3_accesses"]:
        if key in cols:
            ser = pd.to_numeric(df_config[cols[key]], errors="coerce")
            if ser.notna().any():
                print(f"[Event Detection] Found total LLC events using column: '{cols[key]}'")
                return ser

    # 2) Reads + writes
    read_keys  = [k for k in cols if ("read"  in k or "rd_" in k) and ("l3" in k or "llc" in k)]
    write_keys = [k for k in cols if ("write" in k or "wr_" in k) and ("l3" in k or "llc" in k)]
    if read_keys and write_keys:
        # choose the most populated pair
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for rk in read_keys:
            for wk in write_keys:
                s = pd.to_numeric(df_config[cols[rk]], errors="coerce") + pd.to_numeric(df_config[cols[wk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[rk], cols[wk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing reads+writes: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    # 3) Hits + misses
    hit_keys   = [k for k in cols if ("hit"   in k) and ("l3" in k or "llc" in k)]
    miss_keys  = [k for k in cols if ("miss"  in k) and ("l3" in k or "llc" in k)]
    if hit_keys and miss_keys:
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for hk in hit_keys:
            for mk in miss_keys:
                s = pd.to_numeric(df_config[cols[hk]], errors="coerce") + pd.to_numeric(df_config[cols[mk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[hk], cols[mk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing hits+misses: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    print("[Event Detection] No suitable LLC event columns found.")
    return None


def build_mem_instruction_counts(dr_df, benchmarks):
    """
    From DynamoRIO, create a per-benchmark count of memory instructions
    (reads + writes). Returns (Series or None).
    """
    if dr_df is None or dr_df.empty:
        return None

    dr = dr_df.set_index("benchmark")
    read_col  = None
    write_col = None

    # common column names
    for cand in ["read_total", "loads", "ld_total", "mem_reads"]:
        if cand in dr.columns:
            read_col = cand
            break
    for cand in ["write_total", "stores", "st_total", "mem_writes"]:
        if cand in dr.columns:
            write_col = cand
            break

    if read_col is None or write_col is None:
        print("[Mem Instr] Could not find read/write total columns in DynamoRIO data.")
        return None

    print(f"[Mem Instr] Calculating memory instructions from DR columns: '{read_col}' + '{write_col}'")
    mem = pd.to_numeric(dr[read_col], errors="coerce") + pd.to_numeric(dr[write_col], errors="coerce")
    mem = mem.reindex(benchmarks)
    if mem.notna().any():
        return mem
    return None


# -----------------------------
# Plot helpers
# -----------------------------
def grouped_barh(ax, labels, a_values, b_values, a_label, b_label, title, x_label):
    y = np.arange(len(labels))
    h = 0.38
    ax.barh(y - h/2, a_values, height=h, label=a_label)
    ax.barh(y + h/2, b_values, height=h, label=b_label)
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()  # top item at top
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)

def corr_heatmap(ax, matrix, row_labels, col_labels, title):
    im = ax.imshow(matrix, aspect="auto", vmin=-1, vmax=1, cmap="coolwarm")
    ax.set_yticks(np.arange(len(row_labels)))
    ax.set_yticklabels(row_labels)
    ax.set_xticks(np.arange(len(col_labels)))
    ax.set_xticklabels(col_labels, rotation=90)
    ax.set_title(title, fontsize=11)
    # annotate
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            val = matrix[i, j]
            ax.text(
                j, i, f"{val:.2f}",
                ha="center", va="center",
                color="white" if abs(val) > 0.6 else "black",
                fontsize=8
            )
    return im

def stacked_barh(ax, labels, data, category_labels, title, x_label):
    y = np.arange(len(labels))
    left = np.zeros(len(labels))
    for i, category in enumerate(data.keys()):
        values = data[category]
        ax.barh(y, values, left=left, label=category_labels[i], height=0.6)
        left += values
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)


# -----------------------------
# Main
# -----------------------------
def main():
    out_dir = os.getcwd()

    # Load data
    sniper = parse_sniper(SNIPER_RESULTS_DIR)
    dr = parse_dynamorio(DYNAMORIO_LOGS_DIR, TIMESTAMP_PREFIX)

    # Save raw inputs (handy for inspection)
    sniper.to_csv(os.path.join(out_dir, "sniper_raw.csv"), index=False)
    if not dr.empty:
        dr.to_csv(os.path.join(out_dir, "dynamorio_raw.csv"), index=False)

    print("\n--- Processing and Filtering Data ---")
    # Focus on benchmarks present in BOTH SRAM and JanS
    sram = sniper[sniper["config"] == "SRAM"].set_index("benchmark")
    jans = sniper[sniper["config"] == "JanS"].set_index("benchmark")
    common = sram.index.intersection(jans.index)
    if len(common) == 0:
        raise RuntimeError("No common benchmarks between SRAM and JanS.")
    
    print(f"Found {len(common)} common benchmarks between SRAM and JanS configs: {common.tolist()}")

    sram = sram.loc[common].copy()
    jans = jans.loc[common].copy()

    # Sort by SRAM execution time to keep labels readable
    order = sram.sort_values("time_s").index.tolist()
    sram = sram.loc[order]
    jans = jans.loc[order]
    labels = order
    
    print("Sorted benchmarks by SRAM execution time:", labels)
    print("\n--- SRAM Data (head) ---")
    print(sram.head())
    print("\n--- JanS Data (head) ---")
    print(jans.head())
    print("-" * 20)

    # ---------------- Sniper comparisons (compact 2x2) ----------------
    plt.rcParams.update({
        "figure.figsize": (11, 8),
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "xtick.labelsize": 8,
        "ytick.labelsize": 8
    })
    fig, axs = plt.subplots(2, 2)

    # 1) Execution time (s)
    grouped_barh(
        axs[0, 0], labels,
        sram["time_s"].values, jans["time_s"].values,
        "SRAM", "JanS",
        "Execution Time", "seconds"
    )

    # 2) Total LLC energy (J)
    grouped_barh(
        axs[0, 1], labels,
        sram["energy_exact_J"].values, jans["energy_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (total)", "Joules"
    )

    # 3) Dynamic LLC energy (J)
    grouped_barh(
        axs[1, 0], labels,
        sram["dyn_exact_J"].values, jans["dyn_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (dynamic only)", "Joules"
    )

    # 4) Leakage LLC energy (J)
    grouped_barh(
        axs[1, 1], labels,
        sram["leak_J"].values, jans["leak_J"].values,
        "SRAM", "JanS",
        "LLC Energy (leakage only)", "Joules"
    )

    fig.suptitle("SRAM vs JanS — Timing and Energy (per benchmark)", fontsize=12, y=0.99)
    fig.tight_layout(rect=[0, 0, 1, 0.97])

    # ------------------ Figure: Normalized Performance Summary ------------------
    norm = pd.DataFrame(index=order)
    norm["norm_time"]   = safe_div(jans["time_s"], sram["time_s"])
    norm["norm_energy"] = safe_div(jans["energy_exact_J"], sram["energy_exact_J"])
    
    print("\n--- Normalized Data (JanS / SRAM) ---")
    print(norm)
    print("-" * 20)

    fig2, axs2 = plt.subplots(2, 2, figsize=(11, 8))

    # 1) Normalized Execution Time
    axs2[0, 0].bar(norm.index, norm["norm_time"])
    axs2[0, 0].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 0].set_title("Normalized Execution Time (JanS / SRAM)", fontsize=11)
    axs2[0, 0].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 0].grid(True, axis="y", linestyle=":")

    # 2) Normalized Total LLC Energy
    axs2[0, 1].bar(norm.index, norm["norm_energy"])
    axs2[0, 1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 1].set_title("Normalized Total LLC Energy (JanS / SRAM)", fontsize=11)
    axs2[0, 1].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 1].grid(True, axis="y", linestyle=":")

    # 3) Absolute IPC
    x = np.arange(len(labels))
    width = 0.35
    axs2[1, 0].bar(x - width/2, sram["ipc"], width, label='SRAM')
    axs2[1, 0].bar(x + width/2, jans["ipc"], width, label='JanS')
    axs2[1, 0].set_title("Instructions Per Cycle (IPC)", fontsize=11)
    axs2[1, 0].set_ylabel("IPC (Higher is Better)", fontsize=10)
    axs2[1, 0].legend(fontsize=8, frameon=False)

    # 4) L3 Miss Rate (%)
    if "l3_miss_rate_pct" in sram.columns and "l3_miss_rate_pct" in jans.columns:
        axs2[1, 1].bar(x - width/2, sram["l3_miss_rate_pct"], width, label='SRAM')
        axs2[1, 1].bar(x + width/2, jans["l3_miss_rate_pct"], width, label='JanS')
        axs2[1, 1].set_title("L3 Miss Rate", fontsize=11)
        axs2[1, 1].set_ylabel("Miss Rate (%)", fontsize=10)
        axs2[1, 1].legend(fontsize=8, frameon=False)
    else:
        axs2[1, 1].axis("off")

    for ax in axs2.flatten():
        ax.set_xticks(np.arange(len(labels)))
        ax.set_xticklabels(labels, rotation=90)
        ax.tick_params(axis="x", labelsize=8)

    # Geomeans for headline
    gm_time   = geomean(norm["norm_time"])
    gm_energy = geomean(norm["norm_energy"])
    fig2.suptitle(f"Performance & Cache Metrics: SRAM vs. JanS — GeoMeans (JanS/SRAM): "
                  f"time={gm_time:.3f}, energy={gm_energy:.3f}",
                  fontsize=13, y=0.99)
    fig2.tight_layout(rect=[0, 0, 1, 0.96])

    # ------------------ Figure: LLC Energy Breakdown ------------------
    fig_e, axs_e = plt.subplots(1, 2, figsize=(11, 5), sharex=True)
    sram_energy_data = {'Dynamic': sram["dyn_exact_J"], 'Leakage': sram["leak_J"]}
    jans_energy_data = {'Dynamic': jans["dyn_exact_J"], 'Leakage': jans["leak_J"]}

    stacked_barh(axs_e[0], labels, sram_energy_data, ['Dynamic', 'Leakage'], "SRAM LLC Energy Breakdown", "Joules")
    stacked_barh(axs_e[1], labels, jans_energy_data, ['Dynamic', 'Leakage'], "JanS LLC Energy Breakdown", "Joules")

    fig_e.suptitle("LLC Energy Composition: Dynamic vs. Leakage", fontsize=13, y=0.99)
    fig_e.tight_layout(rect=[0, 0, 1, 0.94])

    # ---------------- Mechanism View: Dynamic energy per event ----------------
    print("\n--- Calculating Dynamic Energy per Event ---")
    # Try to use *LLC event counts* from Sniper; if unavailable, fall back to *memory instructions* from DynamoRIO.
    per_event_mode = None  # "llc" or "mem"
    sram_denom = detect_llc_events_per_config(sram)
    jans_denom = detect_llc_events_per_config(jans)

    if sram_denom is not None and jans_denom is not None:
        per_event_mode = "llc"
        sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, sram_denom)
        jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, jans_denom)
        denom_label = "LLC event"
    else:
        mem_instr = build_mem_instruction_counts(dr, labels)
        if mem_instr is not None and np.nanmax(mem_instr.values) > 0:
            per_event_mode = "mem"
            # Same denominator for both configs (program-level memory instruction count)
            sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            denom_label = "memory instruction"
        else:
            per_event_mode = None
    
    print(f"Per-event mode chosen: '{per_event_mode}'")
    if per_event_mode:
        print(f"Denominator label: '{denom_label}'")
    print("-" * 20)

    if per_event_mode is not None:
        fig_pe, axs_pe = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(
            axs_pe[0], labels,
            sram_pJ, jans_pJ,
            "SRAM", "JanS",
            f"Dynamic LLC Energy per {denom_label}", f"pJ / {denom_label}"
        )
        ratio = safe_div(jans_pJ, sram_pJ)
        x = np.arange(len(labels))
        axs_pe[1].bar(x, ratio)
        axs_pe[1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
        axs_pe[1].set_title(f"Normalized pJ/{denom_label} (JanS / SRAM)")
        axs_pe[1].set_ylabel("Ratio (Lower is Better)")
        axs_pe[1].set_xticks(x)
        axs_pe[1].set_xticklabels(labels, rotation=90)
        axs_pe[1].grid(True, axis="y", linestyle=":")

        gm_pe = geomean(ratio)
        fig_pe.suptitle(
            f"Mechanism: Dynamic Energy per {denom_label} — Geomean (JanS/SRAM) = {gm_pe:.3f}",
            fontsize=13, y=0.99
        )
        fig_pe.tight_layout(rect=[0, 0, 1, 0.94])

        # Save CSV of the per-event metrics
        per_event_df = pd.DataFrame({
            "benchmark": labels,
            "SRAM_dyn_pJ_per_"+denom_label: sram_pJ,
            "JanS_dyn_pJ_per_"+denom_label: jans_pJ,
            "JanS_over_SRAM_pJ_per_"+denom_label: ratio
        }).set_index("benchmark")
        # Add denominators for transparency
        if per_event_mode == "llc":
            per_event_df["SRAM_"+denom_label+"s"] = sram_denom.reindex(labels).values
            per_event_df["JanS_"+denom_label+"s"] = jans_denom.reindex(labels).values
        else:
            per_event_df[denom_label+"s"] = build_mem_instruction_counts(dr, labels).reindex(labels).values
        
        print("\n--- Per-Event Dynamic Energy Data ---")
        print(per_event_df)
        print("-" * 20)
        per_event_df.to_csv(os.path.join(out_dir, "per_event_dynamic_energy.csv"))

    # ---------------- Correlation: DynamoRIO features vs totals / gains ----------------
    if not dr.empty:
        print("\n--- Building Correlation Matrix Data ---")
        feat_map = {
            "rtotal":     "read_total",
            "runique":    "read_unique",
            "90%f_tr":    "read_footprint90L",   # global, line-level
            "Hrg":        "read_entropy",
            "Hrl":        "read_local_entropy",
            "wtotal":     "write_total",
            "wunique":    "write_unique",
            "90%f_tw":    "write_footprint90L",  # global, line-level
            "Hwg":        "write_entropy",
            "Hwl":        "write_local_entropy",
        }

        feats = pd.DataFrame({"benchmark": dr["benchmark"]})
        for out_name, src in feat_map.items():
            feats[out_name] = pd.to_numeric(dr.get(src), errors="coerce")
        feats = feats.set_index("benchmark")

        # Targets (SRAM absolute) and normalized gains
        targets_sram = sram[["time_s", "energy_exact_J", "dyn_exact_J", "ipc"]].copy()
        if "l3_miss_rate_pct" in sram.columns:
            targets_sram["L3_miss%"] = sram["l3_miss_rate_pct"]
        targets_sram = targets_sram.rename(columns={
            "time_s": "exe_time", "energy_exact_J": "LLC_energy", "dyn_exact_J": "Dyn_energy", "ipc": "IPC"
        })

        corr_df = feats.join(targets_sram, how="inner").join(norm[["norm_time", "norm_energy"]], how="inner")

        # If per-event dynamic energy exists, add one column (SRAM) and one ratio
        if per_event_mode is not None:
            corr_label_abs = f"pJ/{denom_label} (SRAM)"
            corr_label_norm = f"norm_pJ/{denom_label} (JanS/SRAM)"
            corr_df[corr_label_abs] = pd.Series(sram_pJ, index=labels)
            corr_df[corr_label_norm] = pd.Series(safe_div(jans_pJ, sram_pJ), index=labels)

        print("Correlation DataFrame (head):")
        print(corr_df.head())
        print("-" * 20)

        feature_names = [k for k in feat_map.keys() if k in corr_df.columns and not corr_df[k].isna().all()]
        abs_cols = [c for c in ["exe_time", "LLC_energy", "Dyn_energy", "IPC", "L3_miss%",] if c in corr_df.columns and not corr_df[c].isna().all()]
        norm_cols = [c for c in ["norm_time", "norm_energy"] if c in corr_df.columns and not corr_df[c].isna().all()]
        extra_cols = []
        if per_event_mode is not None:
            for c in [corr_label_abs, corr_label_norm]:
                if c in corr_df.columns and not corr_df[c].isna().all():
                    extra_cols.append(c)

        if feature_names and (abs_cols or norm_cols or extra_cols) and len(corr_df.dropna(how="all")) >= 2:
            n_panels = 2 if extra_cols else 2
            fig_c, axs_c = plt.subplots(1, 2, figsize=(9, 5))

            # Features vs. SRAM absolute metrics
            if abs_cols:
                C1 = corr_df[feature_names + abs_cols].corr().loc[feature_names, abs_cols].values
                corr_heatmap(axs_c[0], C1, feature_names, abs_cols, "Features vs. SRAM Totals")
            else:
                axs_c[0].axis("off")

            # Features vs. normalized gains (+ optional per-event targets)
            cols2 = norm_cols + extra_cols
            if cols2:
                C2 = corr_df[feature_names + cols2].corr().loc[feature_names, cols2].values
                corr_heatmap(axs_c[1], C2, feature_names, cols2, "Features vs. Gains / Per-Event")
            else:
                axs_c[1].axis("off")
            
            fig_c.suptitle("Correlation: Memory Features ↔ Totals & Gains", fontsize=13, y=0.99)
            fig_c.tight_layout(rect=[0, 0, 1, 0.92])
        else:
            print("Not enough data for correlation heatmaps (missing features/targets or too few benchmarks).")
    else:
        print("DynamoRIO features unavailable — skipping correlation plots.")

    # -------- Save headline geomeans --------
    geomean_df = pd.DataFrame({
        "metric": ["time (JanS/SRAM)", "total LLC energy (JanS/SRAM)"],
        "geomean_ratio": [gm_time, gm_energy],
    })
    print("\n--- Geomean Summary ---")
    print(geomean_df)
    print("-" * 20)
    geomean_df.to_csv(os.path.join(out_dir, "geomean_summary.csv"), index=False)

    #########################################
    
    print("\n--- Additional System-Level Analysis (Power & EDP) ---")
    sys = pd.DataFrame({
        "benchmark": labels,
        "SRAM_time_s": sram["time_s"].values,
        "JanS_time_s": jans["time_s"].values,
        "SRAM_energy_J": sram["energy_exact_J"].values,
        "JanS_energy_J": jans["energy_exact_J"].values,
        "SRAM_dyn_W": safe_div(sram["dyn_exact_J"].values, sram["time_s"].values),
        "JanS_dyn_W": safe_div(jans["dyn_exact_J"].values, jans["time_s"].values),
        "SRAM_leak_W": safe_div(sram["leak_J"].values, sram["time_s"].values),
        "JanS_leak_W": safe_div(jans["leak_J"].values, jans["time_s"].values),
    }).set_index("benchmark")
    sys["SRAM_EDP"] = sys["SRAM_energy_J"] * sys["SRAM_time_s"]
    sys["JanS_EDP"] = sys["JanS_energy_J"] * sys["JanS_time_s"]

    # --- NEW: ED^2P (energy * time^2) and normalization
    sys["SRAM_ED2P"] = sys["SRAM_energy_J"] * (sys["SRAM_time_s"] ** 2)
    sys["JanS_ED2P"] = sys["JanS_energy_J"] * (sys["JanS_time_s"] ** 2)
    sys["norm_ED2P"] = safe_div(sys["JanS_ED2P"].values, sys["SRAM_ED2P"].values)

    print("System-level metrics (head):")
    print(sys.head())
    print("-" * 20)
    
    fig_sys, axs_sys = plt.subplots(1, 3, figsize=(14, 5))
    grouped_barh(axs_sys[0], labels,
                 sys["SRAM_dyn_W"].values, sys["JanS_dyn_W"].values,
                 "SRAM","JanS","Dynamic Power (LLC)","Watts")
    grouped_barh(axs_sys[1], labels,
                 sys["SRAM_leak_W"].values, sys["JanS_leak_W"].values,
                 "SRAM","JanS","Leakage Power (LLC)","Watts")

    x = np.arange(len(labels))
    edp_ratio = safe_div(sys["JanS_EDP"].values, sys["SRAM_EDP"].values)
    axs_sys[2].bar(x, edp_ratio)
    axs_sys[2].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
    axs_sys[2].set_xticks(x)
    axs_sys[2].set_xticklabels(labels, rotation=90)
    axs_sys[2].set_ylabel("Ratio (Lower is Better)")
    axs_sys[2].set_title("EDP (JanS / SRAM)")
    fig_sys.suptitle("System Power & EDP", fontsize=13, y=0.99)
    fig_sys.tight_layout(rect=[0,0,1,0.94])

    # -- B) Per-miss dynamic energy (best-effort) -----------------------------
    def _approx_misses(df_config, total_series):
        if total_series is None or "l3_miss_rate_pct" not in df_config.columns:
            return None
        total = pd.to_numeric(total_series.reindex(df_config.index), errors="coerce")
        miss_rate = pd.to_numeric(df_config["l3_miss_rate_pct"], errors="coerce") / 100.0
        misses = total * miss_rate
        return misses if misses.notna().any() else None

    sram_total = detect_llc_events_per_config(sram)
    jans_total = detect_llc_events_per_config(jans)
    sram_misses = _approx_misses(sram, sram_total) if sram_total is not None else None
    jans_misses = _approx_misses(jans, jans_total) if jans_total is not None else None

    if sram_misses is not None and jans_misses is not None:
        print("\n--- Per-Miss Dynamic Energy Analysis ---")
        pJmiss_s = safe_div(sram["dyn_exact_J"].values * 1e12, sram_misses.reindex(labels).values)
        pJmiss_j = safe_div(jans["dyn_exact_J"].values * 1e12, jans_misses.reindex(labels).values)
        r_pm = safe_div(pJmiss_j, pJmiss_s)

        pm_df = pd.DataFrame({
            'sram_misses_approx': sram_misses,
            'jans_misses_approx': jans_misses,
            'sram_pJ_per_miss': pJmiss_s,
            'jans_pJ_per_miss': pJmiss_j,
            'ratio_pJ_per_miss': r_pm
        }, index=labels)
        print("Per-miss energy data (head):")
        print(pm_df.head())
        print("-" * 20)

        fig_pm, axs_pm = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(axs_pm[0], labels, pJmiss_s, pJmiss_j,
                     "SRAM","JanS","Dynamic Energy per L3 Miss","pJ / miss")

        axs_pm[1].bar(x, r_pm)
        axs_pm[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
        axs_pm[1].set_xticks(x)
        axs_pm[1].set_xticklabels(labels, rotation=90)
        axs_pm[1].set_ylabel("Ratio (Lower is Better)")
        axs_pm[1].set_title("pJ/miss (JanS / SRAM)")
        fig_pm.suptitle("Per-Miss Dynamic Energy (approx. via miss_rate × total L3/LLC)", y=0.99)
        fig_pm.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[per-miss] Skipped: need total L3/LLC events + l3_miss_rate_pct in summary.csv.")

    # -- C) Event-type cost fit (pJ per event) -------------------------------
    # Estimate costs for {read_hit, read_miss, write_hit, write_miss, evict} via least squares, if columns exist.
    def _choose_col(df_config, must_terms, maybes=("l3","llc")):
        best = None; best_pop = -1
        for c in df_config.columns:
            cl = c.lower()
            if all(t in cl for t in must_terms) and any(m in cl for m in maybes):
                ser = pd.to_numeric(df_config[c], errors="coerce")
                pop = ser.notna().sum()
                if pop > best_pop:
                    best, best_pop = c, pop
        return best

    def _find_event_cols(df_config):
        mapping = {
            "read_hit":  ["read","hit"],
            "write_hit": ["write","hit"],
            "read_miss": ["read","miss"],
            "write_miss":["write","miss"],
            "evict":     ["evict"],
        }
        out = {}
        for name, terms in mapping.items():
            col = _choose_col(df_config, terms)
            if col is None and name == "evict":
                col = _choose_col(df_config, ["writeback"]) or _choose_col(df_config, ["wb"])
            if col is not None:
                out[name] = col
        return out

    def _fit_costs(df_config, event_cols):
        if not event_cols:
            return None, None
        X_cols = list(event_cols.values())
        X = np.column_stack([pd.to_numeric(df_config[c], errors="coerce").fillna(0.0).values for c in X_cols])
        y = pd.to_numeric(df_config["dyn_exact_J"], errors="coerce").values
        mask = np.isfinite(y)
        for i in range(X.shape[1]):
            mask &= np.isfinite(X[:, i])
        X, y = X[mask], y[mask]
        if X.shape[0] < len(X_cols):
            return None, None
        beta, residuals, rank, s = np.linalg.lstsq(X, y, rcond=None)
        r2 = 1.0 - ((y - X @ beta)**2).sum() / np.maximum(1e-12, ((y - y.mean())**2).sum())
        return pd.Series(beta * 1e12, index=list(event_cols.keys())), r2  # pJ/event

    sram_event_cols = _find_event_cols(sram)
    jans_event_cols = _find_event_cols(jans)
    coef_s, r2_s = _fit_costs(sram, sram_event_cols)
    coef_j, r2_j = _fit_costs(jans, jans_event_cols)

    if coef_s is not None or coef_j is not None:
        print("\n--- Fitted Event Cost Analysis ---")
        print(f"SRAM event columns used for fit: {sram_event_cols}")
        print(f"JanS event columns used for fit: {jans_event_cols}")
        
        keys = sorted(set([] if coef_s is None else coef_s.index).union([] if coef_j is None else coef_j.index))
        s_vals = np.array([coef_s.get(k, np.nan) if coef_s is not None else np.nan for k in keys])
        j_vals = np.array([coef_j.get(k, np.nan) if coef_j is not None else np.nan for k in keys])

        fit_df = pd.DataFrame({'event_type': keys, 'SRAM_pJ_per_event': s_vals, 'JanS_pJ_per_event': j_vals}).set_index('event_type')
        print("Fitted coefficients (pJ/event):")
        print(fit_df)
        print(f"SRAM R² = {r2_s:.3f}, JanS R² = {r2_j:.3f}")
        print("-" * 20)

        fig_ev, ax_ev = plt.subplots(1, 1, figsize=(10, 4.8))
        xx = np.arange(len(keys)); w = 0.42
        ax_ev.bar(xx - w/2, s_vals, width=w, label="SRAM")
        ax_ev.bar(xx + w/2, j_vals, width=w, label="JanS")
        ax_ev.set_xticks(xx)
        ax_ev.set_xticklabels(keys)
        ax_ev.set_ylabel("pJ / event")
        ax_ev.set_title("Fitted LLC Event Costs")
        ax_ev.grid(True, axis="y", linestyle=":")
        ax_ev.legend(fontsize=8, frameon=False)
        fig_ev.suptitle(f"Event-Cost Fit (least squares) — R² SRAM={r2_s if r2_s is not None else float('nan'):.2f}, JanS={r2_j if r2_j is not None else float('nan'):.2f}", y=0.99)
        fig_ev.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[event-fit] Skipped: insufficient L3/LLC event columns in summary.csv.")

    # -- D) What-if gating rule visualization ---------------------------------
    try:
        if not dr.empty:
            print("\n--- What-if Gating Rule Visualization ---")
            dr_idx = dr.set_index("benchmark")
            rf = pd.to_numeric(dr_idx.get("read_footprint90L"), errors="coerce")
            wf = pd.to_numeric(dr_idx.get("write_footprint90L"), errors="coerce")
            p50s = pd.to_numeric(dr_idx.get("p50_strideB"), errors="coerce")
            rf_thr = np.nanmedian(rf.values); wf_thr = np.nanmedian(wf.values); stride_thr = 512 * 1024
            enable = ((rf >= rf_thr) | (wf >= wf_thr)) & (p50s <= stride_thr)
            enable = enable.reindex(labels).fillna(False)

            print(f"Gating rule: ((read_footprint >= {rf_thr:.1f}) OR (write_footprint >= {wf_thr:.1f})) AND (p50_stride <= {stride_thr})")
            print("Gating decisions (True means enable JanS):")
            print(enable)
            
            chosen_E = np.where(enable.values, jans["energy_exact_J"].values, sram["energy_exact_J"].values)
            chosen_T = np.where(enable.values, jans["time_s"].values,         sram["time_s"].values)
            energy_ratio = safe_div(chosen_E, sram["energy_exact_J"].values)
            time_ratio   = safe_div(chosen_T, sram["time_s"].values)
            print("-" * 20)

            fig_gate, axs_gate = plt.subplots(1, 2, figsize=(12, 5))
            axs_gate[0].bar(x, energy_ratio)
            axs_gate[0].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
            axs_gate[0].set_xticks(x); axs_gate[0].set_xticklabels(labels, rotation=90)
            axs_gate[0].set_ylabel("Ratio vs SRAM"); axs_gate[0].set_title("What-if Energy (rule)")

            axs_gate[1].bar(x, time_ratio)
            axs_gate[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
            axs_gate[1].set_xticks(x); axs_gate[1].set_xticklabels(labels, rotation=90)
            axs_gate[1].set_ylabel("Ratio vs SRAM"); axs_gate[1].set_title("What-if Time (rule)")

            # annotate chosen config under each bar
            for ax in axs_gate:
                ymin, ymax = ax.get_ylim()
                for xi, choose_j in enumerate(enable.values):
                    ax.text(xi, ymin + 0.02*(ymax - ymin),
                            "JanS" if choose_j else "SRAM",
                            rotation=90, ha="center", va="bottom", fontsize=7, alpha=0.75)
            fig_gate.suptitle("Simple Gating Rule Outcome", y=0.99)
            fig_gate.tight_layout(rect=[0,0,1,0.94])
        else:
            print("\n[gating] Skipped: no DynamoRIO features available.")
    except Exception as e:
        print("\n[gating] Error:", e)
    
    #########################################
    
        # ==== PREDICTORS ↔ OUTCOMES: DATA-BACKED CHECK ===========================
    # Build per-access metrics from DR (reads+writes)
    def _mem_accesses_from_dr(dr_df, bench_idx):
        if dr_df is None or dr_df.empty:
            return None
        d = dr_df.set_index("benchmark")
        # prefer "read_total"/"write_total", else common fallbacks
        rc = next((c for c in ["read_total","loads","ld_total","mem_reads"] if c in d.columns), None)
        wc = next((c for c in ["write_total","stores","st_total","mem_writes"] if c in d.columns), None)
        if rc is None or wc is None:
            return None
        mem = pd.to_numeric(d[rc], errors="coerce") + pd.to_numeric(d[wc], errors="coerce")
        return mem.reindex(bench_idx)

    mem = _mem_accesses_from_dr(dr, labels)
    if mem is not None and np.nanmax(mem.values) > 0:
        # Per-access metrics (SRAM & JanS)
        sram_pJ = safe_div(sram["dyn_exact_J"].values * 1e12, mem.values)
        jans_pJ = safe_div(jans["dyn_exact_J"].values * 1e12, mem.values)
        sram_ns = safe_div(sram["time_s"].values * 1e9, mem.values)
        jans_ns = safe_div(jans["time_s"].values * 1e9, mem.values)
        ratio_pJ = safe_div(jans_pJ, sram_pJ)
        ratio_ns = safe_div(jans_ns, sram_ns)

        # Pull DR predictors
        dr_idx = dr.set_index("benchmark")
        feats = pd.DataFrame(index=labels)
        for col in ["read_footprint90L","write_footprint90L","read_local_entropy","write_local_entropy"]:
            feats[col] = pd.to_numeric(dr_idx.get(col), errors="coerce").reindex(labels)

        # --- NEW: write_share computation (task 1) -------------------------
        # compute write_share = write_total / (read_total + write_total)
        rtot = pd.to_numeric(dr_idx.get("read_total"), errors="coerce").reindex(labels)
        wtot = pd.to_numeric(dr_idx.get("write_total"), errors="coerce").reindex(labels)
        write_share = safe_div(wtot, (rtot + wtot))
        feats["write_share"] = write_share

        # Assemble analysis frame
        A = pd.DataFrame({
            "ratio_pJ_per_access": ratio_pJ,
            "ratio_ns_per_access": ratio_ns,
            "sram_pJ_per_access":  sram_pJ,
            "sram_ns_per_access":  sram_ns,
        }, index=labels).join(feats)
        
        print("\n--- Predictor Analysis DataFrame (head) ---")
        print(A.head())
        print("-" * 20)

        def _corr_table(df, Xcols, Ycol):
            rows = []
            for x in Xcols:
                xser = pd.to_numeric(df[x], errors="coerce")
                yser = pd.to_numeric(df[Ycol], errors="coerce")
                if xser.notna().sum() >= 3 and yser.notna().sum() >= 3:
                    r_p = xser.corr(yser, method="pearson")
                    r_s = xser.corr(yser, method="spearman")
                    rows.append([x, r_p, r_s, xser.notna().sum()])
            return pd.DataFrame(rows, columns=["feature","pearson_r","spearman_r","N"]).set_index("feature")

        # Correlations that support the claims
        tab_foot_vs_ratio = _corr_table(A,
            ["read_footprint90L","write_footprint90L"], "ratio_pJ_per_access")
        tab_entropy_vs_sram_ns = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "sram_ns_per_access")
        tab_entropy_vs_sram_pJ = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "sram_pJ_per_access")
        tab_entropy_vs_ratio_ns = _corr_table(A,
            ["read_local_entropy","write_local_entropy"], "ratio_ns_per_access")

        print("\n[predictors] JanS/SRAM pJ per access vs 90% footprints:")
        print(tab_foot_vs_ratio.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] SRAM ns/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_sram_ns.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] SRAM pJ/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_sram_pJ.to_string(float_format=lambda v: f"{v: .3f}"))
        print("\n[predictors] JanS/SRAM ns/access vs local entropy (Hrl/Hwl):")
        print(tab_entropy_vs_ratio_ns.to_string(float_format=lambda v: f"{v: .3f}"))

        # Save CSV summary
        corr_out = (tab_foot_vs_ratio.assign(target="ratio_pJ/access")
                    .append(tab_entropy_vs_sram_ns.assign(target="sram_ns/access"))
                    .append(tab_entropy_vs_sram_pJ.assign(target="sram_pJ/access"))
                    .append(tab_entropy_vs_ratio_ns.assign(target="ratio_ns/access")))
        corr_out.to_csv(os.path.join(out_dir, "predictors_correlations.csv"))

        # --- NEW: Task 1: correlate write_share with pJ/access and with NVM/SRAM pJ per event if available
        print("\n--- Task 1: write_share correlations ---")
        if "write_share" in A.columns:
            for target in ["sram_pJ_per_access", "ratio_pJ_per_access"]:
                x = A["write_share"].values
                y = A[target].values
                obs_s, lo, hi, n_obs = bootstrap_spearman_ci(x, y, n_boot=5000, random_state=1)
                pear = pd.Series(x).corr(pd.Series(y), method="pearson")
                print(f"Target: {target}: N={n_obs}, Pearson={pear:.3f}, Spearman={obs_s:.3f}, 95% CI=[{lo:.3f}, {hi:.3f}]")
                if np.isfinite(lo) and lo < 0 and hi > 0:
                    print("  CI crosses zero -> call: TREND (not robustly significant).")
                elif np.isfinite(lo) and lo > 0:
                    print("  CI > 0 -> positive association (robust).")
                elif np.isfinite(hi) and hi < 0:
                    print("  CI < 0 -> negative association (robust).")
        else:
            print("write_share not available in DR features.")

        # --- NEW: Task 2 — rank-based / robust checks and bootstrap CIs (general helper use)
        print("\n--- Task 2: Bootstrap Spearman CIs for some key correlations ---")
        # Example list of pairs to bootstrap
        check_pairs = [
            ("write_share", "sram_pJ_per_access"),
            ("write_share", "ratio_pJ_per_access"),
            ("write_local_entropy", "sram_pJ_per_access"),
            ("write_footprint90L", "ratio_pJ_per_access")
        ]
        boot_results = []
        for a, b in check_pairs:
            if a in A.columns and b in A.columns:
                obs, lo, hi, nobs = bootstrap_spearman_ci(A[a].values, A[b].values, n_boot=5000, random_state=2)
                boot_results.append((a,b,obs,lo,hi,nobs))
                print(f"{a:<22} vs {b:<25} => Spearman={obs:.3f}, 95% CI [{lo:.3f}, {hi:.3f}], N={nobs}")
        # Save bootstrap results
        pd.DataFrame(boot_results, columns=["x","y","spearman","lo95","hi95","N"]).to_csv(os.path.join(out_dir, "bootstrap_spearman_cis.csv"), index=False)

        # --- NEW: Task 3 — Partial correlations / tiny regressions
        print("\n--- Task 3: Partial correlations and small regressions (keep 1-2 predictors) ---")
        # Target: sram_pJ_per_access (absolute cost) and ratio_pJ_per_access (JanS/SRAM)
        predictors = {
            "write_share": A.get("write_share"),
            "write_footprint90L": A.get("write_footprint90L"),
            "read_footprint90L": A.get("read_footprint90L"),
            "write_local_entropy": A.get("write_local_entropy"),
            "read_local_entropy": A.get("read_local_entropy")
        }
        # Partial correlation of sram_pJ_per_access with write_share controlling for write_footprint90L
        if "write_share" in A.columns and "write_footprint90L" in A.columns:
            r_partial, n_partial = partial_corr_pearson(A["sram_pJ_per_access"].values, A["write_share"].values, 
                                                        pd.DataFrame({"write_footprint90L": A["write_footprint90L"].values}))
            print(f"Partial Pearson(sram_pJ_per_access ~ write_share | write_footprint90L): r={r_partial:.3f}, N={n_partial}")
        # Tiny regression: sram_pJ_per_access ~ write_share + write_footprint90L (LOO stability)
        if "write_share" in A.columns and "write_footprint90L" in A.columns:
            mask = np.isfinite(A["sram_pJ_per_access"]) & np.isfinite(A["write_share"]) & np.isfinite(A["write_footprint90L"])
            y = A["sram_pJ_per_access"].values[mask]
            X = np.column_stack([A["write_share"].values[mask], A["write_footprint90L"].values[mask]])
            if len(y) >= 3:
                # add intercept inside loo function
                loo = loo_regression_stability(y, X)
                if loo is not None:
                    print("LOO regression coefficients (intercept, write_share, write_footprint90L) mean ± std:")
                    means = loo["mean_coef"]; stds = loo["std_coef"]
                    print(f"  intercept {means[0]:.3e} ± {stds[0]:.3e}")
                    print(f"  write_share {means[1]:.3e} ± {stds[1]:.3e}")
                    print(f"  write_footprint90L {means[2]:.3e} ± {stds[2]:.3e}")
                # also full regression
                Xfull = np.column_stack([np.ones(len(X)), X])
                beta, *_ = np.linalg.lstsq(Xfull, y, rcond=None)
                print("Full regression coefficients (intercept, write_share, write_footprint90L):", beta)
            else:
                print("Not enough points for regression.")

        # --- NEW: Task 4 — AI-only slice (leela, deepsjeng, exchange2) ------------
        ai_cores = ["leela", "deepsjeng", "exchange2"]
        ai_present = [b for b in ai_cores if b in A.index]
        print("\n--- Task 4: AI-only slice analysis ---")
        if len(ai_present) >= 2:
            Asub = A.loc[ai_present]
            for target in ["sram_pJ_per_access", "ratio_pJ_per_access", "sram_ns_per_access", "sram_pJ_per_access"]:
                for feat in ["write_local_entropy", "write_footprint90L", "write_share"]:
                    if feat in Asub.columns and target in Asub.columns:
                        obs, lo, hi, nobs = bootstrap_spearman_ci(Asub[feat].values, Asub[target].values, n_boot=5000, random_state=3)
                        print(f"[AI-set] {feat} vs {target}: Spearman={obs:.3f}, 95%CI=[{lo:.3f},{hi:.3f}], N={nobs}")
        else:
            print("Not enough AI benchmarks present in dataset for AI-only slice.")

        # --- NEW: Task 5 — System-level metrics beyond LLC (we already have energy_exact_J) ---
        print("\n--- Task 5: System energy & ED2P normalized to SRAM ---")
        # We compute ED2P = energy * time^2 (system-level) and normalize JanS/SRAM
        sys_energy = pd.DataFrame({
            "benchmark": labels,
            "SRAM_energy_J": sram["energy_exact_J"].values,
            "JanS_energy_J": jans["energy_exact_J"].values,
            "SRAM_time_s": sram["time_s"].values,
            "JanS_time_s": jans["time_s"].values
        }).set_index("benchmark")
        sys_energy["SRAM_ED2P"] = sys_energy["SRAM_energy_J"] * (sys_energy["SRAM_time_s"] ** 2)
        sys_energy["JanS_ED2P"] = sys_energy["JanS_energy_J"] * (sys_energy["JanS_time_s"] ** 2)
        sys_energy["JanS_over_SRAM_ED2P"] = safe_div(sys_energy["JanS_ED2P"].values, sys_energy["SRAM_ED2P"].values)
        print(sys_energy[["SRAM_energy_J","JanS_energy_J","SRAM_ED2P","JanS_ED2P","JanS_over_SRAM_ED2P"]])
        sys_energy.to_csv(os.path.join(out_dir, "system_level_ed2p.csv"))

        # --- NEW: Task 6 — Endurance feasibility (offline) -----------------------
        print("\n--- Task 6: Endurance feasibility (approximate/offline) ---")
        # Assumptions (documented):
        #  - We'll use DR write_total and write_unique to estimate average writes per unique line:
        #       avg_writes_per_line = write_total / write_unique
        #  - Assume MRAM cell endurance default = 1e12 writes (user can change)
        #  - Compute estimated time-to-limit (years) = endurance / (avg_writes_per_line / runtime_seconds)
        #  - If write_unique==0 we skip. This is a coarse approximation and *not* a distributional analysis.
        endurance_default = 1e12  # default writes per cell (conservative; change as needed)
        results_end = []
        for b in labels:
            wt = pd.to_numeric(dr_idx.get("write_total"), errors="coerce").reindex(labels).loc[b]
            wu = pd.to_numeric(dr_idx.get("write_unique"), errors="coerce").reindex(labels).loc[b]
            runtime = sram.loc[b]["time_s"] if b in sram.index else np.nan
            if not np.isfinite(wt) or not np.isfinite(wu) or wu == 0 or not np.isfinite(runtime) or runtime <= 0:
                results_end.append((b, np.nan, np.nan, np.nan))
                continue
            avg_writes_per_line = wt / wu
            # rate: writes per line per second
            writes_per_line_per_s = avg_writes_per_line / runtime
            # time to endurance (seconds)
            t_seconds = endurance_default / writes_per_line_per_s if writes_per_line_per_s > 0 else np.nan
            t_years = t_seconds / (3600.0 * 24.0 * 365.0) if np.isfinite(t_seconds) else np.nan
            results_end.append((b, avg_writes_per_line, t_years, writes_per_line_per_s))
        end_df = pd.DataFrame(results_end, columns=["benchmark","avg_writes_per_line","time_to_limit_years","writes_per_line_per_s"]).set_index("benchmark")
        print("Endurance estimate (head):")
        print(end_df.head())
        # Fraction of benchmarks where average-line exhausts in <5 years
        valid = end_df["time_to_limit_years"].dropna()
        frac_short = np.mean(valid < 5) if len(valid) > 0 else np.nan
        print(f"Fraction of benchmarks where average unique line would hit endurance < 5 years (assuming {endurance_default:.1e} writes): {frac_short:.3f}")
        end_df.to_csv(os.path.join(out_dir, "endurance_estimates.csv"))

        # Save the A frame as well for downstream use
        A.to_csv(os.path.join(out_dir, "per_access_predictors.csv"))

        # --- Plots: clean and compact ---------------------------------------
        # 1) ratio pJ/access vs footprints
        fig_pf, axs_pf = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_pf,
            ["read_footprint90L","write_footprint90L"],
            ["JanS/SRAM pJ/access vs Read 90%Footprint (lines)",
             "JanS/SRAM pJ/access vs Write 90%Footprint (lines)"]
        ):
            x = A[col].values; y = A["ratio_pJ_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            # OLS line (best fit)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("lines"); 
        axs_pf[0].set_ylabel("JanS/SRAM pJ per access")
        fig_pf.tight_layout()

        # 2) SRAM per-access latency vs local entropies
        fig_he, axs_he = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_he,
            ["read_local_entropy","write_local_entropy"],
            ["SRAM ns/access vs Hrl","SRAM ns/access vs Hwl"]
        ):
            x = A[col].values; y = A["sram_ns_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("entropy (bits)"); 
        axs_he[0].set_ylabel("SRAM ns per access")
        fig_he.tight_layout()

        # 3) JanS/SRAM ns/access vs local entropies (to show 'little latency benefit')
        fig_ln, axs_ln = plt.subplots(1, 2, figsize=(12, 4.6), sharey=True)
        for ax, col, title in zip(
            axs_ln,
            ["read_local_entropy","write_local_entropy"],
            ["JanS/SRAM ns/access vs Hrl","JanS/SRAM ns/access vs Hwl"]
        ):
            x = A[col].values; y = A["ratio_ns_per_access"].values
            ax.scatter(x, y, alpha=0.8)
            mask = np.isfinite(x) & np.isfinite(y)
            if mask.sum() >= 2:
                m, b = np.polyfit(x[mask], y[mask], 1)
                xs = np.linspace(np.nanmin(x), np.nanmax(x), 100)
                ax.plot(xs, m*xs + b, linestyle="--")
                r = np.corrcoef(x[mask], y[mask])[0,1]
                ax.set_title(f"{title}\nPearson r={r:.3f}")
            ax.grid(True, linestyle=":")
            ax.set_xlabel("entropy (bits)"); 
        axs_ln[0].set_ylabel("JanS/SRAM ns per access")
        fig_ln.tight_layout()
    else:
        print("\n[predictors] Skipped: missing DR read/write totals to build per-access metrics.")
    # ==== END PREDICTORS CHECK ===============================================

    
    print("\n--- Displaying all generated plots ---")
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# --- Parsing Sniper results from: /home/skataoka26/COSC_498/miniMXE/results/sniper_llc_2mb_16w_20251002T020032Z ---
# Sniper parse complete. Merged DataFrame shape: (12, 19)
# Sniper columns found: ['benchmark', 'config', 'time_s', 'energy_exact_J', 'leak_J', 'dyn_exact_nJ', 'dyn_exact_J', 'ipc', 'time_ns', 'l3_miss_rate_pct', 'l3_miss_text', 'l3_accesses_db', 'l3_misses_db', 'l3_read_hits', 'l3_write_hits', 'l3_writebacks', 'l3_evictions', 'l3_misses_custom', 'avg_l3_hit_ns']
# --------------------
#
# --- Parsing DynamoRIO logs from: /home/skataoka26/COSC_498/miniMXE/results_trace/logs with prefix '20250929T203551Z' ---
# Found and processed 12 matching log files.
# DynamoRIO parse complete. DataFrame shape: (12, 40)
# ...

# %%
# JUPYTER CELL — miniMXE viz for Sniper + DynamoRIO
# Requirements: pandas, numpy, matplotlib (no seaborn used)

import os
import re
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------
# ABSOLUTE PATHS (edit if needed)
# -------------------------------
TRACE_LOG_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
SNIPER_DIR    = "/home/skataoka26/COSC_498/miniMXE/results/sniper_roi1000_fixedcap2m_20250927T171235Z"

# -------------------------------
# Helpers
# -------------------------------
def _last_scope_interval_line(log_path: str):
    """Return the last line that contains 'scope=interval' (search from the end)."""
    with open(log_path, "r", errors="ignore") as f:
        lines = f.readlines()
    for line in reversed(lines):
        if "scope=interval" in line:
            return line.strip()
    return None

def _kv_to_dict(kv_line: str):
    """Parse 'a=1,b=2,c=3' (with floats/ints/nan) into a dict."""
    out = {}
    if not kv_line:
        return out
    for part in kv_line.split(","):
        if "=" not in part:
            continue
        k, v = part.split("=", 1)
        k = k.strip()
        v = v.strip()
        if v.lower() == "nan":
            out[k] = float("nan")
            continue
        try:
            # float covers scientific notation
            out[k] = float(v) if (("." in v) or ("e" in v.lower())) else int(v)
        except Exception:
            # fallback to float coercion
            try:
                out[k] = float(v)
            except Exception:
                out[k] = np.nan
    return out

def load_trace_features(trace_dir: str) -> pd.DataFrame:
    """
    Load DynamoRIO rwstats features (from last 'scope=interval') and map to requested labels.
    Returns columns: benchmark, rtotal, runique, f90_tr, Hrg, Hrl, wtotal, wunique, f90_tw, Hwg, Hwl
    """
    rows = []
    for path in sorted(glob.glob(os.path.join(trace_dir, "*_instr.rwstats.log"))):
        base = os.path.basename(path)
        # Expect names like 20250929T203551Z_502_gcc_r_instr.rwstats.log
        m = re.search(r"_(\d+_[^_]+_[rs])_instr\.rwstats\.log$", base)
        if not m:
            # Try looser fallback
            m = re.search(r"_(\d+_[a-z0-9]+_[rs])_instr\.rwstats\.log$", base)
        if not m:
            continue
        benchmark = m.group(1)

        kv = _kv_to_dict(_last_scope_interval_line(path))
        rows.append({
            "benchmark": benchmark,
            "rtotal":    kv.get("read_total", np.nan),
            "runique":   kv.get("read_unique", np.nan),
            # use *L* (lines) footprint 90% to avoid zeros seen in non-L
            "f90_tr":    kv.get("read_footprint90L", kv.get("read_footprint90", np.nan)),
            "Hrg":       kv.get("read_entropy", np.nan),
            "Hrl":       kv.get("read_local_entropy", np.nan),
            "wtotal":    kv.get("write_total", np.nan),
            "wunique":   kv.get("write_unique", np.nan),
            "f90_tw":    kv.get("write_footprint90L", kv.get("write_footprint90", np.nan)),
            "Hwg":       kv.get("write_entropy", np.nan),
            "Hwl":       kv.get("write_local_entropy", np.nan),
        })
    df = pd.DataFrame(rows)
    if not df.empty:
        df = df.drop_duplicates(subset=["benchmark"])
    return df

def load_sniper_results(sniper_dir: str):
    """
    Read energy_bounds.csv and summary.csv from each output_* directory.
    Returns (df_energy, df_summary).
    Also derives llc_dynamic_J from dyn_exact_nJ (nJ -> J).
    """
    energy_rows, summary_rows = [], []
    for outdir in sorted(glob.glob(os.path.join(sniper_dir, "output_*"))):
        eb = os.path.join(outdir, "energy_bounds.csv")
        sm = os.path.join(outdir, "summary.csv")
        if os.path.isfile(eb):
            de = pd.read_csv(eb)
            de["output_dir"] = os.path.abspath(outdir)
            energy_rows.append(de)
        if os.path.isfile(sm):
            ds = pd.read_csv(sm)
            ds["output_dir"] = os.path.abspath(outdir)
            summary_rows.append(ds)

    df_energy  = pd.concat(energy_rows, ignore_index=True) if energy_rows else pd.DataFrame()
    df_summary = pd.concat(summary_rows, ignore_index=True) if summary_rows else pd.DataFrame()

    # derive llc_dynamic_J
    if "dyn_exact_nJ" in df_energy.columns:
        df_energy["llc_dynamic_J"] = pd.to_numeric(df_energy["dyn_exact_nJ"], errors="coerce") * 1e-9
    else:
        df_energy["llc_dynamic_J"] = np.nan

    # normalize must-have columns
    for c in ("time_s", "energy_exact_J", "leak_J", "config", "benchmark"):
        if c not in df_energy.columns:
            df_energy[c] = np.nan if c != "config" else ""

    return df_energy, df_summary

def merge_l3_from_summary(df_energy: pd.DataFrame, df_summary: pd.DataFrame) -> pd.DataFrame:
    """Merge L3 event counts + time from summary into energy table on (benchmark, config)."""
    keep_cfg = ["SRAM", "JanS"]
    s = df_summary[df_summary["config"].isin(keep_cfg)].copy()
    # ensure numeric columns are numeric
    for col in ["l3_accesses_db","l3_misses_db","l3_read_hits","l3_write_hits","l3_writebacks","l3_evictions","time_ns"]:
        if col in s.columns:
            s[col] = pd.to_numeric(s[col], errors="coerce")
    s = s[["benchmark","config","l3_accesses_db","l3_misses_db","l3_read_hits","l3_write_hits","l3_writebacks","l3_evictions","time_ns"]]

    e = df_energy[df_energy["config"].isin(keep_cfg)].copy()
    m = pd.merge(e, s, on=["benchmark","config"], how="left", suffixes=("","_summary"))
    # fill time_s from time_ns if missing
    if "time_s" in m.columns and "time_ns" in m.columns:
        m.loc[m["time_s"].isna() & m["time_ns"].notna(), "time_s"] = m["time_ns"] * 1e-9
    return m

def _multi_get(pivot_df, bench, metric, config):
    """Safe getter for pivoted MultiIndex columns (returns np.nan if missing)."""
    try:
        return float(pivot_df.loc[bench, (metric, config)])
    except Exception:
        return np.nan

# -------------------------------
# Load data
# -------------------------------
df_energy, df_summary = load_sniper_results(SNIPER_DIR)
if df_energy.empty or df_summary.empty:
    raise RuntimeError("Could not find Sniper CSVs under: " + SNIPER_DIR)

df_merged = merge_l3_from_summary(df_energy, df_summary)
df_features = load_trace_features(TRACE_LOG_DIR)

# -------------------------------
# FIGURE 1: Execution time (SRAM vs JanS) by benchmark
# -------------------------------
p = df_merged.pivot_table(index="benchmark",
                          columns="config",
                          values=["time_s","energy_exact_J","llc_dynamic_J","leak_J"],
                          aggfunc="first")

bench_order = sorted(list(p.index))
idx = np.arange(len(bench_order))
width = 0.38

sram_times = [ _multi_get(p, b, "time_s", "SRAM") for b in bench_order ]
jans_times = [ _multi_get(p, b, "time_s", "JanS") for b in bench_order ]

plt.figure(figsize=(12, 6))
plt.bar(idx - width/2, sram_times, width, label="SRAM")
plt.bar(idx + width/2, jans_times, width, label="MRAM (JanS)")
plt.xticks(idx, bench_order, rotation=45, ha="right")
plt.ylabel("Execution time (s)")
plt.title("Execution time: SRAM vs MRAM (JanS)")
plt.legend()
plt.tight_layout()
plt.show()

# -------------------------------
# FIGURE 2: Total LLC energy (SRAM vs JanS) by benchmark
# -------------------------------
sram_E = [ _multi_get(p, b, "energy_exact_J", "SRAM") for b in bench_order ]
jans_E = [ _multi_get(p, b, "energy_exact_J", "JanS") for b in bench_order ]

plt.figure(figsize=(12, 6))
plt.bar(idx - width/2, sram_E, width, label="SRAM")
plt.bar(idx + width/2, jans_E, width, label="MRAM (JanS)")
plt.xticks(idx, bench_order, rotation=45, ha="right")
plt.ylabel("LLC energy (J)")
plt.title("Total LLC energy: SRAM vs MRAM (JanS)")
plt.legend()
plt.tight_layout()
plt.show()

# -------------------------------
# FIGURE 3: LLC energy breakdown (dynamic + leakage), SRAM vs JanS, per benchmark
# -------------------------------
sram_dyn  = [ _multi_get(p, b, "llc_dynamic_J", "SRAM") for b in bench_order ]
jans_dyn  = [ _multi_get(p, b, "llc_dynamic_J", "JanS") for b in bench_order ]
sram_leak = [ _multi_get(p, b, "leak_J",        "SRAM") for b in bench_order ]
jans_leak = [ _multi_get(p, b, "leak_J",        "JanS") for b in bench_order ]

plt.figure(figsize=(12, 6))
plt.bar(idx - width/2, sram_dyn,  width, label="SRAM dyn")
plt.bar(idx - width/2, sram_leak, width, bottom=sram_dyn, label="SRAM leak")
plt.bar(idx + width/2, jans_dyn,  width, label="JanS dyn")
plt.bar(idx + width/2, jans_leak, width, bottom=jans_dyn, label="JanS leak")
plt.xticks(idx, bench_order, rotation=45, ha="right")
plt.ylabel("LLC energy breakdown (J)")
plt.title("LLC energy breakdown: SRAM vs MRAM (JanS)")
plt.legend()
plt.tight_layout()
plt.show()

# -------------------------------
# FIGURE 4: Aggregated LLC event breakdown (SRAM vs JanS)
# -------------------------------
cols_ev = ["l3_read_hits","l3_write_hits","l3_misses_db","l3_writebacks","l3_evictions"]
tmp = df_merged[df_merged["config"].isin(["SRAM","JanS"])][["config"] + cols_ev].copy()
for c in cols_ev:
    tmp[c] = pd.to_numeric(tmp[c], errors="coerce").fillna(0)

agg = tmp.groupby("config")[cols_ev].sum().reindex(["SRAM","JanS"])
labels = ["rd_hits","wr_hits","misses","writebacks","evictions"]
x = np.arange(len(cols_ev))

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, agg.loc["SRAM", cols_ev].values, width, label="SRAM")
plt.bar(x + width/2, agg.loc["JanS", cols_ev].values, width, label="MRAM (JanS)")
plt.xticks(x, labels)
plt.ylabel("Count (aggregated across benchmarks)")
plt.title("LLC event breakdown: SRAM vs MRAM (JanS)")
plt.legend()
plt.tight_layout()
plt.show()

# -------------------------------
# FIGURE 5: Correlation heatmap — features (from DynamoRIO) vs JanS metrics
# Features: rtotal, runique, 90%f_tr, Hrg, Hrl, wtotal, wunique, 90%f_tw, Hwg, Hwl
# Metrics (JanS only): time_s, energy_exact_J, llc_dynamic_J
# -------------------------------
if not df_features.empty:
    jan = df_merged[df_merged["config"] == "JanS"][["benchmark","time_s","energy_exact_J","llc_dynamic_J"]].copy()
    merged = pd.merge(df_features, jan, on="benchmark", how="inner")

    feature_cols = ["rtotal","runique","f90_tr","Hrg","Hrl","wtotal","wunique","f90_tw","Hwg","Hwl"]
    metric_cols  = ["time_s","energy_exact_J","llc_dynamic_J"]

    # compute correlation matrix
    corr = pd.DataFrame(index=feature_cols, columns=metric_cols, dtype=float)
    for f in feature_cols:
        for m in metric_cols:
            corr.loc[f, m] = pd.to_numeric(merged[f], errors="coerce").corr(
                pd.to_numeric(merged[m], errors="coerce"), method="pearson"
            )

    # Friendly y-axis labels to match your screenshot
    ylabels = {
        "rtotal": "rtotal",
        "runique": "runique",
        "f90_tr": "90%f_tr",
        "Hrg": "Hrg",
        "Hrl": "Hrl",
        "wtotal": "wtotal",
        "wunique": "wunique",
        "f90_tw": "90%f_tw",
        "Hwg": "Hwg",
        "Hwl": "Hwl",
    }

    # Heatmap (no seaborn, no custom colors)
    plt.figure(figsize=(7.5, 6))
    data = corr.values.astype(float)
    im = plt.imshow(data, aspect="auto")
    plt.xticks(range(len(metric_cols)), metric_cols)
    plt.yticks(range(len(feature_cols)), [ylabels[c] for c in feature_cols])
    plt.colorbar(im, fraction=0.046, pad=0.04)
    plt.title("Corr(features, JanS metrics)")

    # annotate values
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            val = data[i, j]
            txt = "nan" if (not isinstance(val, (float, np.floating)) or np.isnan(val)) else f"{val:.2f}"
            plt.text(j, i, txt, ha="center", va="center", fontsize=8)

    plt.tight_layout()
    plt.show()
else:
    print("No DynamoRIO features found under:", TRACE_LOG_DIR)

# %%
# JUPYTER CELL — Allocation-oriented correlation analysis (SRAM vs MRAM)
# Requirements: pandas, numpy, matplotlib (NO seaborn). One chart per figure; no custom colors.

import os
import re
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------
# ABSOLUTE PATHS (edit if needed)
# -------------------------------
TRACE_LOG_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
SNIPER_DIR    = "/home/skataoka26/COSC_498/miniMXE/results/sniper_roi1000_fixedcap2m_20250927T171235Z"

# -------------------------------
# Helpers
# -------------------------------
def _last_scope_interval_line(log_path: str):
    """Return the last line that contains 'scope=interval' (search from the end)."""
    with open(log_path, "r", errors="ignore") as f:
        lines = f.readlines()
    for line in reversed(lines):
        if "scope=interval" in line:
            return line.strip()
    return None

def _kv_to_dict(kv_line: str):
    """Parse 'a=1,b=2,c=3' (with floats/ints/nan) into a dict."""
    out = {}
    if not kv_line:
        return out
    for part in kv_line.split(","):
        if "=" not in part:
            continue
        k, v = part.split("=", 1)
        k = k.strip()
        v = v.strip()
        if v.lower() == "nan":
            out[k] = float("nan")
            continue
        try:
            out[k] = float(v) if (("." in v) or ("e" in v.lower())) else int(v)
        except Exception:
            try:
                out[k] = float(v)
            except Exception:
                out[k] = np.nan
    return out

def load_trace_features(trace_dir: str) -> pd.DataFrame:
    """
    Load DynamoRIO rwstats features (from last 'scope=interval') and map to the requested labels.
    Returns: benchmark, rtotal, runique, f90_tr, Hrg, Hrl, wtotal, wunique, f90_tw, Hwg, Hwl
    """
    rows = []
    for path in sorted(glob.glob(os.path.join(trace_dir, "*_instr.rwstats.log"))):
        base = os.path.basename(path)
        m = re.search(r"_(\d+_[^_]+_[rs])_instr\.rwstats\.log$", base)
        if not m:
            m = re.search(r"_(\d+_[a-z0-9]+_[rs])_instr\.rwstats\.log$", base)
        if not m:
            continue
        benchmark = m.group(1)

        kv = _kv_to_dict(_last_scope_interval_line(path))
        rows.append({
            "benchmark": benchmark,
            "rtotal":    kv.get("read_total", np.nan),
            "runique":   kv.get("read_unique", np.nan),
            "f90_tr":    kv.get("read_footprint90L", kv.get("read_footprint90", np.nan)),
            "Hrg":       kv.get("read_entropy", np.nan),
            "Hrl":       kv.get("read_local_entropy", np.nan),
            "wtotal":    kv.get("write_total", np.nan),
            "wunique":   kv.get("write_unique", np.nan),
            "f90_tw":    kv.get("write_footprint90L", kv.get("write_footprint90", np.nan)),
            "Hwg":       kv.get("write_entropy", np.nan),
            "Hwl":       kv.get("write_local_entropy", np.nan),
        })
    df = pd.DataFrame(rows)
    if not df.empty:
        df = df.drop_duplicates(subset=["benchmark"])
    return df

def load_sniper_results(sniper_dir: str):
    """
    Read energy_bounds.csv and summary.csv from each output_* directory.
    Returns (df_energy, df_summary) with llc_dynamic_J derived from dyn_exact_nJ.
    """
    energy_rows, summary_rows = [], []
    for outdir in sorted(glob.glob(os.path.join(sniper_dir, "output_*"))):
        eb = os.path.join(outdir, "energy_bounds.csv")
        sm = os.path.join(outdir, "summary.csv")
        if os.path.isfile(eb):
            de = pd.read_csv(eb)
            de["output_dir"] = os.path.abspath(outdir)
            energy_rows.append(de)
        if os.path.isfile(sm):
            ds = pd.read_csv(sm)
            ds["output_dir"] = os.path.abspath(outdir)
            summary_rows.append(ds)

    df_energy  = pd.concat(energy_rows, ignore_index=True) if energy_rows else pd.DataFrame()
    df_summary = pd.concat(summary_rows, ignore_index=True) if summary_rows else pd.DataFrame()

    if "dyn_exact_nJ" in df_energy.columns:
        df_energy["llc_dynamic_J"] = pd.to_numeric(df_energy["dyn_exact_nJ"], errors="coerce") * 1e-9
    else:
        df_energy["llc_dynamic_J"] = np.nan

    for c in ("time_s","energy_exact_J","leak_J","config","benchmark"):
        if c not in df_energy.columns:
            df_energy[c] = np.nan if c != "config" else ""
    return df_energy, df_summary

def merge_l3_from_summary(df_energy: pd.DataFrame, df_summary: pd.DataFrame) -> pd.DataFrame:
    """Merge L3 event counts + time from summary into energy table on (benchmark, config)."""
    keep_cfg = ["SRAM", "JanS"]
    s = df_summary[df_summary["config"].isin(keep_cfg)].copy()
    for col in ["l3_accesses_db","l3_misses_db","l3_read_hits","l3_write_hits","l3_writebacks","l3_evictions","time_ns"]:
        if col in s.columns:
            s[col] = pd.to_numeric(s[col], errors="coerce")
    s = s[["benchmark","config","l3_accesses_db","l3_misses_db","l3_read_hits","l3_write_hits","l3_writebacks","l3_evictions","time_ns"]]
    e = df_energy[df_energy["config"].isin(keep_cfg)].copy()
    m = pd.merge(e, s, on=["benchmark","config"], how="left", suffixes=("","_summary"))
    if "time_s" in m.columns and "time_ns" in m.columns:
        m.loc[m["time_s"].isna() & m["time_ns"].notna(), "time_s"] = m["time_ns"] * 1e-9
    return m

def _heatmap(df, title):
    """Simple imshow heatmap with numeric annotations."""
    plt.figure(figsize=(8, 6))
    data = df.values.astype(float)
    im = plt.imshow(data, aspect="auto")
    plt.xticks(range(df.shape[1]), df.columns, rotation=0)
    plt.yticks(range(df.shape[0]), df.index)
    plt.colorbar(im, fraction=0.046, pad=0.04)
    plt.title(title)
    # annotate
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            v = data[i, j]
            txt = "nan" if (not isinstance(v, (float, np.floating)) or np.isnan(v)) else f"{v:.2f}"
            plt.text(j, i, txt, ha="center", va="center", fontsize=8)
    plt.tight_layout()
    plt.show()

# -------------------------------
# Load data
# -------------------------------
df_energy, df_summary = load_sniper_results(SNIPER_DIR)
df_all = merge_l3_from_summary(df_energy, df_summary)
df_feat = load_trace_features(TRACE_LOG_DIR)

if df_all.empty:
    raise RuntimeError("Could not load Sniper results from: " + SNIPER_DIR)
if df_feat.empty:
    print("WARNING: No DynamoRIO features found under:", TRACE_LOG_DIR)

# -------------------------------
# Build per-benchmark pivot (SRAM vs JanS)
# -------------------------------
p = df_all.pivot_table(index="benchmark",
                       columns="config",
                       values=["time_s","energy_exact_J","llc_dynamic_J","leak_J"],
                       aggfunc="first")

# helpers
def _get(bench, metric, cfg):
    try:
        return float(p.loc[bench, (metric, cfg)])
    except Exception:
        return np.nan

benchmarks = sorted(list(p.index))

# -------------------------------
# Compute MRAM-vs-SRAM deltas (what drives allocation decisions)
# -------------------------------
rows = []
for b in benchmarks:
    t_sram  = _get(b, "time_s",        "SRAM")
    t_jans  = _get(b, "time_s",        "JanS")
    e_sram  = _get(b, "energy_exact_J","SRAM")
    e_jans  = _get(b, "energy_exact_J","JanS")
    d_sram  = _get(b, "llc_dynamic_J", "SRAM")
    d_jans  = _get(b, "llc_dynamic_J", "JanS")
    l_sram  = _get(b, "leak_J",        "SRAM")
    l_jans  = _get(b, "leak_J",        "JanS")

    # ratios / deltas (guard zeros)
    time_penalty_pct   = 100.0 * ((t_jans - t_sram) / t_sram) if (t_sram and t_sram != 0) else np.nan
    energy_saving_pct  = 100.0 * ((e_sram - e_jans) / e_sram) if (e_sram and e_sram != 0) else np.nan
    dynamic_penalty_pct= 100.0 * ((d_jans - d_sram) / d_sram) if (d_sram and d_sram != 0) else np.nan
    leak_saving_pct    = 100.0 * ((l_sram - l_jans) / l_sram) if (l_sram and l_sram != 0) else np.nan

    ed2p_sram = e_sram * (t_sram**2) if (t_sram is not None and e_sram is not None) else np.nan
    ed2p_jans = e_jans * (t_jans**2) if (t_jans is not None and e_jans is not None) else np.nan
    ed2p_ratio = (ed2p_jans / ed2p_sram) if (ed2p_sram and ed2p_sram != 0) else np.nan

    rows.append({
        "benchmark": b,
        "time_penalty_pct": time_penalty_pct,   # lower is better for MRAM
        "energy_saving_pct": energy_saving_pct, # higher is better for MRAM
        "dynamic_penalty_pct": dynamic_penalty_pct, # lower is better for MRAM
        "leak_saving_pct": leak_saving_pct,     # higher is better for MRAM
        "ed2p_ratio": ed2p_ratio                # < 1 favors MRAM overall
    })

df_delta = pd.DataFrame(rows)

# -------------------------------
# 1) Baseline: features vs JanS absolute metrics
# -------------------------------
if not df_feat.empty:
    jan = df_all[df_all["config"] == "JanS"][["benchmark","time_s","energy_exact_J","llc_dynamic_J"]].copy()
    merged_abs = pd.merge(df_feat, jan, on="benchmark", how="inner")

    feature_cols = ["rtotal","runique","f90_tr","Hrg","Hrl","wtotal","wunique","f90_tw","Hwg","Hwl"]
    metric_cols  = ["time_s","energy_exact_J","llc_dynamic_J"]

    corr_abs = pd.DataFrame(index=feature_cols, columns=metric_cols, dtype=float)
    corr_abs_spearman = pd.DataFrame(index=feature_cols, columns=metric_cols, dtype=float)
    for f in feature_cols:
        xf = pd.to_numeric(merged_abs[f], errors="coerce")
        for m in metric_cols:
            ym = pd.to_numeric(merged_abs[m], errors="coerce")
            corr_abs.loc[f, m] = xf.corr(ym, method="pearson")
            corr_abs_spearman.loc[f, m] = xf.corr(ym, method="spearman")

    _heatmap(corr_abs, "Pearson Corr: features vs JanS absolute metrics")
    _heatmap(corr_abs_spearman, "Spearman Corr: features vs JanS absolute metrics")

# -------------------------------
# 2) Allocation-oriented: features vs MRAM-vs-SRAM deltas
# -------------------------------
if not df_feat.empty:
    merged_delta = pd.merge(df_feat, df_delta, on="benchmark", how="inner")

    delta_metrics = ["time_penalty_pct","energy_saving_pct","dynamic_penalty_pct","leak_saving_pct","ed2p_ratio"]

    corr_delta = pd.DataFrame(index=feature_cols, columns=delta_metrics, dtype=float)
    corr_delta_spearman = pd.DataFrame(index=feature_cols, columns=delta_metrics, dtype=float)

    for f in feature_cols:
        xf = pd.to_numeric(merged_delta[f], errors="coerce")
        for m in delta_metrics:
            ym = pd.to_numeric(merged_delta[m], errors="coerce")
            corr_delta.loc[f, m] = xf.corr(ym, method="pearson")
            corr_delta_spearman.loc[f, m] = xf.corr(ym, method="spearman")

    _heatmap(corr_delta, "Pearson Corr: features vs MRAM advantage/penalty (SRAM↔MRAM deltas)")
    _heatmap(corr_delta_spearman, "Spearman Corr: features vs MRAM advantage/penalty (SRAM↔MRAM deltas)")

    # Print top-3 absolute correlations per allocation metric (Pearson)
    for m in delta_metrics:
        s = corr_delta[m].abs().sort_values(ascending=False)
        print(f"\nTop |corr| features for {m}:")
        print(s.head(3))

    # -------------------------------
    # 3) Scatter: top-3 features vs ed2p_ratio (strongest Pearson |corr|)
    # -------------------------------
    top3 = corr_delta["ed2p_ratio"].abs().sort_values(ascending=False).head(3).index.tolist()
    for f in top3:
        plt.figure(figsize=(6, 4.5))
        x = pd.to_numeric(merged_delta[f], errors="coerce")
        y = pd.to_numeric(merged_delta["ed2p_ratio"], errors="coerce")
        plt.scatter(x, y)
        plt.xlabel(f)
        plt.ylabel("ed2p_ratio (JanS/SRAM)")
        plt.title(f"{f} vs ed2p_ratio")
        # naive least-squares fit line (if enough finite points)
        mask = x.notna() & y.notna()
        if mask.sum() >= 2:
            coef = np.polyfit(x[mask], y[mask], 1)
            xs = np.linspace(np.nanmin(x[mask]), np.nanmax(x[mask]), 100)
            ys = coef[0]*xs + coef[1]
            plt.plot(xs, ys)
        plt.tight_layout()
        plt.show()

else:
    print("No DynamoRIO features found; correlation plots skipped.")

# -------------------------------
# Quick reading guide (printed)
# -------------------------------
print("\nReading guide:")
print("- Positive correlation with energy_saving_pct or leak_saving_pct suggests the feature is MRAM-friendly (energy benefit).")
print("- Negative correlation with time_penalty_pct and ed2p_ratio suggests the feature is MRAM-friendly (performance/overall).")
print("- Features showing the opposite signs are SRAM-friendly.")
# Out:
# Top |corr| features for time_penalty_pct:
# Hrl    0.6137
# Hrg    0.6101
# Hwl    0.4614
# Name: time_penalty_pct, dtype: float64
#
# Top |corr| features for energy_saving_pct:
# runique    0.3921
# f90_tw     0.2067
# f90_tr     0.1761
# Name: energy_saving_pct, dtype: float64
#
# Top |corr| features for dynamic_penalty_pct:
# runique    0.3725
# Hwg        0.3276
# Hrl        0.2653
# Name: dynamic_penalty_pct, dtype: float64
#
# Top |corr| features for leak_saving_pct:
# Hrl    0.5878
# Hrg    0.5825
# Hwl    0.4303
# Name: leak_saving_pct, dtype: float64
#
# Top |corr| features for ed2p_ratio:
# runique    0.3781
# f90_tw     0.2079
# Hrl        0.1925
# Name: ed2p_ratio, dtype: float64
# Reading guide:
# - Positive correlation with energy_saving_pct or leak_saving_pct suggests the feature is MRAM-friendly (energy benefit).
# - Negative correlation with time_penalty_pct and ed2p_ratio suggests the feature is MRAM-friendly (performance/overall).
# ...

# %%
# === miniMXE hybrid-LLC analysis: correlations, tiny model, and SRAM vs MRAM bar charts ===
# Requirements: numpy, pandas, matplotlib (no seaborn). Shows plots inline (no saving).

import os
import re
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------
# ABSOLUTE PATHS (edit if needed)
# -------------------------------
TRACE_LOG_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
SNIPER_DIR    = "/home/skataoka26/COSC_498/miniMXE/results/sniper_llc_2mb_16w_20251002T020032Z"

# Which are "AI" workloads for the subset views
AI_BENCHMARKS = {"531_deepsjeng_r", "541_leela_r"}

# -------------------------------
# Utilities
# -------------------------------
def _last_scope_interval_line(path: str):
    with open(path, "r", errors="ignore") as f:
        lines = f.readlines()
    for line in reversed(lines):
        if "scope=interval" in line:
            return line.strip()
    return None

def _kv_to_dict(kv_line: str):
    out = {}
    if not kv_line:
        return out
    for part in kv_line.split(","):
        if "=" not in part:
            continue
        k, v = part.split("=", 1)
        k, v = k.strip(), v.strip()
        if v.lower() == "nan":
            out[k] = float("nan")
            continue
        try:
            out[k] = float(v) if (("." in v) or ("e" in v.lower())) else int(v)
        except Exception:
            try:
                out[k] = float(v)
            except Exception:
                out[k] = np.nan
    return out

def load_trace_features(trace_dir: str) -> pd.DataFrame:
    """Load last-scope DynamoRIO features and map to the labels we plot."""
    rows = []
    for p in sorted(glob.glob(os.path.join(trace_dir, "*_instr.rwstats.log"))):
        base = os.path.basename(p)
        m = re.search(r"_(\d+_[^_]+_[rs])_instr\.rwstats\.log$", base) or \
            re.search(r"_(\d+_[a-z0-9]+_[rs])_instr\.rwstats\.log$", base)
        if not m:
            continue
        benchmark = m.group(1)
        kv = _kv_to_dict(_last_scope_interval_line(p))
        rows.append({
            "benchmark": benchmark,
            # read side
            "rtotal":   kv.get("read_total", np.nan),
            "runique":  kv.get("read_unique", np.nan),
            "f90_tr":   kv.get("read_footprint90L", kv.get("read_footprint90", np.nan)),
            "Hrg":      kv.get("read_entropy", np.nan),
            "Hrl":      kv.get("read_local_entropy", np.nan),
            # write side
            "wtotal":   kv.get("write_total", np.nan),
            "wunique":  kv.get("write_unique", np.nan),
            "f90_tw":   kv.get("write_footprint90L", kv.get("write_footprint90", np.nan)),
            "Hwg":      kv.get("write_entropy", np.nan),
            "Hwl":      kv.get("write_local_entropy", np.nan),
        })
    df = pd.DataFrame(rows)
    if not df.empty:
        df = df.drop_duplicates(subset=["benchmark"])
    return df

def load_sniper_results(sniper_dir: str):
    """Read energy_bounds.csv and summary.csv from each output_* dir."""
    e_rows, s_rows = [], []
    for outdir in sorted(glob.glob(os.path.join(sniper_dir, "output_*"))):
        eb = os.path.join(outdir, "energy_bounds.csv")
        sm = os.path.join(outdir, "summary.csv")
        if os.path.isfile(eb):
            de = pd.read_csv(eb)
            de["output_dir"] = os.path.abspath(outdir)
            e_rows.append(de)
        if os.path.isfile(sm):
            ds = pd.read_csv(sm)
            ds["output_dir"] = os.path.abspath(outdir)
            s_rows.append(ds)
    df_e  = pd.concat(e_rows, ignore_index=True) if e_rows else pd.DataFrame()
    df_s  = pd.concat(s_rows, ignore_index=True) if s_rows else pd.DataFrame()
    if "dyn_exact_nJ" in df_e.columns:
        df_e["llc_dynamic_J"] = pd.to_numeric(df_e["dyn_exact_nJ"], errors="coerce") * 1e-9
    else:
        df_e["llc_dynamic_J"] = np.nan
    for c in ("time_s","energy_exact_J","leak_J","config","benchmark"):
        if c not in df_e.columns:
            df_e[c] = np.nan if c != "config" else ""
    return df_e, df_s

def merge_l3_from_summary(df_energy: pd.DataFrame, df_summary: pd.DataFrame) -> pd.DataFrame:
    keep_cfg = ["SRAM","JanS"]
    s = df_summary[df_summary["config"].isin(keep_cfg)].copy()
    for col in ["l3_accesses_db","l3_misses_db","l3_read_hits","l3_write_hits","l3_writebacks","l3_evictions","time_ns"]:
        if col in s.columns:
            s[col] = pd.to_numeric(s[col], errors="coerce")
    s = s[["benchmark","config","l3_accesses_db","l3_misses_db","l3_read_hits","l3_write_hits","l3_writebacks","l3_evictions","time_ns"]]
    e = df_energy[df_energy["config"].isin(keep_cfg)].copy()
    m = pd.merge(e, s, on=["benchmark","config"], how="left", suffixes=("","_summary"))
    if "time_s" in m.columns and "time_ns" in m.columns:
        m.loc[m["time_s"].isna() & m["time_ns"].notna(), "time_s"] = m["time_ns"] * 1e-9
    return m

def _heatmap(ax, mat, title, vmin=-1, vmax=1):
    data = mat.values.astype(float)
    im = ax.imshow(data, aspect="auto", vmin=vmin, vmax=vmax)
    ax.set_xticks(range(mat.shape[1])); ax.set_xticklabels(mat.columns, rotation=0)
    ax.set_yticks(range(mat.shape[0])); ax.set_yticklabels(mat.index)
    ax.set_title(title)
    # annotate
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            v = data[i, j]
            txt = "nan" if (not isinstance(v, (float, np.floating)) or np.isnan(v)) else f"{v:.2f}"
            ax.text(j, i, txt, ha="center", va="center", fontsize=8)
    return im

def _corr(df, features, targets, method="pearson"):
    out = pd.DataFrame(index=features, columns=targets, dtype=float)
    for f in features:
        xf = pd.to_numeric(df[f], errors="coerce")
        for t in targets:
            yt = pd.to_numeric(df[t], errors="coerce")
            out.loc[f, t] = xf.corr(yt, method=method)
    return out

# Standardization helpers
def zscore_train(x):
    mu = np.nanmean(x); sd = np.nanstd(x) if np.nanstd(x) > 0 else 1.0
    return (x - mu) / sd, mu, sd

def zscore_apply(x, mu, sd):
    sd = 1.0 if (sd is None or sd == 0) else sd
    return (x - mu) / sd

# Logistic regression (Newton) with L2 (no sklearn)
def logistic_newton_l2(X, y, lam=1.0, max_iter=100, tol=1e-6):
    # X: (n, p) with bias column included; y in {0,1}
    n, p = X.shape
    w = np.zeros(p)
    I = np.eye(p); I[0,0] = 0.0  # don't regularize intercept
    for _ in range(max_iter):
        z = X @ w
        p_hat = 1.0 / (1.0 + np.exp(-z))
        W = p_hat * (1 - p_hat)             # (n,)
        # gradient and Hessian (L2)
        grad = X.T @ (p_hat - y) + lam * (I @ w)
        # build Hessian
        H = (X.T * W) @ X + lam * I         # X.T * W -> broadcasts row-wise
        try:
            step = np.linalg.solve(H, grad)
        except np.linalg.LinAlgError:
            step = np.linalg.pinv(H) @ grad
        w_new = w - step
        if np.linalg.norm(w_new - w) < tol:
            w = w_new; break
        w = w_new
    return w

# -------------------------------
# Load & prepare data
# -------------------------------
df_energy, df_summary = load_sniper_results(SNIPER_DIR)
df_all = merge_l3_from_summary(df_energy, df_summary)
df_feat = load_trace_features(TRACE_LOG_DIR)
assert not df_all.empty and not df_feat.empty, "Missing data — check absolute paths."

# Pivot for deltas & components
piv = df_all.pivot_table(index="benchmark",
                         columns="config",
                         values=["time_s","energy_exact_J","llc_dynamic_J","leak_J"],
                         aggfunc="first")
benchmarks = sorted(list(piv.index))

def _get(b, metric, cfg):
    try: return float(piv.loc[b, (metric, cfg)])
    except Exception: return np.nan

rows_delta = []
for b in benchmarks:
    tS, tM = _get(b,"time_s","SRAM"), _get(b,"time_s","JanS")
    eS, eM = _get(b,"energy_exact_J","SRAM"), _get(b,"energy_exact_J","JanS")
    dS, dM = _get(b,"llc_dynamic_J","SRAM"), _get(b,"llc_dynamic_J","JanS")
    lS, lM = _get(b,"leak_J","SRAM"), _get(b,"leak_J","JanS")

    time_penalty_pct    = 100.0*((tM - tS)/tS) if (tS and tS != 0) else np.nan
    energy_saving_pct   = 100.0*((eS - eM)/eS) if (eS and eS != 0) else np.nan
    dynamic_penalty_pct = 100.0*((dM - dS)/dS) if (dS and dS != 0) else np.nan
    leak_saving_pct     = 100.0*((lS - lM)/lS) if (lS and lS != 0) else np.nan
    ed2p_ratio          = (eM*(tM**2))/(eS*(tS**2)) if (tS and eS and (eS*(tS**2)) != 0) else np.nan

    rows_delta.append({
        "benchmark": b,
        "time_penalty_pct": time_penalty_pct,
        "energy_saving_pct": energy_saving_pct,
        "dynamic_penalty_pct": dynamic_penalty_pct,
        "leak_saving_pct": leak_saving_pct,
        "ed2p_ratio": ed2p_ratio
    })
df_delta = pd.DataFrame(rows_delta)

# Merge JanS absolutes for correlation
jan_abs = df_all[df_all["config"]=="JanS"][["benchmark","time_s","energy_exact_J","llc_dynamic_J"]].copy()
merged_abs_all   = pd.merge(df_feat, jan_abs, on="benchmark", how="inner")
merged_delta_all = pd.merge(df_feat, df_delta, on="benchmark", how="inner")

# Build AI subsets
merged_abs_ai   = merged_abs_all[merged_abs_all["benchmark"].isin(AI_BENCHMARKS)].copy()
merged_delta_ai = merged_delta_all[merged_delta_all["benchmark"].isin(AI_BENCHMARKS)].copy()

# Add normalized features & composites (computed globally for display — CV fold uses train-only z-scores)
def add_normals_and_composites(df):
    df = df.copy()
    total_acc = pd.to_numeric(df["rtotal"], errors="coerce") + pd.to_numeric(df["wtotal"], errors="coerce")
    df["read_uniqueness"] = pd.to_numeric(df["runique"], errors="coerce") / (pd.to_numeric(df["rtotal"], errors="coerce") + 1e-9)
    df["write_share"]     = pd.to_numeric(df["wtotal"],  errors="coerce") / (total_acc + 1e-9)
    # Global z-scores (for display; CV uses train-only)
    def zcol(x): 
        x = pd.to_numeric(x, errors="coerce"); m,s = x.mean(), x.std(ddof=0); s = s if s>0 else 1.0; 
        return (x - m)/s
    df["z_runique"] = zcol(df["runique"])
    df["z_Hrg"] = zcol(df["Hrg"])
    df["z_Hrl"] = zcol(df["Hrl"])
    df["z_wunique"] = zcol(df["wunique"])
    df["z_Hwg"] = zcol(df["Hwg"])
    df["WEI"] = df["z_Hwg"] + df["z_wunique"]
    df["RS"]  = df["z_runique"] - df["z_Hrg"]
    return df

merged_abs_all   = add_normals_and_composites(merged_abs_all)
merged_delta_all = add_normals_and_composites(merged_delta_all)
merged_abs_ai    = add_normals_and_composites(merged_abs_ai)
merged_delta_ai  = add_normals_and_composites(merged_delta_ai)

# -------------------------------
# 1) Correlation grids (All vs AI), Pearson + Spearman
# -------------------------------
FEATURES = ["rtotal","runique","f90_tr","Hrg","Hrl","wtotal","wunique","f90_tw","Hwg","Hwl",
            "read_uniqueness","write_share","WEI","RS"]
ABS_METRICS    = ["time_s","energy_exact_J","llc_dynamic_J"]
DELTA_METRICS  = ["time_penalty_pct","energy_saving_pct","dynamic_penalty_pct","leak_saving_pct","ed2p_ratio"]

def _grid_corr(all_df, ai_df, features, metrics, title_base):
    # Pearson
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    mat_all = _corr(all_df, features, metrics, method="pearson")
    mat_ai  = _corr(ai_df,  features, metrics, method="pearson") if not ai_df.empty else pd.DataFrame(index=features, columns=metrics)
    im1 = _heatmap(axes[0], mat_all, f"{title_base} — ALL (Pearson, N={all_df['benchmark'].nunique()})")
    im2 = _heatmap(axes[1], mat_ai,  f"{title_base} — AI (Pearson, N={ai_df['benchmark'].nunique()})")
    fig.colorbar(im2, ax=axes.ravel().tolist(), fraction=0.046, pad=0.04)
    plt.tight_layout(); plt.show()

    # Spearman
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    mat_all_s = _corr(all_df, features, metrics, method="spearman")
    mat_ai_s  = _corr(ai_df,  features, metrics, method="spearman") if not ai_df.empty else pd.DataFrame(index=features, columns=metrics)
    im1 = _heatmap(axes[0], mat_all_s, f"{title_base} — ALL (Spearman, N={all_df['benchmark'].nunique()})")
    im2 = _heatmap(axes[1], mat_ai_s,  f"{title_base} — AI (Spearman, N={ai_df['benchmark'].nunique()})")
    fig.colorbar(im2, ax=axes.ravel().tolist(), fraction=0.046, pad=0.04)
    plt.tight_layout(); plt.show()

_grid_corr(merged_abs_all,   merged_abs_ai,   FEATURES, ABS_METRICS,   "Features vs JanS metrics")
_grid_corr(merged_delta_all, merged_delta_ai, FEATURES, DELTA_METRICS, "Features vs MRAM advantage/penalty (SRAM↔MRAM deltas)")

# -------------------------------
# 2) Tiny model for allocation (ed2p_ratio < 1) with LOBO CV
# -------------------------------
# Base features + normalized + composites
MODEL_BASE = ["runique","Hrg","Hrl","wunique","Hwg","read_uniqueness","write_share","WEI","RS"]

# Build per-benchmark table with label and these features
df_model = pd.merge(merged_delta_all[["benchmark","ed2p_ratio","time_penalty_pct"] + MODEL_BASE],
                    merged_delta_all[["benchmark"]], on="benchmark", how="left").drop_duplicates("benchmark")
df_model["label_mram_beneficial"] = (df_model["ed2p_ratio"] < 1.0).astype(int)

# Leave-one-benchmark-out
preds, trues, test_bench, time_penalties = [], [], [], []
coefs = []
for b in df_model["benchmark"].unique():
    train = df_model[df_model["benchmark"] != b].copy()
    test  = df_model[df_model["benchmark"] == b].copy()
    y_tr = train["label_mram_beneficial"].values.astype(float)
    # Build X with bias and z-scores computed on TRAIN ONLY
    feat_list = MODEL_BASE
    # Train z-scores
    zs_params = {}
    X_tr_cols = []
    for f in feat_list:
        x = pd.to_numeric(train[f], errors="coerce").values.astype(float)
        xz, mu, sd = zscore_train(x)
        zs_params[f] = (mu, sd)
        X_tr_cols.append(xz)
    X_tr = np.column_stack([np.ones(len(train))] + X_tr_cols)
    # Fit
    w = logistic_newton_l2(X_tr, y_tr, lam=1.0, max_iter=200, tol=1e-6)
    coefs.append(w)
    # Apply to test
    X_te_cols = []
    for f in feat_list:
        mu, sd = zs_params[f]
        xv = pd.to_numeric(test[f], errors="coerce").values.astype(float)
        X_te_cols.append(zscore_apply(xv, mu, sd))
    X_te = np.column_stack([np.ones(len(test))] + X_te_cols)
    p = 1.0/(1.0 + np.exp(-(X_te @ w)))
    preds.extend(list(p))
    trues.extend(list(test["label_mram_beneficial"].values.astype(float)))
    test_bench.extend(list(test["benchmark"].values))
    time_penalties.extend(list(test["time_penalty_pct"].values.astype(float)))

# Report aggregated CV results
preds = np.array(preds); trues = np.array(trues); time_penalties = np.array(time_penalties)
yhat = (preds >= 0.5).astype(int)

tp = int(((yhat==1) & (trues==1)).sum())
tn = int(((yhat==0) & (trues==0)).sum())
fp = int(((yhat==1) & (trues==0)).sum())
fn = int(((yhat==0) & (trues==1)).sum())
acc = (tp+tn)/len(trues) if len(trues)>0 else float('nan')

print("\nLOBO CV — tiny logistic model (ed2p_ratio < 1):")
print(f"Confusion matrix (τ=0.5): TP={tp}, FP={fp}, FN={fn}, TN={tn}, ACC={acc:.2f}")
print("Per-benchmark predictions (p(MRAM-beneficial)):")
for b, p_, y in zip(test_bench, preds, trues):
    print(f"  {b:>18s}  p={p_:6.3f}  true={int(y)}")

# Median coefficients across folds (for interpretability)
W = np.vstack(coefs) if len(coefs)>0 else np.zeros((1, len(MODEL_BASE)+1))
w_med = np.median(W, axis=0)
print("\nMedian coefficients across folds (log-odds):")
print("  (bias) = {:.3f}".format(w_med[0]))
for f, c in zip(MODEL_BASE, w_med[1:]):
    print("  {:>16s} : {: .3f}".format(f, c))

# Choose τ to keep average time_penalty among predicted MRAM <= bound (5%, then 3% & 10% for context)
def choose_tau_for_time_penalty(pred_probs, penalties, bound_pct=5.0):
    taus = np.linspace(0.1, 0.9, 81)
    best_tau, best_energy = None, -1e9
    for tau in taus:
        sel = pred_probs >= tau
        if sel.sum() == 0:
            continue
        mean_pen = np.nanmean(penalties[sel])
        if np.isnan(mean_pen) or mean_pen > bound_pct:
            continue
        # proxy: maximize share moved to MRAM subject to penalty bound
        moved = sel.mean()
        if moved > best_energy:
            best_energy, best_tau = moved, tau
    return best_tau

for bound in [3.0, 5.0, 10.0]:
    tau = choose_tau_for_time_penalty(preds, time_penalties, bound_pct=bound)
    if tau is not None:
        sel = preds >= tau
        mean_pen = np.nanmean(time_penalties[sel]) if sel.any() else float('nan')
        print(f"\nRecommended τ for mean time_penalty ≤ {bound:.0f}%: τ={tau:.2f} "
              f"(fraction sent to MRAM={sel.mean():.2f}, mean_penalty={mean_pen:.2f}%)")
    else:
        print(f"\nNo τ found satisfying mean time_penalty ≤ {bound:.0f}% (dataset too small or penalties too high).")

# -------------------------------
# 3) Conventional bar charts (SRAM vs MRAM)
# -------------------------------
# Build tidy per-benchmark table for plotting
df_plot = df_all[df_all["config"].isin(["SRAM","JanS"])][
    ["benchmark","config","time_s","energy_exact_J","llc_dynamic_J","leak_J",
     "l3_read_hits","l3_write_hits","l3_misses_db","l3_writebacks","l3_evictions"]
].copy()

# --- (i) Exec time per benchmark (SRAM vs MRAM) ---
bench_order = sorted(df_plot["benchmark"].unique())
idx = np.arange(len(bench_order)); width = 0.38

def _get_metric(b, cfg, col):
    v = df_plot[(df_plot["benchmark"]==b) & (df_plot["config"]==cfg)][col]
    return float(v.values[0]) if len(v)>0 else np.nan

sram_t = [_get_metric(b,"SRAM","time_s") for b in bench_order]
jans_t = [_get_metric(b,"JanS","time_s") for b in bench_order]

plt.figure(figsize=(12,6))
plt.bar(idx - width/2, sram_t, width, label="SRAM")
plt.bar(idx + width/2, jans_t, width, label="MRAM (JanS)")
plt.xticks(idx, bench_order, rotation=45, ha="right")
plt.ylabel("Execution time (s)"); plt.title("Execution time: SRAM vs MRAM (JanS)")
plt.legend(); plt.tight_layout(); plt.show()

# --- (ii) Total LLC energy per benchmark (SRAM vs MRAM) ---
sram_E = [_get_metric(b,"SRAM","energy_exact_J") for b in bench_order]
jans_E = [_get_metric(b,"JanS","energy_exact_J") for b in bench_order]

plt.figure(figsize=(12,6))
plt.bar(idx - width/2, sram_E, width, label="SRAM")
plt.bar(idx + width/2, jans_E, width, label="MRAM (JanS)")
plt.xticks(idx, bench_order, rotation=45, ha="right")
plt.ylabel("LLC energy (J)"); plt.title("Total LLC energy: SRAM vs MRAM (JanS)")
plt.legend(); plt.tight_layout(); plt.show()

# --- (iii) LLC energy breakdown (dynamic + leakage), SRAM vs MRAM, per benchmark ---
sram_dyn  = [_get_metric(b,"SRAM","llc_dynamic_J") for b in bench_order]
jans_dyn  = [_get_metric(b,"JanS","llc_dynamic_J") for b in bench_order]
sram_leak = [_get_metric(b,"SRAM","leak_J")        for b in bench_order]
jans_leak = [_get_metric(b,"JanS","leak_J")        for b in bench_order]

plt.figure(figsize=(12,6))
plt.bar(idx - width/2, sram_dyn,  width, label="SRAM dynamic")
plt.bar(idx - width/2, sram_leak, width, bottom=sram_dyn, label="SRAM leakage")
plt.bar(idx + width/2, jans_dyn,  width, label="JanS dynamic")
plt.bar(idx + width/2, jans_leak, width, bottom=jans_dyn, label="JanS leakage")
plt.xticks(idx, bench_order, rotation=45, ha="right")
plt.ylabel("LLC energy breakdown (J)"); plt.title("LLC energy breakdown: SRAM vs MRAM (JanS)")
plt.legend(); plt.tight_layout(); plt.show()

# --- (iv) Aggregated LLC events (counts) across all benchmarks ---
ev_cols = ["l3_read_hits","l3_write_hits","l3_misses_db","l3_writebacks","l3_evictions"]
agg = df_plot.groupby("config")[ev_cols].sum().reindex(["SRAM","JanS"])
x = np.arange(len(ev_cols))
plt.figure(figsize=(10,6))
plt.bar(x - width/2, agg.loc["SRAM", ev_cols].values, width, label="SRAM")
plt.bar(x + width/2, agg.loc["JanS", ev_cols].values, width, label="MRAM (JanS)")
plt.xticks(x, ["rd_hits","wr_hits","misses","writebacks","evictions"])
plt.ylabel("Count (aggregated)"); plt.title("LLC event breakdown: SRAM vs MRAM (aggregated)")
plt.legend(); plt.tight_layout(); plt.show()

# --- (v) Per-benchmark % improvements/penalties (energy_saving_pct, time_penalty_pct) ---
order = benchmarks
dp = df_delta.set_index("benchmark").loc[order]
plt.figure(figsize=(12,6))
plt.bar(np.arange(len(order)) - width/2, dp["energy_saving_pct"].values, width, label="Energy saving % (MRAM vs SRAM)")
plt.bar(np.arange(len(order)) + width/2, dp["time_penalty_pct"].values,  width, label="Time penalty % (MRAM vs SRAM)")
plt.axhline(0, linestyle="--")
plt.xticks(np.arange(len(order)), order, rotation=45, ha="right")
plt.ylabel("Percent (%)"); plt.title("MRAM vs SRAM: energy saving and time penalty by benchmark")
plt.legend(); plt.tight_layout(); plt.show()

print("\nDone. The figures above include: time, total energy, dynamic/leak breakdown, event breakdown, and % deltas.")
print("Model outputs above include LOBO CV confusion matrix, per-benchmark predictions, median weights, and recommended τ for time-penalty bounds.")
# Out:
# /home/skataoka26/.local/lib/python3.9/site-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /home/skataoka26/.local/lib/python3.9/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /tmp/ipykernel_2085289/3914182220.py:268: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_2085289/3914182220.py:277: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(); plt.show()
# LOBO CV — tiny logistic model (ed2p_ratio < 1):
# Confusion matrix (τ=0.5): TP=6, FP=0, FN=0, TN=0, ACC=1.00
# Per-benchmark predictions (p(MRAM-beneficial)):
#      500_perlbench_r  p= 1.000  true=1
#            502_gcc_r  p= 1.000  true=1
# ...

# %%
#!/usr/bin/env python3

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Absolute paths (edit if needed)
# -----------------------------
RUN_IDS = {
    "Baseline (JanS, 2MB, 16 Way)": "sniper_roi1000_fixedcap2m_20250927T171235Z",
    "JanS, 2MB, 8 Way": "sniper_assoc_jans2mb_8way_20250929T024544Z",
    "JanS, 16MB, 16 Way": "sniper_cap_equal_16mb_20250929T024544Z",
    "JanS, 32MB, 16 Way": "sniper_cap_equal_32mb_20250929T024544Z",
    "ChungS, 2MB, 16 Way": "sniper_dev_chungs_2mb_20250929T024350Z",
    "UmekiS, 2MB, 16 Way": "sniper_dev_umekis_2mb_20250929T024536Z",
    "XueS, 2MB, 16 Way": "sniper_dev_xues_2mb_20250929T024537Z"
}
SNIPER_RESULTS_DIR= f"/home/skataoka26/COSC_498/miniMXE/results/{RUN_IDS['Baseline (JanS, 2MB, 16 Way)']}"
# sniper_llc_2mb_16w_20251002T020032Z
SNIPER_RESULTS_DIR= "/home/skataoka26/COSC_498/miniMXE/results/sniper_llc_2mb_16w_20251002T020032Z"
DYNAMORIO_LOGS_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
TIMESTAMP_PREFIX    = "20250929T203551Z"  # prefix used in DynamoRIO filenames

# -----------------------------
# Utilities
# -----------------------------
def safe_div(numer, denom):
    numer = np.array(numer, dtype=float)
    denom = np.array(denom, dtype=float)
    with np.errstate(divide='ignore', invalid='ignore'):
        out = np.where((denom > 0) & np.isfinite(denom), numer / denom, np.nan)
    return out

def geomean(values):
    vals = np.array([v for v in np.ravel(values) if v > 0 and np.isfinite(v)], dtype=float)
    return float(np.exp(np.mean(np.log(vals)))) if len(vals) else np.nan

# --- NEW: statistics helpers for bootstrap / partial correlations / LOO stability
def bootstrap_spearman_ci(x, y, n_boot=10000, alpha=0.05, random_state=0):
    """
    Compute Spearman correlation and bootstrap percentile CI.
    x,y: 1-D arrays (can contain nans).
    Returns (observed_spearman, lower, upper, n_obs)
    """
    rng = np.random.default_rng(random_state)
    mask = np.isfinite(x) & np.isfinite(y)
    x0 = np.array(x)[mask]
    y0 = np.array(y)[mask]
    n = len(x0)
    if n < 3:
        return (np.nan, np.nan, np.nan, n)
    # observed
    obs = pd.Series(x0).corr(pd.Series(y0), method="spearman")
    # bootstrap
    boots = []
    for _ in range(n_boot):
        idx = rng.integers(0, n, n)
        xi = x0[idx]
        yi = y0[idx]
        # if all equal or constant, result may be nan; skip those
        try:
            r = pd.Series(xi).corr(pd.Series(yi), method="spearman")
        except Exception:
            r = np.nan
        boots.append(r)
    boots = np.array([b for b in boots if np.isfinite(b)])
    if boots.size == 0:
        return (obs, np.nan, np.nan, n)
    lo = np.percentile(boots, 100 * alpha / 2.0)
    hi = np.percentile(boots, 100 * (1 - alpha/2.0))
    return (obs, lo, hi, n)

def partial_corr_pearson(x, y, controls):
    """
    Partial Pearson correlation between x and y controlling for columns in controls (2D array or DataFrame).
    Uses residualization (OLS).
    Returns Pearson r and N used.
    """
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)
    if isinstance(controls, pd.DataFrame):
        C = controls.values.astype(float)
    else:
        C = np.asarray(controls, dtype=float)
    mask = np.isfinite(x) & np.isfinite(y) & np.all(np.isfinite(C), axis=1)
    x0 = x[mask]; y0 = y[mask]; C0 = C[mask]
    if len(x0) < 3:
        return (np.nan, len(x0))
    # Add intercept
    Xc = np.column_stack([np.ones(len(C0)), C0])
    # regress x on controls
    beta_x, *_ = np.linalg.lstsq(Xc, x0, rcond=None)
    resid_x = x0 - Xc.dot(beta_x)
    beta_y, *_ = np.linalg.lstsq(Xc, y0, rcond=None)
    resid_y = y0 - Xc.dot(beta_y)
    r = np.corrcoef(resid_x, resid_y)[0,1]
    return (r, len(x0))

def loo_regression_stability(y, X):
    """
    Leave-one-out coefficient stability for linear regression of y ~ X (no intercept automatically added).
    Returns dict with 'coefs' array shape (n_points, n_features), and 'mean_coef', 'std_coef'
    We add intercept inside.
    """
    y = np.asarray(y, dtype=float)
    X = np.asarray(X, dtype=float)
    n = len(y)
    if n < 3 or X.shape[0] != n:
        return None
    coefs = []
    for i in range(n):
        mask = np.ones(n, dtype=bool)
        mask[i] = False
        Xi = X[mask]; yi = y[mask]
        Xi2 = np.column_stack([np.ones(Xi.shape[0]), Xi])
        try:
            beta, *_ = np.linalg.lstsq(Xi2, yi, rcond=None)
            coefs.append(beta)  # intercept + coefs
        except Exception:
            coefs.append(np.full(Xi2.shape[1], np.nan))
    coefs = np.vstack(coefs)
    return {
        "coefs": coefs,
        "mean_coef": np.nanmean(coefs, axis=0),
        "std_coef": np.nanstd(coefs, axis=0)
    }

# -----------------------------
# Parsing helpers
# -----------------------------
def parse_sniper(base_dir):
    """
    Walk output_* folders, read summary.csv and energy_bounds.csv,
    merge them on (benchmark, config). Return a tidy DataFrame.
    Besides the core columns, we opportunistically keep LLC event counters
    (e.g., l3/llc accesses, hits/misses, reads/writes) if they exist.
    """
    energy_rows = []
    summary_rows = []
    print(f"--- Parsing Sniper results from: {base_dir} ---")
    for root, _, files in os.walk(base_dir):
        if os.path.basename(root).startswith("output_") and "summary.csv" in files and "energy_bounds.csv" in files:
            energy_path  = os.path.join(root, "energy_bounds.csv")
            summary_path = os.path.join(root, "summary.csv")

            e = pd.read_csv(energy_path)
            s = pd.read_csv(summary_path)

            # Keep columns we actually use from energy
            e_keep = [
                "benchmark", "config", "time_s",
                "energy_exact_J", "leak_J", "dyn_exact_nJ"
            ]
            e = e[[c for c in e_keep if c in e.columns]].copy()

            # Base columns we want from summary
            s_base = ["benchmark", "config", "ipc", "time_ns", "l3_miss_rate_pct"]
            keep_s = [c for c in s_base if c in s.columns]

            # Try to keep any plausible LLC event columns automatically
            # (we won't fail if they're absent)
            for col in s.columns:
                cl = col.lower()
                if ("l3" in cl or "llc" in cl) and (
                    "access" in cl or "read" in cl or "write" in cl or "hit" in cl or "miss" in cl or "evict" in cl
                ):
                    if col not in keep_s:
                        keep_s.append(col)

            s = s[keep_s].copy()

            # Numeric coercion
            for col in ["time_s", "energy_exact_J", "leak_J", "dyn_exact_nJ"]:
                if col in e.columns:
                    e[col] = pd.to_numeric(e[col], errors="coerce")

            for col in s.columns:
                if col not in ("benchmark", "config"):
                    s[col] = pd.to_numeric(s[col], errors="coerce")

            # Convert nJ -> J
            if "dyn_exact_nJ" in e.columns:
                e["dyn_exact_J"] = e["dyn_exact_nJ"] * 1e-9

            energy_rows.append(e)
            summary_rows.append(s)

    if not energy_rows or not summary_rows:
        raise FileNotFoundError(
            "Could not find summary.csv and energy_bounds.csv in output_* directories under: " + base_dir
        )

    E = pd.concat(energy_rows, ignore_index=True)
    S = pd.concat(summary_rows, ignore_index=True)

    df = pd.merge(E, S, on=["benchmark", "config"], how="inner")

    # minimal sanity
    df = df.dropna(subset=["benchmark", "config", "time_s", "energy_exact_J"])
    print(f"Sniper parse complete. Merged DataFrame shape: {df.shape}")
    print(f"Sniper columns found: {df.columns.tolist()}")
    print("-" * 20)
    return df


def _kv_from_line(s: str) -> dict:
    """Extract numeric key=value pairs from one rwstats line. 'scope' handled separately."""
    kv = {}
    m = re.search(r"\bscope=(\w+)", s)
    if m:
        kv["scope"] = m.group(1)

    for k, v in re.findall(r"([A-Za-z0-9_]+)=([+\-]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+\-]?\d+)?|nan)", s):
        try:
            kv[k] = float("nan") if v.lower() == "nan" else float(v)
        except Exception:
            pass
    return kv


def parse_dynamorio(logs_dir, ts_prefix):
    """
    Parse DynamoRIO log files. For each file, grab the LAST stats-like line
    (lines contain 'scope='). File name format: {ts_prefix}_<benchmark>_instr.rwstats.log
    """
    rows = []
    print(f"\n--- Parsing DynamoRIO logs from: {logs_dir} with prefix '{ts_prefix}' ---")
    if not os.path.isdir(logs_dir):
        print("DynamoRIO logs directory not found. Returning empty DataFrame.")
        print("-" * 20)
        return pd.DataFrame()

    found_files = 0
    for fname in os.listdir(logs_dir):
        if not (fname.startswith(ts_prefix) and fname.endswith("_instr.rwstats.log")):
            continue
        m = re.match(rf"{re.escape(ts_prefix)}_(.+?)_instr\.rwstats\.log$", fname)
        if not m:
            continue
        
        found_files += 1
        benchmark = m.group(1)
        fpath = os.path.join(logs_dir, fname)

        last = None
        with open(fpath, "r", errors="ignore") as f:
            for line in f:
                t = line.strip()
                if "scope=" in t and "=" in t:
                    last = t

        if not last:
            continue

        kv = _kv_from_line(last)
        kv["benchmark"] = benchmark
        rows.append(kv)

    print(f"Found and processed {found_files} matching log files.")
    df = pd.DataFrame(rows) if rows else pd.DataFrame()
    if not df.empty:
        print(f"DynamoRIO parse complete. DataFrame shape: {df.shape}")
        print(f"DynamoRIO columns found: {df.columns.tolist()}")
    else:
        print("DynamoRIO parse complete. No data found, returning empty DataFrame.")
    print("-" * 20)
    return df


# -----------------------------
# Event detection (for per-event view)
# -----------------------------
def detect_llc_events_per_config(df_config):
    """
    Best-effort extraction of an LLC event count from Sniper summary columns
    for a (benchmark-indexed, single-config) DataFrame.
    Priority:
      1) total 'llc_accesses' or 'l3_accesses'
      2) sum of reads+writes
      3) sum of hits+misses
    Returns: pd.Series (index=benchmark) or None if nothing found.
    """
    if df_config is None or df_config.empty:
        return None

    cols = {c.lower(): c for c in df_config.columns}

    # 1) Direct totals
    for key in ["llc_accesses", "l3_accesses", "roi_llc_accesses", "roi_l3_accesses"]:
        if key in cols:
            ser = pd.to_numeric(df_config[cols[key]], errors="coerce")
            if ser.notna().any():
                print(f"[Event Detection] Found total LLC events using column: '{cols[key]}'")
                return ser

    # 2) Reads + writes
    read_keys  = [k for k in cols if ("read"  in k or "rd_" in k) and ("l3" in k or "llc" in k)]
    write_keys = [k for k in cols if ("write" in k or "wr_" in k) and ("l3" in k or "llc" in k)]
    if read_keys and write_keys:
        # choose the most populated pair
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for rk in read_keys:
            for wk in write_keys:
                s = pd.to_numeric(df_config[cols[rk]], errors="coerce") + pd.to_numeric(df_config[cols[wk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[rk], cols[wk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing reads+writes: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    # 3) Hits + misses
    hit_keys   = [k for k in cols if ("hit"   in k) and ("l3" in k or "llc" in k)]
    miss_keys  = [k for k in cols if ("miss"  in k) and ("l3" in k or "llc" in k)]
    if hit_keys and miss_keys:
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for hk in hit_keys:
            for mk in miss_keys:
                s = pd.to_numeric(df_config[cols[hk]], errors="coerce") + pd.to_numeric(df_config[cols[mk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[hk], cols[mk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing hits+misses: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    print("[Event Detection] No suitable LLC event columns found.")
    return None


def build_mem_instruction_counts(dr_df, benchmarks):
    """
    From DynamoRIO, create a per-benchmark count of memory instructions
    (reads + writes). Returns (Series or None).
    """
    if dr_df is None or dr_df.empty:
        return None

    dr = dr_df.set_index("benchmark")
    read_col  = None
    write_col = None

    # common column names
    for cand in ["read_total", "loads", "ld_total", "mem_reads"]:
        if cand in dr.columns:
            read_col = cand
            break
    for cand in ["write_total", "stores", "st_total", "mem_writes"]:
        if cand in dr.columns:
            write_col = cand
            break

    if read_col is None or write_col is None:
        print("[Mem Instr] Could not find read/write total columns in DynamoRIO data.")
        return None

    print(f"[Mem Instr] Calculating memory instructions from DR columns: '{read_col}' + '{write_col}'")
    mem = pd.to_numeric(dr[read_col], errors="coerce") + pd.to_numeric(dr[write_col], errors="coerce")
    mem = mem.reindex(benchmarks)
    if mem.notna().any():
        return mem
    return None


# -----------------------------
# Plot helpers
# -----------------------------
def grouped_barh(ax, labels, a_values, b_values, a_label, b_label, title, x_label):
    y = np.arange(len(labels))
    h = 0.38
    ax.barh(y - h/2, a_values, height=h, label=a_label)
    ax.barh(y + h/2, b_values, height=h, label=b_label)
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()  # top item at top
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)

def corr_heatmap(ax, matrix, row_labels, col_labels, title):
    im = ax.imshow(matrix, aspect="auto", vmin=-1, vmax=1, cmap="coolwarm")
    ax.set_yticks(np.arange(len(row_labels)))
    ax.set_yticklabels(row_labels)
    ax.set_xticks(np.arange(len(col_labels)))
    ax.set_xticklabels(col_labels, rotation=90)
    ax.set_title(title, fontsize=11)
    # annotate
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            val = matrix[i, j]
            ax.text(
                j, i, f"{val:.2f}",
                ha="center", va="center",
                color="white" if abs(val) > 0.6 else "black",
                fontsize=8
            )
    return im

def stacked_barh(ax, labels, data, category_labels, title, x_label):
    y = np.arange(len(labels))
    left = np.zeros(len(labels))
    for i, category in enumerate(data.keys()):
        values = data[category]
        ax.barh(y, values, left=left, label=category_labels[i], height=0.6)
        left += values
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)


# -----------------------------
# Main
# -----------------------------
def main():
    out_dir = os.getcwd()

    # Load data
    sniper = parse_sniper(SNIPER_RESULTS_DIR)
    dr = parse_dynamorio(DYNAMORIO_LOGS_DIR, TIMESTAMP_PREFIX)

    # Save raw inputs (handy for inspection)
    sniper.to_csv(os.path.join(out_dir, "sniper_raw.csv"), index=False)
    if not dr.empty:
        dr.to_csv(os.path.join(out_dir, "dynamorio_raw.csv"), index=False)

    print("\n--- Processing and Filtering Data ---")
    # Focus on benchmarks present in BOTH SRAM and JanS
    sram = sniper[sniper["config"] == "SRAM"].set_index("benchmark")
    jans = sniper[sniper["config"] == "JanS"].set_index("benchmark")
    common = sram.index.intersection(jans.index)
    if len(common) == 0:
        raise RuntimeError("No common benchmarks between SRAM and JanS.")
    
    print(f"Found {len(common)} common benchmarks between SRAM and JanS configs: {common.tolist()}")

    sram = sram.loc[common].copy()
    jans = jans.loc[common].copy()

    # Sort by SRAM execution time to keep labels readable
    order = sram.sort_values("time_s").index.tolist()
    sram = sram.loc[order]
    jans = jans.loc[order]
    labels = order
    
    print("Sorted benchmarks by SRAM execution time:", labels)
    print("\n--- SRAM Data (head) ---")
    print(sram.head())
    print("\n--- JanS Data (head) ---")
    print(jans.head())
    print("-" * 20)

    # ---------------- Sniper comparisons (compact 2x2) ----------------
    plt.rcParams.update({
        "figure.figsize": (11, 8),
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "xtick.labelsize": 8,
        "ytick.labelsize": 8
    })
    fig, axs = plt.subplots(2, 2)

    # 1) Execution time (s)
    grouped_barh(
        axs[0, 0], labels,
        sram["time_s"].values, jans["time_s"].values,
        "SRAM", "JanS",
        "Execution Time", "seconds"
    )

    # 2) Total LLC energy (J)
    grouped_barh(
        axs[0, 1], labels,
        sram["energy_exact_J"].values, jans["energy_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (total)", "Joules"
    )

    # 3) Dynamic LLC energy (J)
    grouped_barh(
        axs[1, 0], labels,
        sram["dyn_exact_J"].values, jans["dyn_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (dynamic only)", "Joules"
    )

    # 4) Leakage LLC energy (J)
    grouped_barh(
        axs[1, 1], labels,
        sram["leak_J"].values, jans["leak_J"].values,
        "SRAM", "JanS",
        "LLC Energy (leakage only)", "Joules"
    )

    fig.suptitle("SRAM vs JanS — Timing and Energy (per benchmark)", fontsize=12, y=0.99)
    fig.tight_layout(rect=[0, 0, 1, 0.97])

    # ------------------ Figure: Normalized Performance Summary ------------------
    norm = pd.DataFrame(index=order)
    norm["norm_time"]   = safe_div(jans["time_s"], sram["time_s"])
    norm["norm_energy"] = safe_div(jans["energy_exact_J"], sram["energy_exact_J"])
    
    print("\n--- Normalized Data (JanS / SRAM) ---")
    print(norm)
    print("-" * 20)

    fig2, axs2 = plt.subplots(2, 2, figsize=(11, 8))

    # 1) Normalized Execution Time
    axs2[0, 0].bar(norm.index, norm["norm_time"])
    axs2[0, 0].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 0].set_title("Normalized Execution Time (JanS / SRAM)", fontsize=11)
    axs2[0, 0].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 0].grid(True, axis="y", linestyle=":")

    # 2) Normalized Total LLC Energy
    axs2[0, 1].bar(norm.index, norm["norm_energy"])
    axs2[0, 1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 1].set_title("Normalized Total LLC Energy (JanS / SRAM)", fontsize=11)
    axs2[0, 1].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 1].grid(True, axis="y", linestyle=":")

    # 3) Absolute IPC
    x = np.arange(len(labels))
    width = 0.35
    axs2[1, 0].bar(x - width/2, sram["ipc"], width, label='SRAM')
    axs2[1, 0].bar(x + width/2, jans["ipc"], width, label='JanS')
    axs2[1, 0].set_title("Instructions Per Cycle (IPC)", fontsize=11)
    axs2[1, 0].set_ylabel("IPC (Higher is Better)", fontsize=10)
    axs2[1, 0].legend(fontsize=8, frameon=False)

    # 4) L3 Miss Rate (%)
    if "l3_miss_rate_pct" in sram.columns and "l3_miss_rate_pct" in jans.columns:
        axs2[1, 1].bar(x - width/2, sram["l3_miss_rate_pct"], width, label='SRAM')
        axs2[1, 1].bar(x + width/2, jans["l3_miss_rate_pct"], width, label='JanS')
        axs2[1, 1].set_title("L3 Miss Rate", fontsize=11)
        axs2[1, 1].set_ylabel("Miss Rate (%)", fontsize=10)
        axs2[1, 1].legend(fontsize=8, frameon=False)
    else:
        axs2[1, 1].axis("off")

    for ax in axs2.flatten():
        ax.set_xticks(np.arange(len(labels)))
        ax.set_xticklabels(labels, rotation=90)
        ax.tick_params(axis="x", labelsize=8)

    # Geomeans for headline
    gm_time   = geomean(norm["norm_time"])
    gm_energy = geomean(norm["norm_energy"])
    fig2.suptitle(f"Performance & Cache Metrics: SRAM vs. JanS — GeoMeans (JanS/SRAM): "
                  f"time={gm_time:.3f}, energy={gm_energy:.3f}",
                  fontsize=13, y=0.99)
    fig2.tight_layout(rect=[0, 0, 1, 0.96])

    # ------------------ Figure: LLC Energy Breakdown ------------------
    fig_e, axs_e = plt.subplots(1, 2, figsize=(11, 5), sharex=True)
    sram_energy_data = {'Dynamic': sram["dyn_exact_J"], 'Leakage': sram["leak_J"]}
    jans_energy_data = {'Dynamic': jans["dyn_exact_J"], 'Leakage': jans["leak_J"]}

    stacked_barh(axs_e[0], labels, sram_energy_data, ['Dynamic', 'Leakage'], "SRAM LLC Energy Breakdown", "Joules")
    stacked_barh(axs_e[1], labels, jans_energy_data, ['Dynamic', 'Leakage'], "JanS LLC Energy Breakdown", "Joules")

    fig_e.suptitle("LLC Energy Composition: Dynamic vs. Leakage", fontsize=13, y=0.99)
    fig_e.tight_layout(rect=[0, 0, 1, 0.94])

    # ---------------- Mechanism View: Dynamic energy per event ----------------
    print("\n--- Calculating Dynamic Energy per Event ---")
    # Try to use *LLC event counts* from Sniper; if unavailable, fall back to *memory instructions* from DynamoRIO.
    per_event_mode = None  # "llc" or "mem"
    sram_denom = detect_llc_events_per_config(sram)
    jans_denom = detect_llc_events_per_config(jans)

    if sram_denom is not None and jans_denom is not None:
        per_event_mode = "llc"
        sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, sram_denom)
        jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, jans_denom)
        denom_label = "LLC event"
    else:
        mem_instr = build_mem_instruction_counts(dr, labels)
        if mem_instr is not None and np.nanmax(mem_instr.values) > 0:
            per_event_mode = "mem"
            # Same denominator for both configs (program-level memory instruction count)
            sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            denom_label = "memory instruction"
        else:
            per_event_mode = None
    
    print(f"Per-event mode chosen: '{per_event_mode}'")
    if per_event_mode:
        print(f"Denominator label: '{denom_label}'")
    print("-" * 20)

    if per_event_mode is not None:
        fig_pe, axs_pe = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(
            axs_pe[0], labels,
            sram_pJ, jans_pJ,
            "SRAM", "JanS",
            f"Dynamic LLC Energy per {denom_label}", f"pJ / {denom_label}"
        )
        ratio = safe_div(jans_pJ, sram_pJ)
        x = np.arange(len(labels))
        axs_pe[1].bar(x, ratio)
        axs_pe[1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
        axs_pe[1].set_title(f"Normalized pJ/{denom_label} (JanS / SRAM)")
        axs_pe[1].set_ylabel("Ratio (Lower is Better)")
        axs_pe[1].set_xticks(x)
        axs_pe[1].set_xticklabels(labels, rotation=90)
        axs_pe[1].grid(True, axis="y", linestyle=":")

        gm_pe = geomean(ratio)
        fig_pe.suptitle(
            f"Mechanism: Dynamic Energy per {denom_label} — Geomean (JanS/SRAM) = {gm_pe:.3f}",
            fontsize=13, y=0.99
        )
        fig_pe.tight_layout(rect=[0, 0, 1, 0.94])

        # Save CSV of the per-event metrics
        per_event_df = pd.DataFrame({
            "benchmark": labels,
            "SRAM_dyn_pJ_per_"+denom_label: sram_pJ,
            "JanS_dyn_pJ_per_"+denom_label: jans_pJ,
            "JanS_over_SRAM_pJ_per_"+denom_label: ratio
        }).set_index("benchmark")
        # Add denominators for transparency
        if per_event_mode == "llc":
            per_event_df["SRAM_"+denom_label+"s"] = sram_denom.reindex(labels).values
            per_event_df["JanS_"+denom_label+"s"] = jans_denom.reindex(labels).values
        else:
            per_event_df[denom_label+"s"] = build_mem_instruction_counts(dr, labels).reindex(labels).values
        
        print("\n--- Per-Event Dynamic Energy Data ---")
        print(per_event_df)
        print("-" * 20)
        per_event_df.to_csv(os.path.join(out_dir, "per_event_dynamic_energy.csv"))

    # ---------------- Correlation: DynamoRIO features vs totals / gains ----------------
    if not dr.empty:
        print("\n--- Building Correlation Matrix Data ---")
        feat_map = {
            "rtotal":     "read_total",
            "runique":    "read_unique",
            "90%f_tr":    "read_footprint90L",   # global, line-level
            "Hrg":        "read_entropy",
            "Hrl":        "read_local_entropy",
            "wtotal":     "write_total",
            "wunique":    "write_unique",
            "90%f_tw":    "write_footprint90L",  # global, line-level
            "Hwg":        "write_entropy",
            "Hwl":        "write_local_entropy",
        }

        feats = pd.DataFrame({"benchmark": dr["benchmark"]})
        for out_name, src in feat_map.items():
            feats[out_name] = pd.to_numeric(dr.get(src), errors="coerce")
        feats = feats.set_index("benchmark")

        # Targets (SRAM absolute) and normalized gains
        targets_sram = sram[["time_s", "energy_exact_J", "dyn_exact_J", "ipc"]].copy()
        if "l3_miss_rate_pct" in sram.columns:
            targets_sram["L3_miss%"] = sram["l3_miss_rate_pct"]
        targets_sram = targets_sram.rename(columns={
            "time_s": "exe_time", "energy_exact_J": "LLC_energy", "dyn_exact_J": "Dyn_energy", "ipc": "IPC"
        })

        corr_df = feats.join(targets_sram, how="inner").join(norm[["norm_time", "norm_energy"]], how="inner")

        # If per-event dynamic energy exists, add one column (SRAM) and one ratio
        if per_event_mode is not None:
            corr_label_abs = f"pJ/{denom_label} (SRAM)"
            corr_label_norm = f"norm_pJ/{denom_label} (JanS/SRAM)"
            corr_df[corr_label_abs] = pd.Series(sram_pJ, index=labels)
            corr_df[corr_label_norm] = pd.Series(safe_div(jans_pJ, sram_pJ), index=labels)

        print("Correlation DataFrame (head):")
        print(corr_df.head())
        print("-" * 20)

        feature_names = [k for k in feat_map.keys() if k in corr_df.columns and not corr_df[k].isna().all()]
        abs_cols = [c for c in ["exe_time", "LLC_energy", "Dyn_energy", "IPC", "L3_miss%",] if c in corr_df.columns and not corr_df[c].isna().all()]
        norm_cols = [c for c in ["norm_time", "norm_energy"] if c in corr_df.columns and not corr_df[c].isna().all()]
        extra_cols = []
        if per_event_mode is not None:
            for c in [corr_label_abs, corr_label_norm]:
                if c in corr_df.columns and not corr_df[c].isna().all():
                    extra_cols.append(c)

        if feature_names and (abs_cols or norm_cols or extra_cols) and len(corr_df.dropna(how="all")) >= 2:
            n_panels = 2 if extra_cols else 2
            fig_c, axs_c = plt.subplots(1, 2, figsize=(9, 5))

            # Features vs. SRAM absolute metrics
            if abs_cols:
                C1 = corr_df[feature_names + abs_cols].corr().loc[feature_names, abs_cols].values
                corr_heatmap(axs_c[0], C1, feature_names, abs_cols, "Features vs. SRAM Totals")
            else:
                axs_c[0].axis("off")

            # Features vs. normalized gains (+ optional per-event targets)
            cols2 = norm_cols + extra_cols
            if cols2:
                C2 = corr_df[feature_names + cols2].corr().loc[feature_names, cols2].values
                corr_heatmap(axs_c[1], C2, feature_names, cols2, "Features vs. Gains / Per-Event")
            else:
                axs_c[1].axis("off")
            
            fig_c.suptitle("Correlation: Memory Features ↔ Totals & Gains", fontsize=13, y=0.99)
            fig_c.tight_layout(rect=[0, 0, 1, 0.92])
        else:
            print("Not enough data for correlation heatmaps (missing features/targets or too few benchmarks).")
    else:
        print("DynamoRIO features unavailable — skipping correlation plots.")

    # -------- Save headline geomeans --------
    geomean_df = pd.DataFrame({
        "metric": ["time (JanS/SRAM)", "total LLC energy (JanS/SRAM)"],
        "geomean_ratio": [gm_time, gm_energy],
    })
    print("\n--- Geomean Summary ---")
    print(geomean_df)
    print("-" * 20)
    geomean_df.to_csv(os.path.join(out_dir, "geomean_summary.csv"), index=False)

    #########################################
    
    print("\n--- Additional System-Level Analysis (Power & EDP) ---")
    sys = pd.DataFrame({
        "benchmark": labels,
        "SRAM_time_s": sram["time_s"].values,
        "JanS_time_s": jans["time_s"].values,
        "SRAM_energy_J": sram["energy_exact_J"].values,
        "JanS_energy_J": jans["energy_exact_J"].values,
        "SRAM_dyn_W": safe_div(sram["dyn_exact_J"].values, sram["time_s"].values),
        "JanS_dyn_W": safe_div(jans["dyn_exact_J"].values, jans["time_s"].values),
        "SRAM_leak_W": safe_div(sram["leak_J"].values, sram["time_s"].values),
        "JanS_leak_W": safe_div(jans["leak_J"].values, jans["time_s"].values),
    }).set_index("benchmark")
    sys["SRAM_EDP"] = sys["SRAM_energy_J"] * sys["SRAM_time_s"]
    sys["JanS_EDP"] = sys["JanS_energy_J"] * sys["JanS_time_s"]

    # --- NEW: ED^2P (energy * time^2) and normalization
    sys["SRAM_ED2P"] = sys["SRAM_energy_J"] * (sys["SRAM_time_s"] ** 2)
    sys["JanS_ED2P"] = sys["JanS_energy_J"] * (sys["JanS_time_s"] ** 2)
    sys["norm_ED2P"] = safe_div(sys["JanS_ED2P"].values, sys["SRAM_ED2P"].values)

    print("System-level metrics (head):")
    print(sys.head())
    print("-" * 20)
    
    fig_sys, axs_sys = plt.subplots(1, 3, figsize=(14, 5))
    grouped_barh(axs_sys[0], labels,
                 sys["SRAM_dyn_W"].values, sys["JanS_dyn_W"].values,
                 "SRAM","JanS","Dynamic Power (LLC)","Watts")
    grouped_barh(axs_sys[1], labels,
                 sys["SRAM_leak_W"].values, sys["JanS_leak_W"].values,
                 "SRAM","JanS","Leakage Power (LLC)","Watts")

    x = np.arange(len(labels))
    edp_ratio = safe_div(sys["JanS_EDP"].values, sys["SRAM_EDP"].values)
    axs_sys[2].bar(x, edp_ratio)
    axs_sys[2].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
    axs_sys[2].set_xticks(x)
    axs_sys[2].set_xticklabels(labels, rotation=90)
    axs_sys[2].set_ylabel("Ratio (Lower is Better)")
    axs_sys[2].set_title("EDP (JanS / SRAM)")
    fig_sys.suptitle("System Power & EDP", fontsize=13, y=0.99)
    fig_sys.tight_layout(rect=[0,0,1,0.94])

    # -- B) Per-miss dynamic energy (best-effort) -----------------------------
    def _approx_misses(df_config, total_series):
        if total_series is None or "l3_miss_rate_pct" not in df_config.columns:
            return None
        total = pd.to_numeric(total_series.reindex(df_config.index), errors="coerce")
        miss_rate = pd.to_numeric(df_config["l3_miss_rate_pct"], errors="coerce") / 100.0
        misses = total * miss_rate
        return misses if misses.notna().any() else None

    sram_total = detect_llc_events_per_config(sram)
    jans_total = detect_llc_events_per_config(jans)
    sram_misses = _approx_misses(sram, sram_total) if sram_total is not None else None
    jans_misses = _approx_misses(jans, jans_total) if jans_total is not None else None

    if sram_misses is not None and jans_misses is not None:
        print("\n--- Per-Miss Dynamic Energy Analysis ---")
        pJmiss_s = safe_div(sram["dyn_exact_J"].values * 1e12, sram_misses.reindex(labels).values)
        pJmiss_j = safe_div(jans["dyn_exact_J"].values * 1e12, jans_misses.reindex(labels).values)
        r_pm = safe_div(pJmiss_j, pJmiss_s)

        pm_df = pd.DataFrame({
            'sram_misses_approx': sram_misses,
            'jans_misses_approx': jans_misses,
            'sram_pJ_per_miss': pJmiss_s,
            'jans_pJ_per_miss': pJmiss_j,
            'ratio_pJ_per_miss': r_pm
        }, index=labels)
        print("Per-miss energy data (head):")
        print(pm_df.head())
        print("-" * 20)

        fig_pm, axs_pm = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(axs_pm[0], labels, pJmiss_s, pJmiss_j,
                     "SRAM","JanS","Dynamic Energy per L3 Miss","pJ / miss")

        axs_pm[1].bar(x, r_pm)
        axs_pm[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
        axs_pm[1].set_xticks(x)
        axs_pm[1].set_xticklabels(labels, rotation=90)
        axs_pm[1].set_ylabel("Ratio (Lower is Better)")
        axs_pm[1].set_title("pJ/miss (JanS / SRAM)")
        fig_pm.suptitle("Per-Miss Dynamic Energy (approx. via miss_rate × total L3/LLC)", y=0.99)
        fig_pm.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[per-miss] Skipped: need total L3/LLC events + l3_miss_rate_pct in summary.csv.")

    print("\n--- Displaying all generated plots ---")
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# --- Parsing Sniper results from: /home/skataoka26/COSC_498/miniMXE/results/sniper_llc_2mb_16w_20251002T020032Z ---
# Sniper parse complete. Merged DataFrame shape: (12, 19)
# Sniper columns found: ['benchmark', 'config', 'time_s', 'energy_exact_J', 'leak_J', 'dyn_exact_nJ', 'dyn_exact_J', 'ipc', 'time_ns', 'l3_miss_rate_pct', 'l3_miss_text', 'l3_accesses_db', 'l3_misses_db', 'l3_read_hits', 'l3_write_hits', 'l3_writebacks', 'l3_evictions', 'l3_misses_custom', 'avg_l3_hit_ns']
# --------------------
#
# --- Parsing DynamoRIO logs from: /home/skataoka26/COSC_498/miniMXE/results_trace/logs with prefix '20250929T203551Z' ---
# Found and processed 12 matching log files.
# DynamoRIO parse complete. DataFrame shape: (12, 40)
# ...

# %%
#!/usr/bin/env python3

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Absolute paths (edit if needed)
# -----------------------------
RUN_IDS = {
    "Baseline (JanS, 2MB, 16 Way)": "sniper_roi1000_fixedcap2m_20250927T171235Z",
    "JanS, 2MB, 8 Way": "sniper_assoc_jans2mb_8way_20250929T024544Z",
    "JanS, 16MB, 16 Way": "sniper_cap_equal_16mb_20250929T024544Z",
    "JanS, 32MB, 16 Way": "sniper_cap_equal_32mb_20250929T024544Z",
    "ChungS, 2MB, 16 Way": "sniper_dev_chungs_2mb_20250929T024350Z",
    "UmekiS, 2MB, 16 Way": "sniper_dev_umekis_2mb_20250929T024536Z",
    "XueS, 2MB, 16 Way": "sniper_dev_xues_2mb_20250929T024537Z"
}
SNIPER_RESULTS_DIR= f"/home/skataoka26/COSC_498/miniMXE/results/{RUN_IDS['Baseline (JanS, 2MB, 16 Way)']}"
# sniper_llc_2mb_16w_20251002T020032Z
SNIPER_RESULTS_DIR= "/home/skataoka26/COSC_498/miniMXE/results/sniper_llc_2mb_16w_20251002T020032Z"
DYNAMORIO_LOGS_DIR = "/home/skataoka26/COSC_498/miniMXE/results_trace/logs"
TIMESTAMP_PREFIX    = "20250929T203551Z"  # prefix used in DynamoRIO filenames

# -----------------------------
# Utilities
# -----------------------------
def safe_div(numer, denom):
    numer = np.array(numer, dtype=float)
    denom = np.array(denom, dtype=float)
    with np.errstate(divide='ignore', invalid='ignore'):
        out = np.where((denom > 0) & np.isfinite(denom), numer / denom, np.nan)
    return out

def geomean(values):
    vals = np.array([v for v in np.ravel(values) if v > 0 and np.isfinite(v)], dtype=float)
    return float(np.exp(np.mean(np.log(vals)))) if len(vals) else np.nan

# --- NEW: statistics helpers for bootstrap / partial correlations / LOO stability
def bootstrap_spearman_ci(x, y, n_boot=10000, alpha=0.05, random_state=0):
    """
    Compute Spearman correlation and bootstrap percentile CI.
    x,y: 1-D arrays (can contain nans).
    Returns (observed_spearman, lower, upper, n_obs)
    """
    rng = np.random.default_rng(random_state)
    mask = np.isfinite(x) & np.isfinite(y)
    x0 = np.array(x)[mask]
    y0 = np.array(y)[mask]
    n = len(x0)
    if n < 3:
        return (np.nan, np.nan, np.nan, n)
    # observed
    obs = pd.Series(x0).corr(pd.Series(y0), method="spearman")
    # bootstrap
    boots = []
    for _ in range(n_boot):
        idx = rng.integers(0, n, n)
        xi = x0[idx]
        yi = y0[idx]
        # if all equal or constant, result may be nan; skip those
        try:
            r = pd.Series(xi).corr(pd.Series(yi), method="spearman")
        except Exception:
            r = np.nan
        boots.append(r)
    boots = np.array([b for b in boots if np.isfinite(b)])
    if boots.size == 0:
        return (obs, np.nan, np.nan, n)
    lo = np.percentile(boots, 100 * alpha / 2.0)
    hi = np.percentile(boots, 100 * (1 - alpha/2.0))
    return (obs, lo, hi, n)

def partial_corr_pearson(x, y, controls):
    """
    Partial Pearson correlation between x and y controlling for columns in controls (2D array or DataFrame).
    Uses residualization (OLS).
    Returns Pearson r and N used.
    """
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)
    if isinstance(controls, pd.DataFrame):
        C = controls.values.astype(float)
    else:
        C = np.asarray(controls, dtype=float)
    mask = np.isfinite(x) & np.isfinite(y) & np.all(np.isfinite(C), axis=1)
    x0 = x[mask]; y0 = y[mask]; C0 = C[mask]
    if len(x0) < 3:
        return (np.nan, len(x0))
    # Add intercept
    Xc = np.column_stack([np.ones(len(C0)), C0])
    # regress x on controls
    beta_x, *_ = np.linalg.lstsq(Xc, x0, rcond=None)
    resid_x = x0 - Xc.dot(beta_x)
    beta_y, *_ = np.linalg.lstsq(Xc, y0, rcond=None)
    resid_y = y0 - Xc.dot(beta_y)
    r = np.corrcoef(resid_x, resid_y)[0,1]
    return (r, len(x0))

def loo_regression_stability(y, X):
    """
    Leave-one-out coefficient stability for linear regression of y ~ X (no intercept automatically added).
    Returns dict with 'coefs' array shape (n_points, n_features), and 'mean_coef', 'std_coef'
    We add intercept inside.
    """
    y = np.asarray(y, dtype=float)
    X = np.asarray(X, dtype=float)
    n = len(y)
    if n < 3 or X.shape[0] != n:
        return None
    coefs = []
    for i in range(n):
        mask = np.ones(n, dtype=bool)
        mask[i] = False
        Xi = X[mask]; yi = y[mask]
        Xi2 = np.column_stack([np.ones(Xi.shape[0]), Xi])
        try:
            beta, *_ = np.linalg.lstsq(Xi2, yi, rcond=None)
            coefs.append(beta)  # intercept + coefs
        except Exception:
            coefs.append(np.full(Xi2.shape[1], np.nan))
    coefs = np.vstack(coefs)
    return {
        "coefs": coefs,
        "mean_coef": np.nanmean(coefs, axis=0),
        "std_coef": np.nanstd(coefs, axis=0)
    }

# -----------------------------
# Parsing helpers
# -----------------------------
def parse_sniper(base_dir):
    """
    Walk output_* folders, read summary.csv and energy_bounds.csv,
    merge them on (benchmark, config). Return a tidy DataFrame.
    Besides the core columns, we opportunistically keep LLC event counters
    (e.g., l3/llc accesses, hits/misses, reads/writes) if they exist.
    """
    energy_rows = []
    summary_rows = []
    print(f"--- Parsing Sniper results from: {base_dir} ---")
    for root, _, files in os.walk(base_dir):
        if os.path.basename(root).startswith("output_") and "summary.csv" in files and "energy_bounds.csv" in files:
            energy_path  = os.path.join(root, "energy_bounds.csv")
            summary_path = os.path.join(root, "summary.csv")

            e = pd.read_csv(energy_path)
            s = pd.read_csv(summary_path)

            # Keep columns we actually use from energy
            e_keep = [
                "benchmark", "config", "time_s",
                "energy_exact_J", "leak_J", "dyn_exact_nJ"
            ]
            e = e[[c for c in e_keep if c in e.columns]].copy()

            # Base columns we want from summary
            s_base = ["benchmark", "config", "ipc", "time_ns", "l3_miss_rate_pct"]
            keep_s = [c for c in s_base if c in s.columns]

            # Try to keep any plausible LLC event columns automatically
            # (we won't fail if they're absent)
            for col in s.columns:
                cl = col.lower()
                if ("l3" in cl or "llc" in cl) and (
                    "access" in cl or "read" in cl or "write" in cl or "hit" in cl or "miss" in cl or "evict" in cl
                ):
                    if col not in keep_s:
                        keep_s.append(col)

            s = s[keep_s].copy()

            # Numeric coercion
            for col in ["time_s", "energy_exact_J", "leak_J", "dyn_exact_nJ"]:
                if col in e.columns:
                    e[col] = pd.to_numeric(e[col], errors="coerce")

            for col in s.columns:
                if col not in ("benchmark", "config"):
                    s[col] = pd.to_numeric(s[col], errors="coerce")

            # Convert nJ -> J
            if "dyn_exact_nJ" in e.columns:
                e["dyn_exact_J"] = e["dyn_exact_nJ"] * 1e-9

            energy_rows.append(e)
            summary_rows.append(s)

    if not energy_rows or not summary_rows:
        raise FileNotFoundError(
            "Could not find summary.csv and energy_bounds.csv in output_* directories under: " + base_dir
        )

    E = pd.concat(energy_rows, ignore_index=True)
    S = pd.concat(summary_rows, ignore_index=True)

    df = pd.merge(E, S, on=["benchmark", "config"], how="inner")

    # minimal sanity
    df = df.dropna(subset=["benchmark", "config", "time_s", "energy_exact_J"])
    print(f"Sniper parse complete. Merged DataFrame shape: {df.shape}")
    print(f"Sniper columns found: {df.columns.tolist()}")
    print("-" * 20)
    return df


def _kv_from_line(s: str) -> dict:
    """Extract numeric key=value pairs from one rwstats line. 'scope' handled separately."""
    kv = {}
    m = re.search(r"\bscope=(\w+)", s)
    if m:
        kv["scope"] = m.group(1)

    for k, v in re.findall(r"([A-Za-z0-9_]+)=([+\-]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+\-]?\d+)?|nan)", s):
        try:
            kv[k] = float("nan") if v.lower() == "nan" else float(v)
        except Exception:
            pass
    return kv


def parse_dynamorio(logs_dir, ts_prefix):
    """
    Parse DynamoRIO log files. For each file, grab the LAST stats-like line
    (lines contain 'scope='). File name format: {ts_prefix}_<benchmark>_instr.rwstats.log
    """
    rows = []
    print(f"\n--- Parsing DynamoRIO logs from: {logs_dir} with prefix '{ts_prefix}' ---")
    if not os.path.isdir(logs_dir):
        print("DynamoRIO logs directory not found. Returning empty DataFrame.")
        print("-" * 20)
        return pd.DataFrame()

    found_files = 0
    for fname in os.listdir(logs_dir):
        if not (fname.startswith(ts_prefix) and fname.endswith("_instr.rwstats.log")):
            continue
        m = re.match(rf"{re.escape(ts_prefix)}_(.+?)_instr\.rwstats\.log$", fname)
        if not m:
            continue
        
        found_files += 1
        benchmark = m.group(1)
        fpath = os.path.join(logs_dir, fname)

        last = None
        with open(fpath, "r", errors="ignore") as f:
            for line in f:
                t = line.strip()
                if "scope=" in t and "=" in t:
                    last = t

        if not last:
            continue

        kv = _kv_from_line(last)
        kv["benchmark"] = benchmark
        rows.append(kv)

    print(f"Found and processed {found_files} matching log files.")
    df = pd.DataFrame(rows) if rows else pd.DataFrame()
    if not df.empty:
        print(f"DynamoRIO parse complete. DataFrame shape: {df.shape}")
        print(f"DynamoRIO columns found: {df.columns.tolist()}")
    else:
        print("DynamoRIO parse complete. No data found, returning empty DataFrame.")
    print("-" * 20)
    return df



# -----------------------------
# Event detection (for per-event view)
# -----------------------------
def detect_llc_events_per_config(df_config):
    """
    Best-effort extraction of an LLC event count from Sniper summary columns
    for a (benchmark-indexed, single-config) DataFrame.
    Priority:
      1) total 'llc_accesses' or 'l3_accesses'
      2) sum of reads+writes
      3) sum of hits+misses
    Returns: pd.Series (index=benchmark) or None if nothing found.
    """
    if df_config is None or df_config.empty:
        return None

    cols = {c.lower(): c for c in df_config.columns}

    # 1) Direct totals
    for key in ["llc_accesses", "l3_accesses", "roi_llc_accesses", "roi_l3_accesses"]:
        if key in cols:
            ser = pd.to_numeric(df_config[cols[key]], errors="coerce")
            if ser.notna().any():
                print(f"[Event Detection] Found total LLC events using column: '{cols[key]}'")
                return ser

    # 2) Reads + writes
    read_keys  = [k for k in cols if ("read"  in k or "rd_" in k) and ("l3" in k or "llc" in k)]
    write_keys = [k for k in cols if ("write" in k or "wr_" in k) and ("l3" in k or "llc" in k)]
    if read_keys and write_keys:
        # choose the most populated pair
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for rk in read_keys:
            for wk in write_keys:
                s = pd.to_numeric(df_config[cols[rk]], errors="coerce") + pd.to_numeric(df_config[cols[wk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[rk], cols[wk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing reads+writes: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    # 3) Hits + misses
    hit_keys   = [k for k in cols if ("hit"   in k) and ("l3" in k or "llc" in k)]
    miss_keys  = [k for k in cols if ("miss"  in k) and ("l3" in k or "llc" in k)]
    if hit_keys and miss_keys:
        best = None
        best_non_na = -1
        best_pair = (None, None)
        for hk in hit_keys:
            for mk in miss_keys:
                s = pd.to_numeric(df_config[cols[hk]], errors="coerce") + pd.to_numeric(df_config[cols[mk]], errors="coerce")
                nn = s.notna().sum()
                if nn > best_non_na:
                    best = s
                    best_non_na = nn
                    best_pair = (cols[hk], cols[mk])
        if best is not None and best_non_na > 0:
            print(f"[Event Detection] Calculated total LLC events by summing hits+misses: '{best_pair[0]}' + '{best_pair[1]}'")
            return best

    print("[Event Detection] No suitable LLC event columns found.")
    return None

def build_mem_instruction_counts(dr_df, benchmarks):
    """
    From DynamoRIO, create a per-benchmark count of memory instructions
    (reads + writes). Returns (Series or None).
    """
    if dr_df is None or dr_df.empty:
        return None

    dr = dr_df.set_index("benchmark")
    read_col  = None
    write_col = None

    # common column names
    for cand in ["read_total", "loads", "ld_total", "mem_reads"]:
        if cand in dr.columns:
            read_col = cand
            break
    for cand in ["write_total", "stores", "st_total", "mem_writes"]:
        if cand in dr.columns:
            write_col = cand
            break

    if read_col is None or write_col is None:
        print("[Mem Instr] Could not find read/write total columns in DynamoRIO data.")
        return None

    print(f"[Mem Instr] Calculating memory instructions from DR columns: '{read_col}' + '{write_col}'")
    mem = pd.to_numeric(dr[read_col], errors="coerce") + pd.to_numeric(dr[write_col], errors="coerce")
    mem = mem.reindex(benchmarks)
    if mem.notna().any():
        return mem
    return None


# -----------------------------
# Plot helpers
# -----------------------------
def grouped_barh(ax, labels, a_values, b_values, a_label, b_label, title, x_label):
    y = np.arange(len(labels))
    h = 0.38
    ax.barh(y - h/2, a_values, height=h, label=a_label)
    ax.barh(y + h/2, b_values, height=h, label=b_label)
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()  # top item at top
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)

def corr_heatmap(ax, matrix, row_labels, col_labels, title):
    im = ax.imshow(matrix, aspect="auto", vmin=-1, vmax=1, cmap="coolwarm")
    ax.set_yticks(np.arange(len(row_labels)))
    ax.set_yticklabels(row_labels)
    ax.set_xticks(np.arange(len(col_labels)))
    ax.set_xticklabels(col_labels, rotation=90)
    ax.set_title(title, fontsize=11)
    # annotate
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            val = matrix[i, j]
            ax.text(
                j, i, f"{val:.2f}",
                ha="center", va="center",
                color="white" if abs(val) > 0.6 else "black",
                fontsize=8
            )
    return im

def stacked_barh(ax, labels, data, category_labels, title, x_label):
    y = np.arange(len(labels))
    left = np.zeros(len(labels))
    # Ensure data values are numpy arrays for safe addition
    for i, category in enumerate(category_labels):
        values = np.nan_to_num(data.get(category, np.zeros(len(labels))))
        ax.barh(y, values, left=left, label=category, height=0.6)
        left += values
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()
    ax.grid(True, axis="x", linestyle=":", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(x_label, fontsize=10)
    ax.tick_params(axis="y", labelsize=8)
    ax.tick_params(axis="x", labelsize=8)
    ax.legend(fontsize=8, frameon=False)


# -----------------------------
# Main
# -----------------------------
def main():
    out_dir = os.getcwd()

    # Load data
    sniper = parse_sniper(SNIPER_RESULTS_DIR)
    dr = parse_dynamorio(DYNAMORIO_LOGS_DIR, TIMESTAMP_PREFIX)

    # Save raw inputs (handy for inspection)
    sniper.to_csv(os.path.join(out_dir, "sniper_raw.csv"), index=False)
    if not dr.empty:
        dr.to_csv(os.path.join(out_dir, "dynamorio_raw.csv"), index=False)

    print("\n--- Processing and Filtering Data ---")
    # Focus on benchmarks present in BOTH SRAM and JanS
    sram = sniper[sniper["config"] == "SRAM"].set_index("benchmark")
    jans = sniper[sniper["config"] == "JanS"].set_index("benchmark")
    common = sram.index.intersection(jans.index)
    if len(common) == 0:
        raise RuntimeError("No common benchmarks between SRAM and JanS.")
    
    print(f"Found {len(common)} common benchmarks between SRAM and JanS configs: {common.tolist()}")

    sram = sram.loc[common].copy()
    jans = jans.loc[common].copy()

    # Sort by SRAM execution time to keep labels readable
    order = sram.sort_values("time_s").index.tolist()
    sram = sram.loc[order]
    jans = jans.loc[order]
    labels = order
    
    print("Sorted benchmarks by SRAM execution time:", labels)
    print("\n--- SRAM Data (head) ---")
    print(sram.head())
    print("\n--- JanS Data (head) ---")
    print(jans.head())
    print("-" * 20)

    # ---------------- Sniper comparisons (compact 2x2) ----------------
    plt.rcParams.update({
        "figure.figsize": (11, 8),
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "xtick.labelsize": 8,
        "ytick.labelsize": 8
    })
    fig, axs = plt.subplots(2, 2)

    # 1) Execution time (s)
    grouped_barh(
        axs[0, 0], labels,
        sram["time_s"].values, jans["time_s"].values,
        "SRAM", "JanS",
        "Execution Time", "seconds"
    )

    # 2) Total LLC energy (J)
    grouped_barh(
        axs[0, 1], labels,
        sram["energy_exact_J"].values, jans["energy_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (total)", "Joules"
    )

    # 3) Dynamic LLC energy (J)
    grouped_barh(
        axs[1, 0], labels,
        sram["dyn_exact_J"].values, jans["dyn_exact_J"].values,
        "SRAM", "JanS",
        "LLC Energy (dynamic only)", "Joules"
    )

    # 4) Leakage LLC energy (J)
    grouped_barh(
        axs[1, 1], labels,
        sram["leak_J"].values, jans["leak_J"].values,
        "SRAM", "JanS",
        "LLC Energy (leakage only)", "Joules"
    )

    fig.suptitle("SRAM vs JanS — Timing and Energy (per benchmark)", fontsize=12, y=0.99)
    fig.tight_layout(rect=[0, 0, 1, 0.97])

    # ------------------ Figure: Normalized Performance Summary ------------------
    norm = pd.DataFrame(index=order)
    norm["norm_time"]   = safe_div(jans["time_s"], sram["time_s"])
    norm["norm_energy"] = safe_div(jans["energy_exact_J"], sram["energy_exact_J"])
    
    print("\n--- Normalized Data (JanS / SRAM) ---")
    print(norm)
    print("-" * 20)

    fig2, axs2 = plt.subplots(2, 2, figsize=(11, 8))

    # 1) Normalized Execution Time
    axs2[0, 0].bar(norm.index, norm["norm_time"])
    axs2[0, 0].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 0].set_title("Normalized Execution Time (JanS / SRAM)", fontsize=11)
    axs2[0, 0].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 0].grid(True, axis="y", linestyle=":")

    # 2) Normalized Total LLC Energy
    axs2[0, 1].bar(norm.index, norm["norm_energy"])
    axs2[0, 1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
    axs2[0, 1].set_title("Normalized Total LLC Energy (JanS / SRAM)", fontsize=11)
    axs2[0, 1].set_ylabel("Ratio (Lower is Better)", fontsize=10)
    axs2[0, 1].grid(True, axis="y", linestyle=":")

    # 3) Absolute IPC
    x = np.arange(len(labels))
    width = 0.35
    axs2[1, 0].bar(x - width/2, sram["ipc"], width, label='SRAM')
    axs2[1, 0].bar(x + width/2, jans["ipc"], width, label='JanS')
    axs2[1, 0].set_title("Instructions Per Cycle (IPC)", fontsize=11)
    axs2[1, 0].set_ylabel("IPC (Higher is Better)", fontsize=10)
    axs2[1, 0].legend(fontsize=8, frameon=False)

    # 4) L3 Miss Rate (%)
    if "l3_miss_rate_pct" in sram.columns and "l3_miss_rate_pct" in jans.columns:
        axs2[1, 1].bar(x - width/2, sram["l3_miss_rate_pct"], width, label='SRAM')
        axs2[1, 1].bar(x + width/2, jans["l3_miss_rate_pct"], width, label='JanS')
        axs2[1, 1].set_title("L3 Miss Rate", fontsize=11)
        axs2[1, 1].set_ylabel("Miss Rate (%)", fontsize=10)
        axs2[1, 1].legend(fontsize=8, frameon=False)
    else:
        axs2[1, 1].axis("off")

    for ax in axs2.flatten():
        ax.set_xticks(np.arange(len(labels)))
        ax.set_xticklabels(labels, rotation=90)
        ax.tick_params(axis="x", labelsize=8)

    # Geomeans for headline
    gm_time   = geomean(norm["norm_time"])
    gm_energy = geomean(norm["norm_energy"])
    fig2.suptitle(f"Performance & Cache Metrics: SRAM vs. JanS — GeoMeans (JanS/SRAM): "
                  f"time={gm_time:.3f}, energy={gm_energy:.3f}",
                  fontsize=13, y=0.99)
    fig2.tight_layout(rect=[0, 0, 1, 0.96])

    # ------------------ Figure: LLC Energy Breakdown ------------------
    fig_e, axs_e = plt.subplots(1, 2, figsize=(11, 5), sharex=True)
    sram_energy_data = {'Dynamic': sram["dyn_exact_J"], 'Leakage': sram["leak_J"]}
    jans_energy_data = {'Dynamic': jans["dyn_exact_J"], 'Leakage': jans["leak_J"]}

    stacked_barh(axs_e[0], labels, sram_energy_data, ['Dynamic', 'Leakage'], "SRAM LLC Energy Breakdown", "Joules")
    stacked_barh(axs_e[1], labels, jans_energy_data, ['Dynamic', 'Leakage'], "JanS LLC Energy Breakdown", "Joules")

    fig_e.suptitle("LLC Energy Composition: Dynamic vs. Leakage", fontsize=13, y=0.99)
    fig_e.tight_layout(rect=[0, 0, 1, 0.94])

    # ---------------- Mechanism View: Dynamic energy per event ----------------
    print("\n--- Calculating Dynamic Energy per Event ---")
    # Try to use *LLC event counts* from Sniper; if unavailable, fall back to *memory instructions* from DynamoRIO.
    per_event_mode = None  # "llc" or "mem"
    sram_denom = detect_llc_events_per_config(sram)
    jans_denom = detect_llc_events_per_config(jans)

    if sram_denom is not None and jans_denom is not None:
        per_event_mode = "llc"
        sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, sram_denom)
        jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, jans_denom)
        denom_label = "LLC event"
    else:
        mem_instr = build_mem_instruction_counts(dr, labels)
        if mem_instr is not None and np.nanmax(mem_instr.values) > 0:
            per_event_mode = "mem"
            # Same denominator for both configs (program-level memory instruction count)
            sram_pJ = safe_div(sram["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            jans_pJ = safe_div(jans["dyn_exact_J"] * 1e12, mem_instr.reindex(labels).values)
            denom_label = "memory instruction"
        else:
            per_event_mode = None
    
    print(f"Per-event mode chosen: '{per_event_mode}'")
    if per_event_mode:
        print(f"Denominator label: '{denom_label}'")
    print("-" * 20)

    if per_event_mode is not None:
        fig_pe, axs_pe = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(
            axs_pe[0], labels,
            sram_pJ, jans_pJ,
            "SRAM", "JanS",
            f"Dynamic LLC Energy per {denom_label}", f"pJ / {denom_label}"
        )
        ratio = safe_div(jans_pJ, sram_pJ)
        x = np.arange(len(labels))
        axs_pe[1].bar(x, ratio)
        axs_pe[1].axhline(1.0, color='r', linestyle='--', linewidth=1.2)
        axs_pe[1].set_title(f"Normalized pJ/{denom_label} (JanS / SRAM)")
        axs_pe[1].set_ylabel("Ratio (Lower is Better)")
        axs_pe[1].set_xticks(x)
        axs_pe[1].set_xticklabels(labels, rotation=90)
        axs_pe[1].grid(True, axis="y", linestyle=":")

        gm_pe = geomean(ratio)
        fig_pe.suptitle(
            f"Mechanism: Dynamic Energy per {denom_label} — Geomean (JanS/SRAM) = {gm_pe:.3f}",
            fontsize=13, y=0.99
        )
        fig_pe.tight_layout(rect=[0, 0, 1, 0.94])

        # Save CSV of the per-event metrics
        per_event_df = pd.DataFrame({
            "benchmark": labels,
            "SRAM_dyn_pJ_per_"+denom_label: sram_pJ,
            "JanS_dyn_pJ_per_"+denom_label: jans_pJ,
            "JanS_over_SRAM_pJ_per_"+denom_label: ratio
        }).set_index("benchmark")
        # Add denominators for transparency
        if per_event_mode == "llc":
            per_event_df["SRAM_"+denom_label+"s"] = sram_denom.reindex(labels).values
            per_event_df["JanS_"+denom_label+"s"] = jans_denom.reindex(labels).values
        else:
            per_event_df[denom_label+"s"] = build_mem_instruction_counts(dr, labels).reindex(labels).values
        
        print("\n--- Per-Event Dynamic Energy Data ---")
        print(per_event_df)
        print("-" * 20)
        per_event_df.to_csv(os.path.join(out_dir, "per_event_dynamic_energy.csv"))
        
    # [MODIFIED] Moved EDP/ED2P calculations earlier to be available for correlation plots
    print("\n--- System-Level Analysis (Power & EDP) ---")
    sys = pd.DataFrame({
        "benchmark": labels,
        "SRAM_time_s": sram["time_s"].values,
        "JanS_time_s": jans["time_s"].values,
        "SRAM_energy_J": sram["energy_exact_J"].values,
        "JanS_energy_J": jans["energy_exact_J"].values,
        "SRAM_dyn_W": safe_div(sram["dyn_exact_J"].values, sram["time_s"].values),
        "JanS_dyn_W": safe_div(jans["dyn_exact_J"].values, jans["time_s"].values),
        "SRAM_leak_W": safe_div(sram["leak_J"].values, sram["time_s"].values),
        "JanS_leak_W": safe_div(jans["leak_J"].values, jans["time_s"].values),
    }).set_index("benchmark")
    sys["SRAM_EDP"] = sys["SRAM_energy_J"] * sys["SRAM_time_s"]
    sys["JanS_EDP"] = sys["JanS_energy_J"] * sys["JanS_time_s"]
    sys["SRAM_ED2P"] = sys["SRAM_energy_J"] * (sys["SRAM_time_s"] ** 2)
    sys["JanS_ED2P"] = sys["JanS_energy_J"] * (sys["JanS_time_s"] ** 2)

    sys["norm_EDP"] = safe_div(sys["JanS_EDP"].values, sys["SRAM_EDP"].values)
    sys["norm_ED2P"] = safe_div(sys["JanS_ED2P"].values, sys["SRAM_ED2P"].values)
    
    print("System-level metrics (head):")
    print(sys.head())
    print("-" * 20)
    
    fig_sys, axs_sys = plt.subplots(1, 3, figsize=(14, 5))
    grouped_barh(axs_sys[0], labels,
                 sys["SRAM_dyn_W"].values, sys["JanS_dyn_W"].values,
                 "SRAM","JanS","Dynamic Power (LLC)","Watts")
    grouped_barh(axs_sys[1], labels,
                 sys["SRAM_leak_W"].values, sys["JanS_leak_W"].values,
                 "SRAM","JanS","Leakage Power (LLC)","Watts")

    x = np.arange(len(labels))
    axs_sys[2].bar(x, sys["norm_EDP"].values)
    axs_sys[2].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
    axs_sys[2].set_xticks(x)
    axs_sys[2].set_xticklabels(labels, rotation=90)
    axs_sys[2].set_ylabel("Ratio (Lower is Better)")
    axs_sys[2].set_title("EDP (JanS / SRAM)")
    fig_sys.suptitle("System Power & EDP", fontsize=13, y=0.99)
    fig_sys.tight_layout(rect=[0,0,1,0.94])

    # ---------------- Correlation: DynamoRIO features vs totals / gains [MODIFIED: Spearman + Pearson] ----------------
    if not dr.empty:
        print("\n--- Building Correlation Matrix Data (Spearman + Pearson) ---")
        feat_map = {
            "rtotal":     "read_total",
            "runique":    "read_unique",
            "90%f_tr":    "read_footprint90L",   # global, line-level
            "Hrg":        "read_entropy",
            "Hrl":        "read_local_entropy",
            "wtotal":     "write_total",
            "wunique":    "write_unique",
            "90%f_tw":    "write_footprint90L",  # global, line-level
            "Hwg":        "write_entropy",
            "Hwl":        "write_local_entropy",
        }

        feats = pd.DataFrame({"benchmark": dr["benchmark"]})
        for out_name, src in feat_map.items():
            feats[out_name] = pd.to_numeric(dr.get(src), errors="coerce")
        feats = feats.set_index("benchmark")

        # Additional DR-derived features (ratios, intensities)
        print("Calculating additional DynamoRIO features (ratios, intensities)...")
        dr_idx = dr.set_index("benchmark")
        instr_col_name = 'instrs' if 'instrs' in dr_idx.columns else ('instructions' if 'instructions' in dr_idx.columns else None)

        if instr_col_name:
            instr_count = pd.to_numeric(dr_idx[instr_col_name], errors='coerce')
            feats['read_intensity']  = safe_div(feats['rtotal'], instr_count)
            feats['write_intensity'] = safe_div(feats['wtotal'], instr_count)
        else:
            print("Warning: total instruction column not found in DR logs. Skipping intensity features.")

        feats['rw_ratio_total']           = safe_div(feats['rtotal'], feats['wtotal'])
        feats['rw_ratio_unique']          = safe_div(feats['runique'], feats['wunique'])
        feats['rw_ratio_global_entropy']  = safe_div(feats['Hrg'], feats['Hwg'])
        feats['rw_ratio_local_entropy']   = safe_div(feats['Hrl'], feats['Hwl'])
        feats['rw_ratio_90_footprint']    = safe_div(feats['90%f_tr'], feats['90%f_tw'])

        # Targets (SRAM absolute) and normalized gains
        targets_sram = sram[["time_s", "energy_exact_J", "dyn_exact_J", "ipc"]].copy()
        if "l3_miss_rate_pct" in sram.columns:
            targets_sram["L3_miss%"] = sram["l3_miss_rate_pct"]
        targets_sram = targets_sram.rename(columns={
            "time_s": "exe_time", "energy_exact_J": "LLC_energy", "dyn_exact_J": "Dyn_energy", "ipc": "IPC"
        })

        corr_df = feats.join(targets_sram, how="inner").join(norm, how="inner").join(sys, how="inner")

        # If per-event dynamic energy exists, add one column (SRAM) and one ratio
        extra_cols = []
        if 'per_event_mode' in locals() and per_event_mode is not None:
            corr_label_abs  = f"pJ/{denom_label} (SRAM)"
            corr_label_norm = f"norm_pJ/{denom_label} (JanS/SRAM)"
            corr_df[corr_label_abs]  = pd.Series(sram_pJ, index=labels)
            corr_df[corr_label_norm] = pd.Series(safe_div(jans_pJ, sram_pJ), index=labels)
            for c in [corr_label_abs, corr_label_norm]:
                if c in corr_df.columns and not corr_df[c].isna().all():
                    extra_cols.append(c)

        print("Correlation DataFrame (head):")
        print(corr_df.head())
        print("-" * 20)

        base_feature_names = list(feat_map.keys())
        new_feature_names  = ['read_intensity','write_intensity','rw_ratio_total','rw_ratio_unique',
                              'rw_ratio_global_entropy','rw_ratio_local_entropy','rw_ratio_90_footprint']
        feature_names = [c for c in base_feature_names + new_feature_names
                         if c in corr_df.columns and not corr_df[c].isna().all()]

        abs_cols  = [c for c in ["exe_time","LLC_energy","Dyn_energy","IPC","L3_miss%","SRAM_EDP","SRAM_ED2P"]
                     if c in corr_df.columns and not corr_df[c].isna().all()]
        norm_cols = [c for c in ["norm_time","norm_energy","norm_EDP","norm_ED2P"]
                     if c in corr_df.columns and not corr_df[c].isna().all()]
        cols2 = norm_cols + extra_cols

        if feature_names and (abs_cols or cols2) and len(corr_df.dropna(how="all")) >= 2:
            for method, pretty in [("spearman", "Spearman’s ρ"), ("pearson", "Pearson’s r")]:
                fig_c, axs_c = plt.subplots(1, 2, figsize=(11, 7))

                # Features vs. SRAM absolute metrics
                if abs_cols:
                    C1 = corr_df[feature_names + abs_cols].corr(method=method).loc[feature_names, abs_cols].values
                    corr_heatmap(axs_c[0], C1, feature_names, abs_cols, f"Features vs. SRAM Totals & EDP ({pretty})")
                else:
                    axs_c[0].axis("off")

                # Features vs. normalized gains (+ optional per-event targets)
                if cols2:
                    C2 = corr_df[feature_names + cols2].corr(method=method).loc[feature_names, cols2].values
                    corr_heatmap(axs_c[1], C2, feature_names, cols2, f"Features vs. Gains & Per-Event ({pretty})")
                else:
                    axs_c[1].axis("off")

                fig_c.suptitle(f"Correlation: Memory Features ↔ Performance — {pretty}", fontsize= thirteen if 'thirteen' in globals() else 13, y=0.99)
                fig_c.tight_layout(rect=[0, 0, 1, 0.94])
        else:
            print("Not enough data for correlation heatmaps (missing features/targets or too few benchmarks).")
    else:
        print("DynamoRIO features unavailable — skipping correlation plots.")


    # -- B) Per-miss dynamic energy (best-effort) -----------------------------
    def _approx_misses(df_config, total_series):
        if total_series is None or "l3_miss_rate_pct" not in df_config.columns:
            return None
        total = pd.to_numeric(total_series.reindex(df_config.index), errors="coerce")
        miss_rate = pd.to_numeric(df_config["l3_miss_rate_pct"], errors="coerce") / 100.0
        misses = total * miss_rate
        return misses if misses.notna().any() else None

    sram_total = detect_llc_events_per_config(sram)
    jans_total = detect_llc_events_per_config(jans)
    sram_misses = _approx_misses(sram, sram_total) if sram_total is not None else None
    jans_misses = _approx_misses(jans, jans_total) if jans_total is not None else None

    if sram_misses is not None and jans_misses is not None:
        print("\n--- Per-Miss Dynamic Energy Analysis ---")
        pJmiss_s = safe_div(sram["dyn_exact_J"].values * 1e12, sram_misses.reindex(labels).values)
        pJmiss_j = safe_div(jans["dyn_exact_J"].values * 1e12, jans_misses.reindex(labels).values)
        r_pm = safe_div(pJmiss_j, pJmiss_s)

        pm_df = pd.DataFrame({
            'sram_misses_approx': sram_misses,
            'jans_misses_approx': jans_misses,
            'sram_pJ_per_miss': pJmiss_s,
            'jans_pJ_per_miss': pJmiss_j,
            'ratio_pJ_per_miss': r_pm
        }, index=labels)
        print("Per-miss energy data (head):")
        print(pm_df.head())
        print("-" * 20)

        fig_pm, axs_pm = plt.subplots(1, 2, figsize=(11, 5))
        grouped_barh(axs_pm[0], labels, pJmiss_s, pJmiss_j,
                     "SRAM","JanS","Dynamic Energy per L3 Miss","pJ / miss")

        axs_pm[1].bar(x, r_pm)
        axs_pm[1].axhline(1.0, linestyle="--", linewidth=1.2, color="r")
        axs_pm[1].set_xticks(x)
        axs_pm[1].set_xticklabels(labels, rotation=90)
        axs_pm[1].set_ylabel("Ratio (Lower is Better)")
        axs_pm[1].set_title("pJ/miss (JanS / SRAM)")
        fig_pm.suptitle("Per-Miss Dynamic Energy (approx. via miss_rate × total L3/LLC)", y=0.99)
        fig_pm.tight_layout(rect=[0,0,1,0.94])
    else:
        print("\n[per-miss] Skipped: need total L3/LLC events + l3_miss_rate_pct in summary.csv.")

    # -- C) Event-type cost fit (pJ per event) -------------------------------
    # Estimate costs for {read_hit, read_miss, write_hit, write_miss, evict} via least squares, if columns exist.
    def _choose_col(df_config, must_terms, maybes=("l3","llc")):
        best = None; best_pop = -1
        for c in df_config.columns:
            cl = c.lower()
            if all(t in cl for t in must_terms) and any(m in cl for m in maybes):
                ser = pd.to_numeric(df_config[c], errors="coerce")
                pop = ser.notna().sum()
                if pop > best_pop:
                    best, best_pop = c, pop
        return best

    def _find_event_cols(df_config):
        mapping = {
            "read_hit":  ["read","hit"],
            "write_hit": ["write","hit"],
            "read_miss": ["read","miss"],
            "write_miss":["write","miss"],
            "evict":     ["evict"],
        }
        out = {}
        for name, terms in mapping.items():
            col = _choose_col(df_config, terms)
            if col is None and name == "evict":
                col = _choose_col(df_config, ["writeback"]) or _choose_col(df_config, ["wb"])
            if col is not None:
                out[name] = col
        return out

    def _fit_costs(df_config, event_cols):
        if not event_cols:
            return None, None
        X_cols = list(event_cols.values())
        X = np.column_stack([pd.to_numeric(df_config[c], errors="coerce").fillna(0.0).values for c in X_cols])
        y = pd.to_numeric(df_config["dyn_exact_J"], errors="coerce").values
        mask = np.isfinite(y)
        for i in range(X.shape[1]):
            mask &= np.isfinite(X[:, i])
        X, y = X[mask], y[mask]
        if X.shape[0] < len(X_cols):
            return None, None
        beta, residuals, rank, s = np.linalg.lstsq(X, y, rcond=None)
        r2 = 1.0 - ((y - X @ beta)**2).sum() / np.maximum(1e-12, ((y - y.mean())**2).sum())
        return pd.Series(beta * 1e12, index=list(event_cols.keys())), r2  # pJ/event

    sram_event_cols = _find_event_cols(sram)
    jans_event_cols = _find_event_cols(jans)
    coef_s, r2_s = _fit_costs(sram, sram_event_cols)
    coef_j, r2_j = _fit_costs(jans, jans_event_cols)

    if coef_s is not None or coef_j is not None:
        print("\n--- Fitted Event Cost Analysis ---")
        print(f"SRAM event columns used for fit: {sram_event_cols}")
        print(f"JanS event columns used for fit: {jans_event_cols}")
        
        keys = sorted(set([] if coef_s is None else coef_s.index).union([] if coef_j is None else coef_j.index))
        s_vals = np.array([coef_s.get(k, np.nan) if coef_s is not None else np.nan for k in keys])
        j_vals = np.array([coef_j.get(k, np.nan) if coef_j is not None else np.nan for k in keys])

        fit_df = pd.DataFrame({'event_type': keys, 'SRAM_pJ_per_event': s_vals, 'JanS_pJ_per_event': j_vals}).set_index('event_type')
        print("Fitted coefficients (pJ/event):")
        print(fit_df)
        print(f"SRAM R² = {r2_s:.3f}, JanS R² = {r2_j:.3f}")
        print("-" * 20)

        fig_ev, ax_ev = plt.subplots(1, 1, figsize=(10, 4.8))
        xx = np.arange(len(keys)); w = 0.42
        ax_ev.bar(xx - w/2, s_vals, width=w, label="SRAM")
        ax_ev.bar(xx + w/2, j_vals, width=w, label="JanS")
        ax_ev.set_xticks(xx)
        ax_ev.set_xticklabels(keys)
        ax_ev.set_ylabel("pJ / event")
        ax_ev.set_title("Fitted LLC Event Costs")
        ax_ev.grid(True, axis="y", linestyle=":")
        ax_ev.legend(fontsize=8, frameon=False)
        fig_ev.suptitle(f"Event-Cost Fit (least squares) — R² SRAM={r2_s if r2_s is not None else float('nan'):.2f}, JanS={r2_j if r2_j is not None else float('nan'):.2f}", y=0.99)
        fig_ev.tight_layout(rect=[0,0,1,0.94])
        
        # [NEW] Bar plots showing LLC dynamic energy decompositions
        fig_decomp, axs_decomp = plt.subplots(1, 2, figsize=(12, 6), sharey=True)
        all_event_keys = sorted(list(sram_event_cols.keys() | jans_event_cols.keys()))
        
        # SRAM decomposition
        if coef_s is not None:
            sram_decomp_data = {}
            for event_name in all_event_keys:
                if event_name in sram_event_cols:
                    count = pd.to_numeric(sram[sram_event_cols[event_name]], errors='coerce').fillna(0)
                    cost_J = coef_s.get(event_name, 0) * 1e-12
                    energy = count * cost_J
                    sram_decomp_data[event_name] = energy.values
            stacked_barh(axs_decomp[0], labels, sram_decomp_data, all_event_keys, "SRAM Dynamic Energy Decomposition", "Joules")
        
        # JanS decomposition
        if coef_j is not None:
            jans_decomp_data = {}
            for event_name in all_event_keys:
                if event_name in jans_event_cols:
                    count = pd.to_numeric(jans[jans_event_cols[event_name]], errors='coerce').fillna(0)
                    cost_J = coef_j.get(event_name, 0) * 1e-12
                    energy = count * cost_J
                    jans_decomp_data[event_name] = energy.values
            stacked_barh(axs_decomp[1], labels, jans_decomp_data, all_event_keys, "JanS Dynamic Energy Decomposition", "Joules")
        
        fig_decomp.suptitle("LLC Dynamic Energy Decomposition by Event Type (Estimated)", fontsize=13, y=0.99)
        fig_decomp.tight_layout(rect=[0,0,1,0.95])

    else:
        print("\n[event-fit] Skipped: insufficient L3/LLC event columns in summary.csv.")
    
    # -------- Save headline geomeans --------
    geomean_df = pd.DataFrame({
        "metric": ["time (JanS/SRAM)", "total LLC energy (JanS/SRAM)"],
        "geomean_ratio": [gm_time, gm_energy],
    })
    print("\n--- Geomean Summary ---")
    print(geomean_df)
    print("-" * 20)
    geomean_df.to_csv(os.path.join(out_dir, "geomean_summary.csv"), index=False)
    
    print("\n--- Displaying all generated plots ---")
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# --- Parsing Sniper results from: /home/skataoka26/COSC_498/miniMXE/results/sniper_llc_2mb_16w_20251002T020032Z ---
# Sniper parse complete. Merged DataFrame shape: (12, 19)
# Sniper columns found: ['benchmark', 'config', 'time_s', 'energy_exact_J', 'leak_J', 'dyn_exact_nJ', 'dyn_exact_J', 'ipc', 'time_ns', 'l3_miss_rate_pct', 'l3_miss_text', 'l3_accesses_db', 'l3_misses_db', 'l3_read_hits', 'l3_write_hits', 'l3_writebacks', 'l3_evictions', 'l3_misses_custom', 'avg_l3_hit_ns']
# --------------------
#
# --- Parsing DynamoRIO logs from: /home/skataoka26/COSC_498/miniMXE/results_trace/logs with prefix '20250929T203551Z' ---
# Found and processed 12 matching log files.
# DynamoRIO parse complete. DataFrame shape: (12, 40)
# ...
